# %%
"""
Train a model on TACRED.
"""

import os
from datetime import datetime
import time
import numpy as np
import random
import argparse
from shutil import copyfile
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from data.loader import DataLoader
from model.rnn import RelationModel
from utils import scorer, constant, helper
from utils.vocab import Vocab

# %%
print(torch.__version__)
# Out:
# 0.3.1.post2

# %%
import argparse
import sys; sys.argv=['']; del sys  # this has to be done if argparse is used in the notebook
from datetime import datetime

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--data_dir', type=str, default='dataset/tacred')
parser.add_argument('--vocab_dir', type=str, default='dataset/vocab')
parser.add_argument('--emb_dim', type=int, default=300, help='Word embedding dimension.')
parser.add_argument('--ner_dim', type=int, default=30, help='NER embedding dimension.')
parser.add_argument('--pos_dim', type=int, default=30, help='POS embedding dimension.')
parser.add_argument('--hidden_dim', type=int, default=360, help='RNN hidden state size.')            # 200 original
parser.add_argument('--num_layers', type=int, default=2, help='Num of self-attention layers.')
parser.add_argument('--dropout', type=float, default=0.2, help='Input and RNN dropout rate.')        # 0.5 original
parser.add_argument('--word_dropout', type=float, default=0.04,
                    help='The rate at which randomly set a word to UNK.'
                   )
parser.add_argument('--topn', type=int, default=1e10, help='Only finetune top N embeddings.')
parser.add_argument('--lower', dest='lower', action='store_true', help='Lowercase all words.')
parser.add_argument('--no-lower', dest='lower', action='store_false')
parser.set_defaults(lower=False)

parser.add_argument(
    '--self-attn', dest='self_att', action='store_true', 
    help='Use self-attention layer instead of LSTM.', default=True
)

parser.add_argument('--attn', dest='attn', action='store_true', help='Use attention layer.', default="true")
parser.add_argument('--no-attn', dest='attn', action='store_false')
parser.set_defaults(attn=True)

parser.add_argument('--attn_dim', type=int, default=200, help='Attention size.')                    # 200 original
parser.add_argument('--pe_dim', type=int, default=30, help='Position encoding dimension.')

parser.add_argument('--lr', type=float, default=0.2, help='Applies to SGD and Adagrad.')            # lr
parser.add_argument('--lr_decay', type=float, default=0.8)                                          # lr_decay 0.9 original
parser.add_argument('--optim', type=str, default='sgd', help='sgd, adagrad, adam or adamax.')       # sgd original
parser.add_argument('--num_epoch', type=int, default=100)                                           # epochs 30 original
parser.add_argument('--batch_size', type=int, default=50)                                           # batch size 50 original
parser.add_argument('--max_grad_norm', type=float, default=5.0, help='Gradient clipping.')
parser.add_argument('--log_step', type=int, default=400, help='Print log every k steps.')
parser.add_argument('--log', type=str, default='logs.txt', help='Write training log to file.')
parser.add_argument('--save_epoch', type=int, default=5, help='Save model checkpoints every k epochs.')
parser.add_argument('--save_dir', type=str, default='./saved_models', help='Root dir for saving models.')

parser.add_argument(
    '--id', type=str, 
    default='18_self_attention_dropout',                                 # change model folder output before running
    help='Model ID under which to save models.'
   )

parser.add_argument('--info', type=str, default='', help='Optional info for the experiment.')

parser.add_argument('--seed', type=int, default=1234)
parser.add_argument('--cuda', type=bool, default=torch.cuda.is_available())
parser.add_argument('--cpu', action='store_true', help='Ignore CUDA.')

args = parser.parse_args()

# %%
torch.manual_seed(args.seed)
np.random.seed(args.seed)
random.seed(1234)
if args.cpu:
    args.cuda = False
elif args.cuda:
    torch.cuda.manual_seed(args.seed)

# make opt
opt = vars(args)
opt['num_class'] = len(constant.LABEL_TO_ID)

# load vocab
vocab_file = opt['vocab_dir'] + '/vocab.pkl'
vocab = Vocab(vocab_file, load=True)
opt['vocab_size'] = vocab.size
emb_file = opt['vocab_dir'] + '/embedding.npy'
emb_matrix = np.load(emb_file)
assert emb_matrix.shape[0] == vocab.size
assert emb_matrix.shape[1] == opt['emb_dim']

# load data
print("Loading data from {} with batch size {}...".format(opt['data_dir'], opt['batch_size']))
train_batch = DataLoader(opt['data_dir'] + '/train.json', opt['batch_size'], opt, vocab, evaluation=False)
dev_batch = DataLoader(opt['data_dir'] + '/dev.json', opt['batch_size'], opt, vocab, evaluation=True)

model_id = opt['id'] if len(opt['id']) > 1 else '0' + opt['id']
model_save_dir = opt['save_dir'] + '/' + model_id
opt['model_save_dir'] = model_save_dir
helper.ensure_dir(model_save_dir, verbose=True)

# save config
helper.save_config(opt, model_save_dir + '/config.json', verbose=True)
vocab.save(model_save_dir + '/vocab.pkl')
file_logger = helper.FileLogger(model_save_dir + '/' + opt['log'], header="# epoch\ttrain_loss\tdev_loss\tdev_f1")

# print model info
helper.print_config(opt)

# model
model = RelationModel(opt, emb_matrix=emb_matrix)

id2label = dict([(v,k) for k,v in constant.LABEL_TO_ID.items()])
dev_f1_history = []
current_lr = opt['lr']

global_step = 0
global_start_time = time.time()
format_str = '{}: step {}/{} (epoch {}/{}), loss = {:.6f} ({:.3f} sec/batch), lr: {:.6f}'
max_steps = len(train_batch) * opt['num_epoch']
# Out:
# Vocab size 55950 loaded from file
# Loading data from dataset/tacred with batch size 50...
# 1501 batches created for dataset/tacred/train.json
# 516 batches created for dataset/tacred/dev.json
# Config saved to file ./saved_models/18_self_attention_dropout/config.json
# Overwriting old vocab file at ./saved_models/18_self_attention_dropout/vocab.pkl
#
# Running with the following configs:
# 	data_dir : dataset/tacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 360
# 	num_layers : 2
# 	dropout : 0.2
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	self_att : True
# 	attn : True
# 	attn_dim : 200
# 	pe_dim : 30
# 	lr : 0.3
# 	lr_decay : 0.9
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 400
# 	log : logs.txt
# 	save_epoch : 5
# 	save_dir : ./saved_models
# 	id : 18_self_attention_dropout
# 	info :
# 	seed : 1234
# 	cuda : True
# 	cpu : False
# 	num_class : 42
# 	vocab_size : 55950
# 	model_save_dir : ./saved_models/18_self_attention_dropout
#
#
# Finetune all embeddings.

# %%
# start training
for epoch in range(1, opt['num_epoch']+1):
    train_loss = 0
    for i, batch in enumerate(train_batch):
        start_time = time.time()
        global_step += 1
        loss = model.update(batch)
        train_loss += loss
        if global_step % opt['log_step'] == 0:
            duration = time.time() - start_time
            print(
                format_str.format(datetime.now(), global_step, max_steps, epoch,
                opt['num_epoch'], loss, duration, current_lr)
            )
        # do garbage collection, as per https://discuss.pytorch.org/t/best-practices-for-maximum-gpu-utilization/13863/6
        del loss

    # eval on dev
    print("Evaluating on dev set...")
    predictions = []
    dev_loss = 0
    for i, batch in enumerate(dev_batch):
        preds, _, loss = model.predict(batch)
        predictions += preds
        dev_loss += loss
        
    predictions = [id2label[p] for p in predictions]
    dev_p, dev_r, dev_f1 = scorer.score(dev_batch.gold(), predictions)
    
    train_loss = train_loss / train_batch.num_examples * opt['batch_size'] # avg loss per batch
    dev_loss = dev_loss / dev_batch.num_examples * opt['batch_size']
    print(
        "epoch {}: train_loss = {:.6f}, dev_loss = {:.6f}, dev_f1 = {:.4f}".format(epoch,\
            train_loss, dev_loss, dev_f1)
        )
    file_logger.log("{}\t{:.6f}\t{:.6f}\t{:.4f}".format(epoch, train_loss, dev_loss, dev_f1))

    # save
    model_file = model_save_dir + '/checkpoint_epoch_{}.pt'.format(epoch)
    model.save(model_file, epoch)
    if epoch == 1 or dev_f1 > max(dev_f1_history):
        copyfile(model_file, model_save_dir + '/best_model.pt')
        print("new best model saved.")
    if epoch % opt['save_epoch'] != 0:
        os.remove(model_file)
    
    # lr schedule
    if len(dev_f1_history) > 5 and dev_f1 <= dev_f1_history[-1] and opt['optim'] in ['sgd', 'adagrad', 'adam']:
        current_lr *= opt['lr_decay']
        model.update_lr(current_lr)

    dev_f1_history += [dev_f1]
    print("")

print("Training ended with {} epochs.".format(epoch))

# !!!!!!!! change the model output folder !!!!!!!!!!!
# Out:
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\modules\module.py:357: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   result = self.forward(*input, **kwargs)
# 2018-03-07 17:23:03.536819: step 400/150100 (epoch 1/100), loss = 0.904062 (0.119 sec/batch), lr: 0.300000
# 2018-03-07 17:23:56.922022: step 800/150100 (epoch 1/100), loss = 1.109297 (0.141 sec/batch), lr: 0.300000
# 2018-03-07 17:24:49.508465: step 1200/150100 (epoch 1/100), loss = 0.724443 (0.098 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3695.0 / guessed_by_relation= 10702.0
# Calculating Recall: correct_by_relation= 3695.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 34.526%
#    Recall (micro): 57.207%
#        F1 (micro): 43.063%
# epoch 1: train_loss = 1.073904, dev_loss = 0.896375, dev_f1 = 0.4306
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_1.pt
# new best model saved.
#
# 2018-03-07 17:26:07.009008: step 1600/150100 (epoch 2/100), loss = 0.599883 (0.144 sec/batch), lr: 0.300000
# 2018-03-07 17:27:01.875905: step 2000/150100 (epoch 2/100), loss = 0.743129 (0.143 sec/batch), lr: 0.300000
# 2018-03-07 17:27:55.560560: step 2400/150100 (epoch 2/100), loss = 0.629071 (0.133 sec/batch), lr: 0.300000
# 2018-03-07 17:28:47.273330: step 2800/150100 (epoch 2/100), loss = 0.739042 (0.133 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4451.0 / guessed_by_relation= 12518.0
# Calculating Recall: correct_by_relation= 4451.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 35.557%
#    Recall (micro): 68.912%
#        F1 (micro): 46.909%
# epoch 2: train_loss = 0.592074, dev_loss = 0.954708, dev_f1 = 0.4691
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_2.pt
# new best model saved.
#
# 2018-03-07 17:30:06.430025: step 3200/150100 (epoch 3/100), loss = 0.505050 (0.127 sec/batch), lr: 0.300000
# 2018-03-07 17:31:00.298368: step 3600/150100 (epoch 3/100), loss = 0.525999 (0.137 sec/batch), lr: 0.300000
# 2018-03-07 17:31:54.250913: step 4000/150100 (epoch 3/100), loss = 0.369167 (0.138 sec/batch), lr: 0.300000
# 2018-03-07 17:32:46.853625: step 4400/150100 (epoch 3/100), loss = 0.518793 (0.135 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4278.0 / guessed_by_relation= 11010.0
# Calculating Recall: correct_by_relation= 4278.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 38.856%
#    Recall (micro): 66.233%
#        F1 (micro): 48.978%
# epoch 3: train_loss = 0.534363, dev_loss = 0.829080, dev_f1 = 0.4898
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_3.pt
# new best model saved.
#
# 2018-03-07 17:34:04.539317: step 4800/150100 (epoch 4/100), loss = 0.359902 (0.119 sec/batch), lr: 0.300000
# 2018-03-07 17:34:58.332085: step 5200/150100 (epoch 4/100), loss = 0.647622 (0.118 sec/batch), lr: 0.300000
# 2018-03-07 17:35:51.894874: step 5600/150100 (epoch 4/100), loss = 0.876925 (0.132 sec/batch), lr: 0.300000
# 2018-03-07 17:36:59.521435: step 6000/150100 (epoch 4/100), loss = 0.288760 (0.143 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4617.0 / guessed_by_relation= 12113.0
# Calculating Recall: correct_by_relation= 4617.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 38.116%
#    Recall (micro): 71.482%
#        F1 (micro): 49.720%
# epoch 4: train_loss = 0.501534, dev_loss = 0.872581, dev_f1 = 0.4972
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_4.pt
# new best model saved.
#
# 2018-03-07 17:38:39.781278: step 6400/150100 (epoch 5/100), loss = 0.437074 (0.148 sec/batch), lr: 0.300000
# 2018-03-07 17:39:33.440020: step 6800/150100 (epoch 5/100), loss = 0.341312 (0.133 sec/batch), lr: 0.300000
# 2018-03-07 17:40:26.675230: step 7200/150100 (epoch 5/100), loss = 0.513632 (0.130 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4469.0 / guessed_by_relation= 10219.0
# Calculating Recall: correct_by_relation= 4469.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 43.732%
#    Recall (micro): 69.190%
#        F1 (micro): 53.592%
# epoch 5: train_loss = 0.470779, dev_loss = 0.757220, dev_f1 = 0.5359
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_5.pt
# new best model saved.
#
# 2018-03-07 17:41:42.931255: step 7600/150100 (epoch 6/100), loss = 0.461970 (0.138 sec/batch), lr: 0.300000
# 2018-03-07 17:42:36.765565: step 8000/150100 (epoch 6/100), loss = 0.298663 (0.134 sec/batch), lr: 0.300000
# 2018-03-07 17:43:30.383197: step 8400/150100 (epoch 6/100), loss = 0.574413 (0.135 sec/batch), lr: 0.300000
# 2018-03-07 17:44:23.151570: step 8800/150100 (epoch 6/100), loss = 0.482818 (0.117 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4776.0 / guessed_by_relation= 12017.0
# Calculating Recall: correct_by_relation= 4776.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 39.744%
#    Recall (micro): 73.943%
#        F1 (micro): 51.700%
# epoch 6: train_loss = 0.449327, dev_loss = 0.805732, dev_f1 = 0.5170
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_6.pt
#
# 2018-03-07 17:45:40.498483: step 9200/150100 (epoch 7/100), loss = 0.537997 (0.138 sec/batch), lr: 0.300000
# 2018-03-07 17:46:35.430847: step 9600/150100 (epoch 7/100), loss = 0.225000 (0.133 sec/batch), lr: 0.300000
# 2018-03-07 17:47:29.826004: step 10000/150100 (epoch 7/100), loss = 0.246118 (0.137 sec/batch), lr: 0.300000
# 2018-03-07 17:48:22.418910: step 10400/150100 (epoch 7/100), loss = 0.181713 (0.130 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4694.0 / guessed_by_relation= 11025.0
# Calculating Recall: correct_by_relation= 4694.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 42.576%
#    Recall (micro): 72.674%
#        F1 (micro): 53.695%
# epoch 7: train_loss = 0.432372, dev_loss = 0.716308, dev_f1 = 0.5369
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_7.pt
# new best model saved.
#
# 2018-03-07 17:49:04.714186: step 10800/150100 (epoch 8/100), loss = 0.331462 (0.071 sec/batch), lr: 0.300000
# 2018-03-07 17:49:31.995760: step 11200/150100 (epoch 8/100), loss = 0.601731 (0.072 sec/batch), lr: 0.300000
# 2018-03-07 17:49:59.280342: step 11600/150100 (epoch 8/100), loss = 0.474788 (0.072 sec/batch), lr: 0.300000
# 2018-03-07 17:50:26.794211: step 12000/150100 (epoch 8/100), loss = 0.210232 (0.060 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4709.0 / guessed_by_relation= 10741.0
# Calculating Recall: correct_by_relation= 4709.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 43.841%
#    Recall (micro): 72.906%
#        F1 (micro): 54.756%
# epoch 8: train_loss = 0.422655, dev_loss = 0.696110, dev_f1 = 0.5476
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_8.pt
# new best model saved.
#
# 2018-03-07 17:51:08.060879: step 12400/150100 (epoch 9/100), loss = 0.373540 (0.071 sec/batch), lr: 0.300000
# 2018-03-07 17:51:36.011636: step 12800/150100 (epoch 9/100), loss = 0.408459 (0.072 sec/batch), lr: 0.300000
# 2018-03-07 17:52:03.654008: step 13200/150100 (epoch 9/100), loss = 0.492180 (0.072 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4732.0 / guessed_by_relation= 10573.0
# Calculating Recall: correct_by_relation= 4732.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 44.756%
#    Recall (micro): 73.262%
#        F1 (micro): 55.566%
# epoch 9: train_loss = 0.412441, dev_loss = 0.676770, dev_f1 = 0.5557
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_9.pt
# new best model saved.
#
# 2018-03-07 17:52:44.341848: step 13600/150100 (epoch 10/100), loss = 0.472454 (0.066 sec/batch), lr: 0.300000
# 2018-03-07 17:53:11.772819: step 14000/150100 (epoch 10/100), loss = 0.479729 (0.076 sec/batch), lr: 0.300000
# 2018-03-07 17:53:39.472505: step 14400/150100 (epoch 10/100), loss = 0.322089 (0.071 sec/batch), lr: 0.300000
# 2018-03-07 17:54:07.805369: step 14800/150100 (epoch 10/100), loss = 0.515698 (0.063 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4781.0 / guessed_by_relation= 10973.0
# Calculating Recall: correct_by_relation= 4781.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 43.571%
#    Recall (micro): 74.021%
#        F1 (micro): 54.853%
# epoch 10: train_loss = 0.402678, dev_loss = 0.708095, dev_f1 = 0.5485
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_10.pt
#
# 2018-03-07 17:54:48.751292: step 15200/150100 (epoch 11/100), loss = 0.593369 (0.049 sec/batch), lr: 0.270000
# 2018-03-07 17:55:16.034871: step 15600/150100 (epoch 11/100), loss = 0.400766 (0.077 sec/batch), lr: 0.270000
# 2018-03-07 17:55:43.393650: step 16000/150100 (epoch 11/100), loss = 0.480044 (0.071 sec/batch), lr: 0.270000
# 2018-03-07 17:56:10.776493: step 16400/150100 (epoch 11/100), loss = 0.312387 (0.071 sec/batch), lr: 0.270000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4745.0 / guessed_by_relation= 10137.0
# Calculating Recall: correct_by_relation= 4745.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 46.809%
#    Recall (micro): 73.463%
#        F1 (micro): 57.182%
# epoch 11: train_loss = 0.389303, dev_loss = 0.654102, dev_f1 = 0.5718
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_11.pt
# new best model saved.
#
# 2018-03-07 17:56:51.582667: step 16800/150100 (epoch 12/100), loss = 0.659173 (0.065 sec/batch), lr: 0.270000
# 2018-03-07 17:57:19.408039: step 17200/150100 (epoch 12/100), loss = 0.315340 (0.062 sec/batch), lr: 0.270000
# 2018-03-07 17:57:47.416546: step 17600/150100 (epoch 12/100), loss = 0.407522 (0.063 sec/batch), lr: 0.270000
# 2018-03-07 17:58:15.160528: step 18000/150100 (epoch 12/100), loss = 0.313014 (0.072 sec/batch), lr: 0.270000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4721.0 / guessed_by_relation= 10507.0
# Calculating Recall: correct_by_relation= 4721.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 44.932%
#    Recall (micro): 73.092%
#        F1 (micro): 55.652%
# epoch 12: train_loss = 0.380956, dev_loss = 0.661288, dev_f1 = 0.5565
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_12.pt
#
# 2018-03-07 17:58:55.774079: step 18400/150100 (epoch 13/100), loss = 0.465130 (0.075 sec/batch), lr: 0.243000
# 2018-03-07 17:59:23.451698: step 18800/150100 (epoch 13/100), loss = 0.243769 (0.059 sec/batch), lr: 0.243000
# 2018-03-07 17:59:51.370773: step 19200/150100 (epoch 13/100), loss = 0.234770 (0.070 sec/batch), lr: 0.243000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4783.0 / guessed_by_relation= 10352.0
# Calculating Recall: correct_by_relation= 4783.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 46.204%
#    Recall (micro): 74.052%
#        F1 (micro): 56.903%
# epoch 13: train_loss = 0.369335, dev_loss = 0.655179, dev_f1 = 0.5690
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_13.pt
#
# 2018-03-07 18:00:32.533190: step 19600/150100 (epoch 14/100), loss = 0.286864 (0.052 sec/batch), lr: 0.243000
# 2018-03-07 18:01:00.236746: step 20000/150100 (epoch 14/100), loss = 0.364075 (0.077 sec/batch), lr: 0.243000
# 2018-03-07 18:01:27.879280: step 20400/150100 (epoch 14/100), loss = 0.413117 (0.075 sec/batch), lr: 0.243000
# 2018-03-07 18:01:55.383976: step 20800/150100 (epoch 14/100), loss = 0.282454 (0.062 sec/batch), lr: 0.243000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4692.0 / guessed_by_relation= 9588.0
# Calculating Recall: correct_by_relation= 4692.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 48.936%
#    Recall (micro): 72.643%
#        F1 (micro): 58.478%
# epoch 14: train_loss = 0.362383, dev_loss = 0.613478, dev_f1 = 0.5848
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_14.pt
# new best model saved.
#
# 2018-03-07 18:02:36.039905: step 21200/150100 (epoch 15/100), loss = 0.451900 (0.068 sec/batch), lr: 0.243000
# 2018-03-07 18:03:03.720541: step 21600/150100 (epoch 15/100), loss = 0.235666 (0.058 sec/batch), lr: 0.243000
# 2018-03-07 18:03:31.464344: step 22000/150100 (epoch 15/100), loss = 0.376940 (0.053 sec/batch), lr: 0.243000
# 2018-03-07 18:03:59.378530: step 22400/150100 (epoch 15/100), loss = 0.471092 (0.078 sec/batch), lr: 0.243000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4770.0 / guessed_by_relation= 10162.0
# Calculating Recall: correct_by_relation= 4770.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 46.940%
#    Recall (micro): 73.850%
#        F1 (micro): 57.397%
# epoch 15: train_loss = 0.357161, dev_loss = 0.653953, dev_f1 = 0.5740
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_15.pt
#
# 2018-03-07 18:04:42.304572: step 22800/150100 (epoch 16/100), loss = 0.268006 (0.062 sec/batch), lr: 0.218700
# 2018-03-07 18:05:09.582135: step 23200/150100 (epoch 16/100), loss = 0.466753 (0.068 sec/batch), lr: 0.218700
# 2018-03-07 18:05:36.906824: step 23600/150100 (epoch 16/100), loss = 0.335611 (0.058 sec/batch), lr: 0.218700
# 2018-03-07 18:06:04.389934: step 24000/150100 (epoch 16/100), loss = 0.275525 (0.073 sec/batch), lr: 0.218700
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4787.0 / guessed_by_relation= 10122.0
# Calculating Recall: correct_by_relation= 4787.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 47.293%
#    Recall (micro): 74.114%
#        F1 (micro): 57.741%
# epoch 16: train_loss = 0.346501, dev_loss = 0.656467, dev_f1 = 0.5774
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_16.pt
#
# 2018-03-07 18:06:45.079174: step 24400/150100 (epoch 17/100), loss = 0.306720 (0.066 sec/batch), lr: 0.218700
# 2018-03-07 18:07:12.461015: step 24800/150100 (epoch 17/100), loss = 0.394397 (0.072 sec/batch), lr: 0.218700
# 2018-03-07 18:07:39.738578: step 25200/150100 (epoch 17/100), loss = 0.257937 (0.056 sec/batch), lr: 0.218700
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4772.0 / guessed_by_relation= 10237.0
# Calculating Recall: correct_by_relation= 4772.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 46.615%
#    Recall (micro): 73.881%
#        F1 (micro): 57.163%
# epoch 17: train_loss = 0.342057, dev_loss = 0.653562, dev_f1 = 0.5716
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_17.pt
#
# 2018-03-07 18:08:20.417792: step 25600/150100 (epoch 18/100), loss = 0.224537 (0.075 sec/batch), lr: 0.196830
# 2018-03-07 18:08:47.852773: step 26000/150100 (epoch 18/100), loss = 0.243701 (0.061 sec/batch), lr: 0.196830
# 2018-03-07 18:09:15.237622: step 26400/150100 (epoch 18/100), loss = 0.384641 (0.063 sec/batch), lr: 0.196830
# 2018-03-07 18:09:42.577554: step 26800/150100 (epoch 18/100), loss = 0.408601 (0.056 sec/batch), lr: 0.196830
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4686.0 / guessed_by_relation= 9514.0
# Calculating Recall: correct_by_relation= 4686.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 49.254%
#    Recall (micro): 72.550%
#        F1 (micro): 58.674%
# epoch 18: train_loss = 0.330621, dev_loss = 0.610392, dev_f1 = 0.5867
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_18.pt
# new best model saved.
#
# 2018-03-07 18:10:23.488384: step 27200/150100 (epoch 19/100), loss = 0.414083 (0.060 sec/batch), lr: 0.196830
# 2018-03-07 18:10:50.802072: step 27600/150100 (epoch 19/100), loss = 0.170386 (0.052 sec/batch), lr: 0.196830
# 2018-03-07 18:11:18.193939: step 28000/150100 (epoch 19/100), loss = 0.131170 (0.061 sec/batch), lr: 0.196830
# 2018-03-07 18:11:45.574777: step 28400/150100 (epoch 19/100), loss = 0.290611 (0.061 sec/batch), lr: 0.196830
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4685.0 / guessed_by_relation= 9393.0
# Calculating Recall: correct_by_relation= 4685.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 49.878%
#    Recall (micro): 72.534%
#        F1 (micro): 59.109%
# epoch 19: train_loss = 0.324030, dev_loss = 0.626466, dev_f1 = 0.5911
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_19.pt
# new best model saved.
#
# 2018-03-07 18:12:26.329789: step 28800/150100 (epoch 20/100), loss = 0.525701 (0.053 sec/batch), lr: 0.196830
# 2018-03-07 18:12:53.644451: step 29200/150100 (epoch 20/100), loss = 0.241757 (0.072 sec/batch), lr: 0.196830
# 2018-03-07 18:13:21.000222: step 29600/150100 (epoch 20/100), loss = 0.265225 (0.051 sec/batch), lr: 0.196830
# 2018-03-07 18:13:48.472302: step 30000/150100 (epoch 20/100), loss = 0.279710 (0.065 sec/batch), lr: 0.196830
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4783.0 / guessed_by_relation= 10196.0
# Calculating Recall: correct_by_relation= 4783.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 46.911%
#    Recall (micro): 74.052%
#        F1 (micro): 57.436%
# epoch 20: train_loss = 0.319522, dev_loss = 0.671082, dev_f1 = 0.5744
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_20.pt
#
# 2018-03-07 18:14:29.190620: step 30400/150100 (epoch 21/100), loss = 0.309419 (0.073 sec/batch), lr: 0.177147
# 2018-03-07 18:14:56.604546: step 30800/150100 (epoch 21/100), loss = 0.228986 (0.074 sec/batch), lr: 0.177147
# 2018-03-07 18:15:23.951293: step 31200/150100 (epoch 21/100), loss = 0.238002 (0.073 sec/batch), lr: 0.177147
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4584.0 / guessed_by_relation= 9188.0
# Calculating Recall: correct_by_relation= 4584.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 49.891%
#    Recall (micro): 70.971%
#        F1 (micro): 58.593%
# epoch 21: train_loss = 0.310598, dev_loss = 0.624605, dev_f1 = 0.5859
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_21.pt
#
# 2018-03-07 18:16:04.597936: step 31600/150100 (epoch 22/100), loss = 0.325991 (0.060 sec/batch), lr: 0.177147
# 2018-03-07 18:16:32.006848: step 32000/150100 (epoch 22/100), loss = 0.198938 (0.069 sec/batch), lr: 0.177147
# 2018-03-07 18:16:59.418768: step 32400/150100 (epoch 22/100), loss = 0.302746 (0.060 sec/batch), lr: 0.177147
# 2018-03-07 18:17:26.769578: step 32800/150100 (epoch 22/100), loss = 0.258998 (0.061 sec/batch), lr: 0.177147
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4641.0 / guessed_by_relation= 9064.0
# Calculating Recall: correct_by_relation= 4641.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.203%
#    Recall (micro): 71.853%
#        F1 (micro): 59.795%
# epoch 22: train_loss = 0.304157, dev_loss = 0.622142, dev_f1 = 0.5980
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_22.pt
# new best model saved.
#
# 2018-03-07 18:18:07.629272: step 33200/150100 (epoch 23/100), loss = 0.168789 (0.064 sec/batch), lr: 0.177147
# 2018-03-07 18:18:34.943772: step 33600/150100 (epoch 23/100), loss = 0.304159 (0.074 sec/batch), lr: 0.177147
# 2018-03-07 18:19:02.311575: step 34000/150100 (epoch 23/100), loss = 0.423845 (0.070 sec/batch), lr: 0.177147
# 2018-03-07 18:19:29.643282: step 34400/150100 (epoch 23/100), loss = 0.106912 (0.075 sec/batch), lr: 0.177147
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4537.0 / guessed_by_relation= 8632.0
# Calculating Recall: correct_by_relation= 4537.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.560%
#    Recall (micro): 70.243%
#        F1 (micro): 60.129%
# epoch 23: train_loss = 0.301427, dev_loss = 0.598575, dev_f1 = 0.6013
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_23.pt
# new best model saved.
#
# 2018-03-07 18:20:10.454629: step 34800/150100 (epoch 24/100), loss = 0.564804 (0.071 sec/batch), lr: 0.177147
# 2018-03-07 18:20:37.738208: step 35200/150100 (epoch 24/100), loss = 0.263526 (0.071 sec/batch), lr: 0.177147
# 2018-03-07 18:21:05.127067: step 35600/150100 (epoch 24/100), loss = 0.238039 (0.067 sec/batch), lr: 0.177147
# 2018-03-07 18:21:32.591663: step 36000/150100 (epoch 24/100), loss = 0.384062 (0.063 sec/batch), lr: 0.177147
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4604.0 / guessed_by_relation= 9578.0
# Calculating Recall: correct_by_relation= 4604.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 48.068%
#    Recall (micro): 71.280%
#        F1 (micro): 57.417%
# epoch 24: train_loss = 0.294394, dev_loss = 0.688499, dev_f1 = 0.5742
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_24.pt
#
# 2018-03-07 18:22:13.184069: step 36400/150100 (epoch 25/100), loss = 0.270203 (0.067 sec/batch), lr: 0.159432
# 2018-03-07 18:22:40.572928: step 36800/150100 (epoch 25/100), loss = 0.280742 (0.074 sec/batch), lr: 0.159432
# 2018-03-07 18:23:07.900625: step 37200/150100 (epoch 25/100), loss = 0.183589 (0.073 sec/batch), lr: 0.159432
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4450.0 / guessed_by_relation= 8840.0
# Calculating Recall: correct_by_relation= 4450.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 50.339%
#    Recall (micro): 68.896%
#        F1 (micro): 58.174%
# epoch 25: train_loss = 0.283488, dev_loss = 0.650199, dev_f1 = 0.5817
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_25.pt
#
# 2018-03-07 18:23:48.570815: step 37600/150100 (epoch 26/100), loss = 0.269806 (0.061 sec/batch), lr: 0.159432
# 2018-03-07 18:24:15.987748: step 38000/150100 (epoch 26/100), loss = 0.180459 (0.058 sec/batch), lr: 0.159432
# 2018-03-07 18:24:43.349535: step 38400/150100 (epoch 26/100), loss = 0.210717 (0.066 sec/batch), lr: 0.159432
# 2018-03-07 18:25:10.501765: step 38800/150100 (epoch 26/100), loss = 0.240528 (0.074 sec/batch), lr: 0.159432
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4505.0 / guessed_by_relation= 8836.0
# Calculating Recall: correct_by_relation= 4505.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 50.985%
#    Recall (micro): 69.748%
#        F1 (micro): 58.908%
# epoch 26: train_loss = 0.279090, dev_loss = 0.658233, dev_f1 = 0.5891
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_26.pt
#
# 2018-03-07 18:25:51.251166: step 39200/150100 (epoch 27/100), loss = 0.091239 (0.068 sec/batch), lr: 0.159432
# 2018-03-07 18:26:18.398382: step 39600/150100 (epoch 27/100), loss = 0.410306 (0.062 sec/batch), lr: 0.159432
# 2018-03-07 18:26:45.544596: step 40000/150100 (epoch 27/100), loss = 0.374372 (0.058 sec/batch), lr: 0.159432
# 2018-03-07 18:27:12.722895: step 40400/150100 (epoch 27/100), loss = 0.335634 (0.074 sec/batch), lr: 0.159432
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4420.0 / guessed_by_relation= 8489.0
# Calculating Recall: correct_by_relation= 4420.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.067%
#    Recall (micro): 68.432%
#        F1 (micro): 59.138%
# epoch 27: train_loss = 0.274674, dev_loss = 0.636838, dev_f1 = 0.5914
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_27.pt
#
# 2018-03-07 18:27:53.381052: step 40800/150100 (epoch 28/100), loss = 0.375272 (0.062 sec/batch), lr: 0.159432
# 2018-03-07 18:28:20.413965: step 41200/150100 (epoch 28/100), loss = 0.238241 (0.070 sec/batch), lr: 0.159432
# 2018-03-07 18:28:47.970269: step 41600/150100 (epoch 28/100), loss = 0.156225 (0.070 sec/batch), lr: 0.159432
# 2018-03-07 18:29:15.411267: step 42000/150100 (epoch 28/100), loss = 0.330304 (0.074 sec/batch), lr: 0.159432
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4541.0 / guessed_by_relation= 9360.0
# Calculating Recall: correct_by_relation= 4541.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 48.515%
#    Recall (micro): 70.305%
#        F1 (micro): 57.412%
# epoch 28: train_loss = 0.270491, dev_loss = 0.700400, dev_f1 = 0.5741
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_28.pt
#
# 2018-03-07 18:29:56.188125: step 42400/150100 (epoch 29/100), loss = 0.332080 (0.057 sec/batch), lr: 0.143489
# 2018-03-07 18:30:23.575981: step 42800/150100 (epoch 29/100), loss = 0.338091 (0.067 sec/batch), lr: 0.143489
# 2018-03-07 18:30:50.855550: step 43200/150100 (epoch 29/100), loss = 0.155180 (0.073 sec/batch), lr: 0.143489
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4490.0 / guessed_by_relation= 9126.0
# Calculating Recall: correct_by_relation= 4490.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 49.200%
#    Recall (micro): 69.515%
#        F1 (micro): 57.620%
# epoch 29: train_loss = 0.262409, dev_loss = 0.682932, dev_f1 = 0.5762
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_29.pt
#
# 2018-03-07 18:31:31.654081: step 43600/150100 (epoch 30/100), loss = 0.158247 (0.056 sec/batch), lr: 0.143489
# 2018-03-07 18:31:59.094076: step 44000/150100 (epoch 30/100), loss = 0.373111 (0.059 sec/batch), lr: 0.143489
# 2018-03-07 18:32:26.467895: step 44400/150100 (epoch 30/100), loss = 0.318780 (0.062 sec/batch), lr: 0.143489
# 2018-03-07 18:32:53.775538: step 44800/150100 (epoch 30/100), loss = 0.382391 (0.070 sec/batch), lr: 0.143489
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4336.0 / guessed_by_relation= 8465.0
# Calculating Recall: correct_by_relation= 4336.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.223%
#    Recall (micro): 67.131%
#        F1 (micro): 58.108%
# epoch 30: train_loss = 0.256157, dev_loss = 0.662279, dev_f1 = 0.5811
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_30.pt
#
# 2018-03-07 18:33:34.756554: step 45200/150100 (epoch 31/100), loss = 0.203190 (0.075 sec/batch), lr: 0.143489
# 2018-03-07 18:34:02.065200: step 45600/150100 (epoch 31/100), loss = 0.290371 (0.073 sec/batch), lr: 0.143489
# 2018-03-07 18:34:29.446038: step 46000/150100 (epoch 31/100), loss = 0.254387 (0.071 sec/batch), lr: 0.143489
# 2018-03-07 18:34:56.810953: step 46400/150100 (epoch 31/100), loss = 0.115966 (0.072 sec/batch), lr: 0.143489
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4290.0 / guessed_by_relation= 8454.0
# Calculating Recall: correct_by_relation= 4290.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 50.745%
#    Recall (micro): 66.419%
#        F1 (micro): 57.534%
# epoch 31: train_loss = 0.249748, dev_loss = 0.700252, dev_f1 = 0.5753
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_31.pt
#
# 2018-03-07 18:35:37.763130: step 46800/150100 (epoch 32/100), loss = 0.105757 (0.075 sec/batch), lr: 0.129140
# 2018-03-07 18:36:05.008608: step 47200/150100 (epoch 32/100), loss = 0.500735 (0.070 sec/batch), lr: 0.129140
# 2018-03-07 18:36:32.387440: step 47600/150100 (epoch 32/100), loss = 0.242867 (0.073 sec/batch), lr: 0.129140
# 2018-03-07 18:36:59.833451: step 48000/150100 (epoch 32/100), loss = 0.083407 (0.074 sec/batch), lr: 0.129140
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4387.0 / guessed_by_relation= 8427.0
# Calculating Recall: correct_by_relation= 4387.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.059%
#    Recall (micro): 67.921%
#        F1 (micro): 58.941%
# epoch 32: train_loss = 0.239197, dev_loss = 0.670998, dev_f1 = 0.5894
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_32.pt
#
# 2018-03-07 18:37:40.552771: step 48400/150100 (epoch 33/100), loss = 0.221548 (0.053 sec/batch), lr: 0.129140
# 2018-03-07 18:38:07.913556: step 48800/150100 (epoch 33/100), loss = 0.386745 (0.069 sec/batch), lr: 0.129140
# 2018-03-07 18:38:35.235054: step 49200/150100 (epoch 33/100), loss = 0.291435 (0.075 sec/batch), lr: 0.129140
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4229.0 / guessed_by_relation= 7895.0
# Calculating Recall: correct_by_relation= 4229.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.566%
#    Recall (micro): 65.475%
#        F1 (micro): 58.924%
# epoch 33: train_loss = 0.237935, dev_loss = 0.681070, dev_f1 = 0.5892
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_33.pt
#
# 2018-03-07 18:39:16.041607: step 49600/150100 (epoch 34/100), loss = 0.406668 (0.058 sec/batch), lr: 0.116226
# 2018-03-07 18:39:43.469570: step 50000/150100 (epoch 34/100), loss = 0.192538 (0.067 sec/batch), lr: 0.116226
# 2018-03-07 18:40:10.853416: step 50400/150100 (epoch 34/100), loss = 0.183326 (0.054 sec/batch), lr: 0.116226
# 2018-03-07 18:40:38.157048: step 50800/150100 (epoch 34/100), loss = 0.159084 (0.074 sec/batch), lr: 0.116226
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4311.0 / guessed_by_relation= 8451.0
# Calculating Recall: correct_by_relation= 4311.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.012%
#    Recall (micro): 66.744%
#        F1 (micro): 57.827%
# epoch 34: train_loss = 0.226004, dev_loss = 0.736550, dev_f1 = 0.5783
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_34.pt
#
# 2018-03-07 18:41:19.027872: step 51200/150100 (epoch 35/100), loss = 0.159973 (0.075 sec/batch), lr: 0.104604
# 2018-03-07 18:41:46.335515: step 51600/150100 (epoch 35/100), loss = 0.115652 (0.073 sec/batch), lr: 0.104604
# 2018-03-07 18:42:13.727381: step 52000/150100 (epoch 35/100), loss = 0.229846 (0.059 sec/batch), lr: 0.104604
# 2018-03-07 18:42:41.059089: step 52400/150100 (epoch 35/100), loss = 0.094243 (0.071 sec/batch), lr: 0.104604
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4259.0 / guessed_by_relation= 8084.0
# Calculating Recall: correct_by_relation= 4259.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.684%
#    Recall (micro): 65.939%
#        F1 (micro): 58.571%
# epoch 35: train_loss = 0.215079, dev_loss = 0.699360, dev_f1 = 0.5857
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_35.pt
#
# 2018-03-07 18:43:21.954879: step 52800/150100 (epoch 36/100), loss = 0.222145 (0.053 sec/batch), lr: 0.104604
# 2018-03-07 18:43:49.313658: step 53200/150100 (epoch 36/100), loss = 0.122656 (0.071 sec/batch), lr: 0.104604
# 2018-03-07 18:44:16.515018: step 53600/150100 (epoch 36/100), loss = 0.262606 (0.052 sec/batch), lr: 0.104604
# 2018-03-07 18:44:43.763504: step 54000/150100 (epoch 36/100), loss = 0.248465 (0.064 sec/batch), lr: 0.104604
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4411.0 / guessed_by_relation= 8581.0
# Calculating Recall: correct_by_relation= 4411.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.404%
#    Recall (micro): 68.292%
#        F1 (micro): 58.657%
# epoch 36: train_loss = 0.213800, dev_loss = 0.728983, dev_f1 = 0.5866
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_36.pt
#
# 2018-03-07 18:45:24.271262: step 54400/150100 (epoch 37/100), loss = 0.241356 (0.071 sec/batch), lr: 0.104604
# 2018-03-07 18:45:51.407449: step 54800/150100 (epoch 37/100), loss = 0.103820 (0.062 sec/batch), lr: 0.104604
# 2018-03-07 18:46:18.511550: step 55200/150100 (epoch 37/100), loss = 0.399704 (0.057 sec/batch), lr: 0.104604
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4346.0 / guessed_by_relation= 8494.0
# Calculating Recall: correct_by_relation= 4346.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.166%
#    Recall (micro): 67.286%
#        F1 (micro): 58.129%
# epoch 37: train_loss = 0.205335, dev_loss = 0.758993, dev_f1 = 0.5813
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_37.pt
#
# 2018-03-07 18:46:59.010284: step 55600/150100 (epoch 38/100), loss = 0.107667 (0.059 sec/batch), lr: 0.094143
# 2018-03-07 18:47:26.284839: step 56000/150100 (epoch 38/100), loss = 0.206839 (0.063 sec/batch), lr: 0.094143
# 2018-03-07 18:47:53.513271: step 56400/150100 (epoch 38/100), loss = 0.278764 (0.064 sec/batch), lr: 0.094143
# 2018-03-07 18:48:20.628402: step 56800/150100 (epoch 38/100), loss = 0.130014 (0.075 sec/batch), lr: 0.094143
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4232.0 / guessed_by_relation= 7757.0
# Calculating Recall: correct_by_relation= 4232.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.557%
#    Recall (micro): 65.521%
#        F1 (micro): 59.539%
# epoch 38: train_loss = 0.199577, dev_loss = 0.729925, dev_f1 = 0.5954
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_38.pt
#
# 2018-03-07 18:49:01.313632: step 57200/150100 (epoch 39/100), loss = 0.124160 (0.070 sec/batch), lr: 0.094143
# 2018-03-07 18:49:28.416731: step 57600/150100 (epoch 39/100), loss = 0.325594 (0.071 sec/batch), lr: 0.094143
# 2018-03-07 18:49:55.656193: step 58000/150100 (epoch 39/100), loss = 0.234963 (0.064 sec/batch), lr: 0.094143
# 2018-03-07 18:50:22.790374: step 58400/150100 (epoch 39/100), loss = 0.056850 (0.064 sec/batch), lr: 0.094143
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4294.0 / guessed_by_relation= 8407.0
# Calculating Recall: correct_by_relation= 4294.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.076%
#    Recall (micro): 66.481%
#        F1 (micro): 57.769%
# epoch 39: train_loss = 0.194980, dev_loss = 0.771788, dev_f1 = 0.5777
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_39.pt
#
# 2018-03-07 18:51:03.456553: step 58800/150100 (epoch 40/100), loss = 0.156814 (0.063 sec/batch), lr: 0.084729
# 2018-03-07 18:51:30.477434: step 59200/150100 (epoch 40/100), loss = 0.180698 (0.053 sec/batch), lr: 0.084729
# 2018-03-07 18:51:58.013685: step 59600/150100 (epoch 40/100), loss = 0.298421 (0.058 sec/batch), lr: 0.084729
# 2018-03-07 18:52:25.427611: step 60000/150100 (epoch 40/100), loss = 0.319110 (0.066 sec/batch), lr: 0.084729
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4244.0 / guessed_by_relation= 8255.0
# Calculating Recall: correct_by_relation= 4244.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.411%
#    Recall (micro): 65.707%
#        F1 (micro): 57.687%
# epoch 40: train_loss = 0.186381, dev_loss = 0.761467, dev_f1 = 0.5769
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_40.pt
#
# 2018-03-07 18:53:05.688712: step 60400/150100 (epoch 41/100), loss = 0.107733 (0.064 sec/batch), lr: 0.076256
# 2018-03-07 18:53:33.046489: step 60800/150100 (epoch 41/100), loss = 0.173339 (0.073 sec/batch), lr: 0.076256
# 2018-03-07 18:54:00.344105: step 61200/150100 (epoch 41/100), loss = 0.204206 (0.075 sec/batch), lr: 0.076256
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4116.0 / guessed_by_relation= 7738.0
# Calculating Recall: correct_by_relation= 4116.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.192%
#    Recall (micro): 63.725%
#        F1 (micro): 57.984%
# epoch 41: train_loss = 0.178176, dev_loss = 0.755538, dev_f1 = 0.5798
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_41.pt
#
# 2018-03-07 18:54:40.680407: step 61600/150100 (epoch 42/100), loss = 0.083143 (0.072 sec/batch), lr: 0.076256
# 2018-03-07 18:55:08.131431: step 62000/150100 (epoch 42/100), loss = 0.325443 (0.062 sec/batch), lr: 0.076256
# 2018-03-07 18:55:35.539341: step 62400/150100 (epoch 42/100), loss = 0.150365 (0.059 sec/batch), lr: 0.076256
# 2018-03-07 18:56:02.790835: step 62800/150100 (epoch 42/100), loss = 0.122224 (0.066 sec/batch), lr: 0.076256
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4351.0 / guessed_by_relation= 8529.0
# Calculating Recall: correct_by_relation= 4351.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.014%
#    Recall (micro): 67.363%
#        F1 (micro): 58.060%
# epoch 42: train_loss = 0.173091, dev_loss = 0.794768, dev_f1 = 0.5806
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_42.pt
#
# 2018-03-07 18:56:43.334688: step 63200/150100 (epoch 43/100), loss = 0.236068 (0.068 sec/batch), lr: 0.076256
# 2018-03-07 18:57:10.665393: step 63600/150100 (epoch 43/100), loss = 0.103760 (0.073 sec/batch), lr: 0.076256
# 2018-03-07 18:57:38.099372: step 64000/150100 (epoch 43/100), loss = 0.246513 (0.076 sec/batch), lr: 0.076256
# 2018-03-07 18:58:05.417042: step 64400/150100 (epoch 43/100), loss = 0.059742 (0.075 sec/batch), lr: 0.076256
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4246.0 / guessed_by_relation= 8331.0
# Calculating Recall: correct_by_relation= 4246.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 50.966%
#    Recall (micro): 65.738%
#        F1 (micro): 57.417%
# epoch 43: train_loss = 0.170108, dev_loss = 0.806810, dev_f1 = 0.5742
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_43.pt
#
# 2018-03-07 18:58:46.070542: step 64800/150100 (epoch 44/100), loss = 0.160766 (0.072 sec/batch), lr: 0.068630
# 2018-03-07 18:59:13.380176: step 65200/150100 (epoch 44/100), loss = 0.102190 (0.069 sec/batch), lr: 0.068630
# 2018-03-07 18:59:40.747979: step 65600/150100 (epoch 44/100), loss = 0.151170 (0.067 sec/batch), lr: 0.068630
# 2018-03-07 19:00:08.156892: step 66000/150100 (epoch 44/100), loss = 0.239434 (0.056 sec/batch), lr: 0.068630
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4053.0 / guessed_by_relation= 7418.0
# Calculating Recall: correct_by_relation= 4053.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.637%
#    Recall (micro): 62.750%
#        F1 (micro): 58.413%
# epoch 44: train_loss = 0.164398, dev_loss = 0.781536, dev_f1 = 0.5841
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_44.pt
#
# 2018-03-07 19:00:48.961637: step 66400/150100 (epoch 45/100), loss = 0.282167 (0.074 sec/batch), lr: 0.068630
# 2018-03-07 19:01:16.283316: step 66800/150100 (epoch 45/100), loss = 0.072705 (0.065 sec/batch), lr: 0.068630
# 2018-03-07 19:01:43.654128: step 67200/150100 (epoch 45/100), loss = 0.182598 (0.053 sec/batch), lr: 0.068630
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4262.0 / guessed_by_relation= 8347.0
# Calculating Recall: correct_by_relation= 4262.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 51.060%
#    Recall (micro): 65.985%
#        F1 (micro): 57.571%
# epoch 45: train_loss = 0.159474, dev_loss = 0.834762, dev_f1 = 0.5757
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_45.pt
#
# 2018-03-07 19:02:24.537885: step 67600/150100 (epoch 46/100), loss = 0.225509 (0.075 sec/batch), lr: 0.061767
# 2018-03-07 19:02:51.979886: step 68000/150100 (epoch 46/100), loss = 0.312533 (0.054 sec/batch), lr: 0.061767
# 2018-03-07 19:03:19.420136: step 68400/150100 (epoch 46/100), loss = 0.296589 (0.059 sec/batch), lr: 0.061767
# 2018-03-07 19:03:46.683661: step 68800/150100 (epoch 46/100), loss = 0.146145 (0.057 sec/batch), lr: 0.061767
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4125.0 / guessed_by_relation= 7687.0
# Calculating Recall: correct_by_relation= 4125.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.662%
#    Recall (micro): 63.864%
#        F1 (micro): 58.320%
# epoch 46: train_loss = 0.153101, dev_loss = 0.808071, dev_f1 = 0.5832
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_46.pt
#
# 2018-03-07 19:04:27.749904: step 69200/150100 (epoch 47/100), loss = 0.177285 (0.066 sec/batch), lr: 0.061767
# 2018-03-07 19:04:55.047521: step 69600/150100 (epoch 47/100), loss = 0.113245 (0.071 sec/batch), lr: 0.061767
# 2018-03-07 19:05:22.476487: step 70000/150100 (epoch 47/100), loss = 0.201694 (0.060 sec/batch), lr: 0.061767
# 2018-03-07 19:05:49.811202: step 70400/150100 (epoch 47/100), loss = 0.081236 (0.066 sec/batch), lr: 0.061767
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4059.0 / guessed_by_relation= 7603.0
# Calculating Recall: correct_by_relation= 4059.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.387%
#    Recall (micro): 62.843%
#        F1 (micro): 57.730%
# epoch 47: train_loss = 0.151429, dev_loss = 0.846166, dev_f1 = 0.5773
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_47.pt
#
# 2018-03-07 19:06:30.916531: step 70800/150100 (epoch 48/100), loss = 0.305066 (0.062 sec/batch), lr: 0.055591
# 2018-03-07 19:06:58.193091: step 71200/150100 (epoch 48/100), loss = 0.192129 (0.073 sec/batch), lr: 0.055591
# 2018-03-07 19:07:25.425534: step 71600/150100 (epoch 48/100), loss = 0.036405 (0.073 sec/batch), lr: 0.055591
# 2018-03-07 19:07:52.647951: step 72000/150100 (epoch 48/100), loss = 0.139062 (0.058 sec/batch), lr: 0.055591
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4104.0 / guessed_by_relation= 7722.0
# Calculating Recall: correct_by_relation= 4104.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.147%
#    Recall (micro): 63.539%
#        F1 (micro): 57.880%
# epoch 48: train_loss = 0.142822, dev_loss = 0.844074, dev_f1 = 0.5788
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_48.pt
#
# 2018-03-07 19:08:33.182780: step 72400/150100 (epoch 49/100), loss = 0.052435 (0.055 sec/batch), lr: 0.055591
# 2018-03-07 19:09:00.282871: step 72800/150100 (epoch 49/100), loss = 0.322686 (0.074 sec/batch), lr: 0.055591
# 2018-03-07 19:09:27.483229: step 73200/150100 (epoch 49/100), loss = 0.170164 (0.059 sec/batch), lr: 0.055591
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4091.0 / guessed_by_relation= 7686.0
# Calculating Recall: correct_by_relation= 4091.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.227%
#    Recall (micro): 63.338%
#        F1 (micro): 57.844%
# epoch 49: train_loss = 0.140469, dev_loss = 0.830193, dev_f1 = 0.5784
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_49.pt
#
# 2018-03-07 19:10:08.111307: step 73600/150100 (epoch 50/100), loss = 0.150090 (0.072 sec/batch), lr: 0.050032
# 2018-03-07 19:10:35.360795: step 74000/150100 (epoch 50/100), loss = 0.118544 (0.061 sec/batch), lr: 0.050032
# 2018-03-07 19:11:02.621312: step 74400/150100 (epoch 50/100), loss = 0.161007 (0.076 sec/batch), lr: 0.050032
# 2018-03-07 19:11:29.686310: step 74800/150100 (epoch 50/100), loss = 0.087539 (0.066 sec/batch), lr: 0.050032
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3989.0 / guessed_by_relation= 7304.0
# Calculating Recall: correct_by_relation= 3989.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.614%
#    Recall (micro): 61.759%
#        F1 (micro): 57.967%
# epoch 50: train_loss = 0.135308, dev_loss = 0.836664, dev_f1 = 0.5797
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_50.pt
#
# 2018-03-07 19:12:10.424681: step 75200/150100 (epoch 51/100), loss = 0.105717 (0.068 sec/batch), lr: 0.050032
# 2018-03-07 19:12:37.521764: step 75600/150100 (epoch 51/100), loss = 0.132639 (0.072 sec/batch), lr: 0.050032
# 2018-03-07 19:13:04.768244: step 76000/150100 (epoch 51/100), loss = 0.197607 (0.073 sec/batch), lr: 0.050032
# 2018-03-07 19:13:31.915461: step 76400/150100 (epoch 51/100), loss = 0.067713 (0.065 sec/batch), lr: 0.050032
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3937.0 / guessed_by_relation= 7209.0
# Calculating Recall: correct_by_relation= 3937.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.612%
#    Recall (micro): 60.954%
#        F1 (micro): 57.609%
# epoch 51: train_loss = 0.130545, dev_loss = 0.866811, dev_f1 = 0.5761
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_51.pt
#
# 2018-03-07 19:14:12.684915: step 76800/150100 (epoch 52/100), loss = 0.160887 (0.069 sec/batch), lr: 0.045028
# 2018-03-07 19:14:39.777987: step 77200/150100 (epoch 52/100), loss = 0.078665 (0.053 sec/batch), lr: 0.045028
# 2018-03-07 19:15:07.026473: step 77600/150100 (epoch 52/100), loss = 0.141068 (0.062 sec/batch), lr: 0.045028
# 2018-03-07 19:15:34.272953: step 78000/150100 (epoch 52/100), loss = 0.143803 (0.074 sec/batch), lr: 0.045028
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4114.0 / guessed_by_relation= 7710.0
# Calculating Recall: correct_by_relation= 4114.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.359%
#    Recall (micro): 63.694%
#        F1 (micro): 58.070%
# epoch 52: train_loss = 0.128223, dev_loss = 0.900077, dev_f1 = 0.5807
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_52.pt
#
# 2018-03-07 19:16:14.992274: step 78400/150100 (epoch 53/100), loss = 0.101894 (0.066 sec/batch), lr: 0.045028
# 2018-03-07 19:16:42.119437: step 78800/150100 (epoch 53/100), loss = 0.187800 (0.071 sec/batch), lr: 0.045028
# 2018-03-07 19:17:09.367922: step 79200/150100 (epoch 53/100), loss = 0.143976 (0.070 sec/batch), lr: 0.045028
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4112.0 / guessed_by_relation= 7788.0
# Calculating Recall: correct_by_relation= 4112.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.799%
#    Recall (micro): 63.663%
#        F1 (micro): 57.724%
# epoch 53: train_loss = 0.124639, dev_loss = 0.913488, dev_f1 = 0.5772
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_53.pt
#
# 2018-03-07 19:17:50.017056: step 79600/150100 (epoch 54/100), loss = 0.012436 (0.071 sec/batch), lr: 0.040526
# 2018-03-07 19:18:17.316678: step 80000/150100 (epoch 54/100), loss = 0.071631 (0.057 sec/batch), lr: 0.040526
# 2018-03-07 19:18:44.537089: step 80400/150100 (epoch 54/100), loss = 0.190119 (0.065 sec/batch), lr: 0.040526
# 2018-03-07 19:19:11.632167: step 80800/150100 (epoch 54/100), loss = 0.032297 (0.071 sec/batch), lr: 0.040526
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3989.0 / guessed_by_relation= 7303.0
# Calculating Recall: correct_by_relation= 3989.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.621%
#    Recall (micro): 61.759%
#        F1 (micro): 57.971%
# epoch 54: train_loss = 0.120606, dev_loss = 0.868416, dev_f1 = 0.5797
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_54.pt
#
# 2018-03-07 19:19:52.660308: step 81200/150100 (epoch 55/100), loss = 0.184453 (0.053 sec/batch), lr: 0.040526
# 2018-03-07 19:20:19.825573: step 81600/150100 (epoch 55/100), loss = 0.194411 (0.071 sec/batch), lr: 0.040526
# 2018-03-07 19:20:47.098122: step 82000/150100 (epoch 55/100), loss = 0.101397 (0.074 sec/batch), lr: 0.040526
# 2018-03-07 19:21:14.233307: step 82400/150100 (epoch 55/100), loss = 0.095131 (0.063 sec/batch), lr: 0.040526
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4056.0 / guessed_by_relation= 7521.0
# Calculating Recall: correct_by_relation= 4056.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.929%
#    Recall (micro): 62.796%
#        F1 (micro): 58.026%
# epoch 55: train_loss = 0.118841, dev_loss = 0.888741, dev_f1 = 0.5803
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_55.pt
#
# 2018-03-07 19:21:55.021811: step 82800/150100 (epoch 56/100), loss = 0.063284 (0.063 sec/batch), lr: 0.040526
# 2018-03-07 19:22:22.073774: step 83200/150100 (epoch 56/100), loss = 0.055259 (0.069 sec/batch), lr: 0.040526
# 2018-03-07 19:22:49.283156: step 83600/150100 (epoch 56/100), loss = 0.109319 (0.060 sec/batch), lr: 0.040526
# 2018-03-07 19:23:16.527631: step 84000/150100 (epoch 56/100), loss = 0.163028 (0.058 sec/batch), lr: 0.040526
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4083.0 / guessed_by_relation= 7591.0
# Calculating Recall: correct_by_relation= 4083.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.787%
#    Recall (micro): 63.214%
#        F1 (micro): 58.121%
# ...
# 2018-03-07 19:32:05.448653: step 90800/150100 (epoch 61/100), loss = 0.031769 (0.068 sec/batch), lr: 0.032826
# 2018-03-07 19:32:32.625949: step 91200/150100 (epoch 61/100), loss = 0.066366 (0.067 sec/batch), lr: 0.032826
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3988.0 / guessed_by_relation= 7509.0
# Calculating Recall: correct_by_relation= 3988.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.110%
#    Recall (micro): 61.743%
#        F1 (micro): 57.102%
# epoch 61: train_loss = 0.105901, dev_loss = 0.931089, dev_f1 = 0.5710
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_61.pt
#
# 2018-03-07 19:33:13.151754: step 91600/150100 (epoch 62/100), loss = 0.134115 (0.065 sec/batch), lr: 0.029543
# 2018-03-07 19:33:40.429318: step 92000/150100 (epoch 62/100), loss = 0.070282 (0.072 sec/batch), lr: 0.029543
# 2018-03-07 19:34:07.651735: step 92400/150100 (epoch 62/100), loss = 0.119959 (0.075 sec/batch), lr: 0.029543
# 2018-03-07 19:34:34.710716: step 92800/150100 (epoch 62/100), loss = 0.100805 (0.072 sec/batch), lr: 0.029543
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4019.0 / guessed_by_relation= 7423.0
# Calculating Recall: correct_by_relation= 4019.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.143%
#    Recall (micro): 62.223%
#        F1 (micro): 57.902%
# epoch 62: train_loss = 0.101677, dev_loss = 0.944364, dev_f1 = 0.5790
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_62.pt
#
# 2018-03-07 19:35:14.878569: step 93200/150100 (epoch 63/100), loss = 0.106781 (0.072 sec/batch), lr: 0.029543
# 2018-03-07 19:35:42.010746: step 93600/150100 (epoch 63/100), loss = 0.043892 (0.052 sec/batch), lr: 0.029543
# 2018-03-07 19:36:09.280287: step 94000/150100 (epoch 63/100), loss = 0.238764 (0.072 sec/batch), lr: 0.029543
# 2018-03-07 19:36:36.412463: step 94400/150100 (epoch 63/100), loss = 0.052644 (0.065 sec/batch), lr: 0.029543
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4023.0 / guessed_by_relation= 7417.0
# Calculating Recall: correct_by_relation= 4023.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.240%
#    Recall (micro): 62.285%
#        F1 (micro): 57.985%
# epoch 63: train_loss = 0.100396, dev_loss = 0.937990, dev_f1 = 0.5799
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_63.pt
#
# 2018-03-07 19:37:16.506120: step 94800/150100 (epoch 64/100), loss = 0.082217 (0.065 sec/batch), lr: 0.029543
# 2018-03-07 19:37:43.605208: step 95200/150100 (epoch 64/100), loss = 0.089391 (0.060 sec/batch), lr: 0.029543
# 2018-03-07 19:38:10.839656: step 95600/150100 (epoch 64/100), loss = 0.073950 (0.067 sec/batch), lr: 0.029543
# 2018-03-07 19:38:38.112206: step 96000/150100 (epoch 64/100), loss = 0.036340 (0.069 sec/batch), lr: 0.029543
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4107.0 / guessed_by_relation= 7659.0
# Calculating Recall: correct_by_relation= 4107.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.623%
#    Recall (micro): 63.586%
#        F1 (micro): 58.181%
# epoch 64: train_loss = 0.096752, dev_loss = 0.956138, dev_f1 = 0.5818
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_64.pt
#
# 2018-03-07 19:39:18.623974: step 96400/150100 (epoch 65/100), loss = 0.056595 (0.059 sec/batch), lr: 0.029543
# 2018-03-07 19:39:45.836365: step 96800/150100 (epoch 65/100), loss = 0.041591 (0.070 sec/batch), lr: 0.029543
# 2018-03-07 19:40:13.041735: step 97200/150100 (epoch 65/100), loss = 0.035216 (0.064 sec/batch), lr: 0.029543
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4115.0 / guessed_by_relation= 7771.0
# Calculating Recall: correct_by_relation= 4115.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.953%
#    Recall (micro): 63.710%
#        F1 (micro): 57.836%
# epoch 65: train_loss = 0.097890, dev_loss = 0.965975, dev_f1 = 0.5784
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_65.pt
#
# 2018-03-07 19:40:52.983988: step 97600/150100 (epoch 66/100), loss = 0.326914 (0.072 sec/batch), lr: 0.026589
# 2018-03-07 19:41:20.295642: step 98000/150100 (epoch 66/100), loss = 0.040633 (0.065 sec/batch), lr: 0.026589
# 2018-03-07 19:41:47.563178: step 98400/150100 (epoch 66/100), loss = 0.051622 (0.063 sec/batch), lr: 0.026589
# 2018-03-07 19:42:14.621157: step 98800/150100 (epoch 66/100), loss = 0.032992 (0.053 sec/batch), lr: 0.026589
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4069.0 / guessed_by_relation= 7321.0
# Calculating Recall: correct_by_relation= 4069.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.580%
#    Recall (micro): 62.997%
#        F1 (micro): 59.057%
# epoch 66: train_loss = 0.095026, dev_loss = 0.945245, dev_f1 = 0.5906
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_66.pt
#
# 2018-03-07 19:42:54.567421: step 99200/150100 (epoch 67/100), loss = 0.135134 (0.055 sec/batch), lr: 0.026589
# 2018-03-07 19:43:21.769784: step 99600/150100 (epoch 67/100), loss = 0.203089 (0.059 sec/batch), lr: 0.026589
# 2018-03-07 19:43:49.006238: step 100000/150100 (epoch 67/100), loss = 0.055471 (0.070 sec/batch), lr: 0.026589
# 2018-03-07 19:44:16.147438: step 100400/150100 (epoch 67/100), loss = 0.088051 (0.074 sec/batch), lr: 0.026589
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4206.0 / guessed_by_relation= 7861.0
# Calculating Recall: correct_by_relation= 4206.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.505%
#    Recall (micro): 65.118%
#        F1 (micro): 58.743%
# epoch 67: train_loss = 0.094457, dev_loss = 0.957132, dev_f1 = 0.5874
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_67.pt
#
# 2018-03-07 19:44:56.214022: step 100800/150100 (epoch 68/100), loss = 0.058197 (0.066 sec/batch), lr: 0.023930
# 2018-03-07 19:45:23.317121: step 101200/150100 (epoch 68/100), loss = 0.183035 (0.056 sec/batch), lr: 0.023930
# 2018-03-07 19:45:50.515474: step 101600/150100 (epoch 68/100), loss = 0.046845 (0.060 sec/batch), lr: 0.023930
# 2018-03-07 19:46:17.781005: step 102000/150100 (epoch 68/100), loss = 0.051855 (0.061 sec/batch), lr: 0.023930
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4095.0 / guessed_by_relation= 7478.0
# Calculating Recall: correct_by_relation= 4095.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.761%
#    Recall (micro): 63.400%
#        F1 (micro): 58.764%
# epoch 68: train_loss = 0.094189, dev_loss = 0.960951, dev_f1 = 0.5876
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_68.pt
#
# 2018-03-07 19:46:58.168442: step 102400/150100 (epoch 69/100), loss = 0.062525 (0.059 sec/batch), lr: 0.023930
# 2018-03-07 19:47:25.359777: step 102800/150100 (epoch 69/100), loss = 0.103538 (0.065 sec/batch), lr: 0.023930
# 2018-03-07 19:47:52.535067: step 103200/150100 (epoch 69/100), loss = 0.027739 (0.060 sec/batch), lr: 0.023930
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4091.0 / guessed_by_relation= 7556.0
# Calculating Recall: correct_by_relation= 4091.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.142%
#    Recall (micro): 63.338%
#        F1 (micro): 58.380%
# epoch 69: train_loss = 0.091895, dev_loss = 0.978731, dev_f1 = 0.5838
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_69.pt
#
# 2018-03-07 19:48:32.983667: step 103600/150100 (epoch 70/100), loss = 0.082660 (0.072 sec/batch), lr: 0.021537
# 2018-03-07 19:49:00.300334: step 104000/150100 (epoch 70/100), loss = 0.277458 (0.073 sec/batch), lr: 0.021537
# 2018-03-07 19:49:27.585919: step 104400/150100 (epoch 70/100), loss = 0.094509 (0.070 sec/batch), lr: 0.021537
# 2018-03-07 19:49:54.645903: step 104800/150100 (epoch 70/100), loss = 0.064598 (0.066 sec/batch), lr: 0.021537
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4100.0 / guessed_by_relation= 7531.0
# Calculating Recall: correct_by_relation= 4100.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.442%
#    Recall (micro): 63.477%
#        F1 (micro): 58.613%
# epoch 70: train_loss = 0.090727, dev_loss = 0.977877, dev_f1 = 0.5861
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_70.pt
#
# 2018-03-07 19:50:35.340157: step 105200/150100 (epoch 71/100), loss = 0.065861 (0.075 sec/batch), lr: 0.021537
# 2018-03-07 19:51:02.518456: step 105600/150100 (epoch 71/100), loss = 0.080164 (0.071 sec/batch), lr: 0.021537
# 2018-03-07 19:51:29.765939: step 106000/150100 (epoch 71/100), loss = 0.106963 (0.065 sec/batch), lr: 0.021537
# 2018-03-07 19:51:56.889092: step 106400/150100 (epoch 71/100), loss = 0.057110 (0.070 sec/batch), lr: 0.021537
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4086.0 / guessed_by_relation= 7643.0
# Calculating Recall: correct_by_relation= 4086.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.461%
#    Recall (micro): 63.261%
#        F1 (micro): 57.949%
# epoch 71: train_loss = 0.089174, dev_loss = 1.014800, dev_f1 = 0.5795
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_71.pt
#
# 2018-03-07 19:52:37.502129: step 106800/150100 (epoch 72/100), loss = 0.031228 (0.073 sec/batch), lr: 0.019383
# 2018-03-07 19:53:04.604226: step 107200/150100 (epoch 72/100), loss = 0.059248 (0.069 sec/batch), lr: 0.019383
# 2018-03-07 19:53:31.817618: step 107600/150100 (epoch 72/100), loss = 0.008957 (0.060 sec/batch), lr: 0.019383
# 2018-03-07 19:53:59.110221: step 108000/150100 (epoch 72/100), loss = 0.062466 (0.062 sec/batch), lr: 0.019383
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4084.0 / guessed_by_relation= 7413.0
# Calculating Recall: correct_by_relation= 4084.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.092%
#    Recall (micro): 63.230%
#        F1 (micro): 58.881%
# epoch 72: train_loss = 0.086574, dev_loss = 1.003600, dev_f1 = 0.5888
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_72.pt
#
# 2018-03-07 19:54:39.595920: step 108400/150100 (epoch 73/100), loss = 0.125278 (0.058 sec/batch), lr: 0.019383
# 2018-03-07 19:55:06.782240: step 108800/150100 (epoch 73/100), loss = 0.040270 (0.069 sec/batch), lr: 0.019383
# 2018-03-07 19:55:33.966555: step 109200/150100 (epoch 73/100), loss = 0.112382 (0.070 sec/batch), lr: 0.019383
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4106.0 / guessed_by_relation= 7556.0
# Calculating Recall: correct_by_relation= 4106.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.341%
#    Recall (micro): 63.570%
#        F1 (micro): 58.594%
# epoch 73: train_loss = 0.086527, dev_loss = 1.009262, dev_f1 = 0.5859
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_73.pt
#
# 2018-03-07 19:56:14.333939: step 109600/150100 (epoch 74/100), loss = 0.052113 (0.061 sec/batch), lr: 0.017445
# 2018-03-07 19:56:41.659631: step 110000/150100 (epoch 74/100), loss = 0.026415 (0.067 sec/batch), lr: 0.017445
# 2018-03-07 19:57:08.951231: step 110400/150100 (epoch 74/100), loss = 0.052640 (0.073 sec/batch), lr: 0.017445
# 2018-03-07 19:57:36.046308: step 110800/150100 (epoch 74/100), loss = 0.044625 (0.068 sec/batch), lr: 0.017445
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4085.0 / guessed_by_relation= 7478.0
# Calculating Recall: correct_by_relation= 4085.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.627%
#    Recall (micro): 63.245%
#        F1 (micro): 58.621%
# epoch 74: train_loss = 0.086000, dev_loss = 1.007246, dev_f1 = 0.5862
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_74.pt
#
# 2018-03-07 19:58:16.526994: step 111200/150100 (epoch 75/100), loss = 0.038707 (0.071 sec/batch), lr: 0.017445
# 2018-03-07 19:58:43.737378: step 111600/150100 (epoch 75/100), loss = 0.110142 (0.071 sec/batch), lr: 0.017445
# 2018-03-07 19:59:11.006920: step 112000/150100 (epoch 75/100), loss = 0.106459 (0.062 sec/batch), lr: 0.017445
# 2018-03-07 19:59:38.132078: step 112400/150100 (epoch 75/100), loss = 0.133906 (0.066 sec/batch), lr: 0.017445
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4078.0 / guessed_by_relation= 7578.0
# Calculating Recall: correct_by_relation= 4078.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.814%
#    Recall (micro): 63.137%
#        F1 (micro): 58.104%
# epoch 75: train_loss = 0.084997, dev_loss = 1.021922, dev_f1 = 0.5810
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_75.pt
#
# 2018-03-07 20:00:18.767174: step 112800/150100 (epoch 76/100), loss = 0.259195 (0.068 sec/batch), lr: 0.015700
# 2018-03-07 20:00:45.923415: step 113200/150100 (epoch 76/100), loss = 0.117428 (0.066 sec/batch), lr: 0.015700
# 2018-03-07 20:01:13.141820: step 113600/150100 (epoch 76/100), loss = 0.054693 (0.072 sec/batch), lr: 0.015700
# 2018-03-07 20:01:40.441442: step 114000/150100 (epoch 76/100), loss = 0.082777 (0.069 sec/batch), lr: 0.015700
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4057.0 / guessed_by_relation= 7354.0
# Calculating Recall: correct_by_relation= 4057.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.167%
#    Recall (micro): 62.812%
#        F1 (micro): 58.742%
# epoch 76: train_loss = 0.082594, dev_loss = 1.000106, dev_f1 = 0.5874
# model saved to ./saved_models/18_self_attention_dropout/checkpoint_epoch_76.pt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ff75530c699e> in <module>()
#       5         start_time = time.time()
#       6         global_step += 1
# ----> 7         loss = model.update(batch)
#       8         train_loss += loss
#       9         if global_step % opt['log_step'] == 0:
#
# J:\PyCharmProjects\tac-self-attention\model\rnn.py in update(self, batch)
#      46         self.model.train()
#      47         self.optimizer.zero_grad()
# ---> 48         logits, _ = self.model(inputs)
#      49         loss = self.criterion(logits, labels)
#      50
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# J:\PyCharmProjects\tac-self-attention\model\rnn.py in forward(self, inputs)
#     333
#     334         # embedding lookup
# --> 335         word_inputs = self.emb(words)
#     336
#     337         inputs = [word_inputs]
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\modules\sparse.py in forward(self, input)
#     101             input, self.weight,
#     102             padding_idx, self.max_norm, self.norm_type,
# --> 103             self.scale_grad_by_freq, self.sparse
#     104         )
#     105
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\_functions\thnn\sparse.py in forward(cls, ctx, indices, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#      57             output = torch.index_select(weight, 0, indices)
#      58         else:
# ---> 59             output = torch.index_select(weight, 0, indices.view(-1))
#      60             output = output.view(indices.size(0), indices.size(1), weight.size(1))
#      61
#
# KeyboardInterrupt:

# %%
# change dropout

# %%
# this is 2 layer encoder + 0.3 lr
