# %%
"""
Train a model on TACRED.
"""

import os
from datetime import datetime
import time
import numpy as np
import random
import argparse
from shutil import copyfile
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from data.loader import DataLoader
from model.rnn import RelationModel
from utils import scorer, constant, helper
from utils.vocab import Vocab

# %%
print(torch.__version__)
# Out:
# 0.3.1.post2

# %%
import argparse
import sys; sys.argv=['']; del sys  # this has to be done if argparse is used in the notebook
from datetime import datetime

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--data_dir', type=str, default='dataset/tacred')
parser.add_argument('--vocab_dir', type=str, default='dataset/vocab')
parser.add_argument('--emb_dim', type=int, default=300, help='Word embedding dimension.')
parser.add_argument('--ner_dim', type=int, default=30, help='NER embedding dimension.')
parser.add_argument('--pos_dim', type=int, default=30, help='POS embedding dimension.')
parser.add_argument('--hidden_dim', type=int, default=360, help='RNN hidden state size.')            # 200 original
parser.add_argument('--num_layers', type=int, default=2, help='Num of self-attention layers.')
parser.add_argument('--dropout', type=float, default=0.1, help='Input and RNN dropout rate.')        # 0.5 original
parser.add_argument('--word_dropout', type=float, default=0.04,                                      # 0.04
                    help='The rate at which randomly set a word to UNK.'
                   )

parser.add_argument('--topn', type=int, default=1e10, help='Only finetune top N embeddings.')
parser.add_argument('--lower', dest='lower', action='store_true', help='Lowercase all words.',
                   default=True)
parser.add_argument('--no-lower', dest='lower', action='store_false')
parser.set_defaults(lower=False)

parser.add_argument(
    '--self-attn', dest='self_att', action='store_true', 
    help='Use self-attention layer instead of LSTM.', default=True
)

parser.add_argument('--attn', dest='attn', action='store_true', help='Use attention layer.', default="true")
parser.add_argument('--no-attn', dest='attn', action='store_false')
parser.set_defaults(attn=True)

parser.add_argument('--attn_dim', type=int, default=200, help='Attention size.')                    # 200 original
parser.add_argument('--pe_dim', type=int, default=30, help='Position encoding dimension.')

parser.add_argument('--lr', type=float, default=0.2, help='Applies to SGD and Adagrad.')            # lr 1.0 orig
parser.add_argument('--lr_decay', type=float, default=0.95)                                          # lr_decay 0.9 original
parser.add_argument('--optim', type=str, default='sgd', help='sgd, adagrad, adam or adamax.')       # sgd original
parser.add_argument('--num_epoch', type=int, default=100)                                           # epochs 30 original
parser.add_argument('--batch_size', type=int, default=50)                                           # batch size 50 original
parser.add_argument('--max_grad_norm', type=float, default=5.0, help='Gradient clipping.')
parser.add_argument('--log_step', type=int, default=400, help='Print log every k steps.')
parser.add_argument('--log', type=str, default='logs.txt', help='Write training log to file.')
parser.add_argument('--save_epoch', type=int, default=5, help='Save model checkpoints every k epochs.')
parser.add_argument('--save_dir', type=str, default='./saved_models', help='Root dir for saving models.')

parser.add_argument(
    '--id', type=str, 
    default='26_self_attention_dropout',                                 # change model folder output before running
    help='Model ID under which to save models.'
   )

parser.add_argument('--info', type=str, default='', help='Optional info for the experiment.')

parser.add_argument('--seed', type=int, default=1234)
parser.add_argument('--cuda', type=bool, default=torch.cuda.is_available())
parser.add_argument('--cpu', action='store_true', help='Ignore CUDA.')

args = parser.parse_args()

# %%
torch.manual_seed(args.seed)
np.random.seed(args.seed)
random.seed(1234)
if args.cpu:
    args.cuda = False
elif args.cuda:
    torch.cuda.manual_seed(args.seed)

# make opt
opt = vars(args)
opt['num_class'] = len(constant.LABEL_TO_ID)

# load vocab
vocab_file = opt['vocab_dir'] + '/vocab.pkl'
vocab = Vocab(vocab_file, load=True)
opt['vocab_size'] = vocab.size
emb_file = opt['vocab_dir'] + '/embedding.npy'
emb_matrix = np.load(emb_file)
assert emb_matrix.shape[0] == vocab.size
assert emb_matrix.shape[1] == opt['emb_dim']

# load data
print("Loading data from {} with batch size {}...".format(opt['data_dir'], opt['batch_size']))
train_batch = DataLoader(opt['data_dir'] + '/train.json', opt['batch_size'], opt, vocab, evaluation=False)
dev_batch = DataLoader(opt['data_dir'] + '/dev.json', opt['batch_size'], opt, vocab, evaluation=True)

model_id = opt['id'] if len(opt['id']) > 1 else '0' + opt['id']
model_save_dir = opt['save_dir'] + '/' + model_id
opt['model_save_dir'] = model_save_dir
helper.ensure_dir(model_save_dir, verbose=True)

# save config
helper.save_config(opt, model_save_dir + '/config.json', verbose=True)
vocab.save(model_save_dir + '/vocab.pkl')
file_logger = helper.FileLogger(model_save_dir + '/' + opt['log'], header="# epoch\ttrain_loss\tdev_loss\tdev_f1")

# print model info
helper.print_config(opt)

# model
model = RelationModel(opt, emb_matrix=emb_matrix)

id2label = dict([(v,k) for k,v in constant.LABEL_TO_ID.items()])
dev_f1_history = []
current_lr = opt['lr']

global_step = 0
global_start_time = time.time()
format_str = '{}: step {}/{} (epoch {}/{}), loss = {:.6f} ({:.3f} sec/batch), lr: {:.6f}'
max_steps = len(train_batch) * opt['num_epoch']
# Out:
# Vocab size 55950 loaded from file
# Loading data from dataset/tacred with batch size 50...
# 1501 batches created for dataset/tacred/train.json
# 516 batches created for dataset/tacred/dev.json
# Config saved to file ./saved_models/26_self_attention_dropout/config.json
# Overwriting old vocab file at ./saved_models/26_self_attention_dropout/vocab.pkl
#
# Running with the following configs:
# 	data_dir : dataset/tacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 360
# 	num_layers : 2
# 	dropout : 0.1
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	self_att : True
# 	attn : True
# 	attn_dim : 200
# 	pe_dim : 30
# 	lr : 0.2
# 	lr_decay : 0.95
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 400
# 	log : logs.txt
# 	save_epoch : 5
# 	save_dir : ./saved_models
# 	id : 26_self_attention_dropout
# 	info :
# 	seed : 1234
# 	cuda : True
# 	cpu : False
# 	num_class : 42
# 	vocab_size : 55950
# 	model_save_dir : ./saved_models/26_self_attention_dropout
#
#
# Finetune all embeddings.
# using weights [1.0, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3]

# %%
# start training
for epoch in range(1, opt['num_epoch']+1):
    train_loss = 0
    for i, batch in enumerate(train_batch):
        start_time = time.time()
        global_step += 1
        loss = model.update(batch)
        train_loss += loss
        if global_step % opt['log_step'] == 0:
            duration = time.time() - start_time
            print(
                format_str.format(datetime.now(), global_step, max_steps, epoch,
                opt['num_epoch'], loss, duration, current_lr)
            )
        # do garbage collection, as per https://discuss.pytorch.org/t/best-practices-for-maximum-gpu-utilization/13863/6
        del loss

    # eval on dev
    print("Evaluating on dev set...")
    predictions = []
    dev_loss = 0
    for i, batch in enumerate(dev_batch):
        preds, _, loss = model.predict(batch)
        predictions += preds
        dev_loss += loss
        
    predictions = [id2label[p] for p in predictions]
    dev_p, dev_r, dev_f1 = scorer.score(dev_batch.gold(), predictions)
    
    train_loss = train_loss / train_batch.num_examples * opt['batch_size'] # avg loss per batch
    dev_loss = dev_loss / dev_batch.num_examples * opt['batch_size']
    print(
        "epoch {}: train_loss = {:.6f}, dev_loss = {:.6f}, dev_f1 = {:.4f}".format(epoch,\
            train_loss, dev_loss, dev_f1)
        )
    file_logger.log("{}\t{:.6f}\t{:.6f}\t{:.4f}".format(epoch, train_loss, dev_loss, dev_f1))

    # save
    model_file = model_save_dir + '/checkpoint_epoch_{}.pt'.format(epoch)
    model.save(model_file, epoch)
    if epoch == 1 or dev_f1 > max(dev_f1_history):
        copyfile(model_file, model_save_dir + '/best_model.pt')
        print("new best model saved.")
    if epoch % opt['save_epoch'] != 0:
        os.remove(model_file)
    
    # lr schedule
    if len(dev_f1_history) > 10 and dev_f1 <= dev_f1_history[-1] and opt['optim'] in ['sgd', 'adagrad', 'adam']:
        current_lr *= opt['lr_decay']
        model.update_lr(current_lr)

    dev_f1_history += [dev_f1]
    print("")

print("Training ended with {} epochs.".format(epoch))

# !!!!!!!! change the model output folder !!!!!!!!!!!
# Out:
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\modules\module.py:357: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   result = self.forward(*input, **kwargs)
# 2018-03-11 14:11:31.024352: step 400/150100 (epoch 1/100), loss = 0.238865 (0.052 sec/batch), lr: 0.200000
# 2018-03-11 14:11:54.443659: step 800/150100 (epoch 1/100), loss = 0.319750 (0.060 sec/batch), lr: 0.200000
# 2018-03-11 14:12:17.782752: step 1200/150100 (epoch 1/100), loss = 0.310774 (0.047 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2534.0 / guessed_by_relation= 5288.0
# Calculating Recall: correct_by_relation= 2534.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 47.920%
#    Recall (micro): 39.232%
#        F1 (micro): 43.143%
# epoch 1: train_loss = 0.358559, dev_loss = 0.485940, dev_f1 = 0.4314
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_1.pt
# new best model saved.
#
# 2018-03-11 14:12:52.677589: step 1600/150100 (epoch 2/100), loss = 0.228677 (0.062 sec/batch), lr: 0.200000
# 2018-03-11 14:13:16.262335: step 2000/150100 (epoch 2/100), loss = 0.357646 (0.061 sec/batch), lr: 0.200000
# 2018-03-11 14:13:39.845077: step 2400/150100 (epoch 2/100), loss = 0.300382 (0.059 sec/batch), lr: 0.200000
# 2018-03-11 14:14:04.306155: step 2800/150100 (epoch 2/100), loss = 0.413276 (0.062 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2702.0 / guessed_by_relation= 4864.0
# Calculating Recall: correct_by_relation= 2702.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.551%
#    Recall (micro): 41.833%
#        F1 (micro): 47.726%
# epoch 2: train_loss = 0.271669, dev_loss = 0.411805, dev_f1 = 0.4773
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_2.pt
# new best model saved.
#
# 2018-03-11 14:14:40.081301: step 3200/150100 (epoch 3/100), loss = 0.249681 (0.051 sec/batch), lr: 0.200000
# 2018-03-11 14:15:04.108973: step 3600/150100 (epoch 3/100), loss = 0.212603 (0.061 sec/batch), lr: 0.200000
# 2018-03-11 14:15:27.734502: step 4000/150100 (epoch 3/100), loss = 0.159994 (0.062 sec/batch), lr: 0.200000
# 2018-03-11 14:15:51.314235: step 4400/150100 (epoch 3/100), loss = 0.255373 (0.057 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2770.0 / guessed_by_relation= 4544.0
# Calculating Recall: correct_by_relation= 2770.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 60.960%
#    Recall (micro): 42.886%
#        F1 (micro): 50.350%
# epoch 3: train_loss = 0.253809, dev_loss = 0.367072, dev_f1 = 0.5035
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_3.pt
# new best model saved.
#
# 2018-03-11 14:16:26.329392: step 4800/150100 (epoch 4/100), loss = 0.211455 (0.050 sec/batch), lr: 0.200000
# 2018-03-11 14:16:49.859995: step 5200/150100 (epoch 4/100), loss = 0.352157 (0.054 sec/batch), lr: 0.200000
# 2018-03-11 14:17:13.393605: step 5600/150100 (epoch 4/100), loss = 0.400575 (0.063 sec/batch), lr: 0.200000
# 2018-03-11 14:17:36.946805: step 6000/150100 (epoch 4/100), loss = 0.164572 (0.063 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2478.0 / guessed_by_relation= 3829.0
# Calculating Recall: correct_by_relation= 2478.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 64.717%
#    Recall (micro): 38.365%
#        F1 (micro): 48.173%
# epoch 4: train_loss = 0.242625, dev_loss = 0.336403, dev_f1 = 0.4817
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_4.pt
#
# 2018-03-11 14:18:11.841642: step 6400/150100 (epoch 5/100), loss = 0.225176 (0.065 sec/batch), lr: 0.200000
# 2018-03-11 14:18:35.404649: step 6800/150100 (epoch 5/100), loss = 0.185555 (0.059 sec/batch), lr: 0.200000
# 2018-03-11 14:18:59.030505: step 7200/150100 (epoch 5/100), loss = 0.253943 (0.055 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2805.0 / guessed_by_relation= 4513.0
# Calculating Recall: correct_by_relation= 2805.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 62.154%
#    Recall (micro): 43.428%
#        F1 (micro): 51.130%
# epoch 5: train_loss = 0.236106, dev_loss = 0.343282, dev_f1 = 0.5113
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_5.pt
# new best model saved.
#
# 2018-03-11 14:19:33.579394: step 7600/150100 (epoch 6/100), loss = 0.226533 (0.063 sec/batch), lr: 0.200000
# 2018-03-11 14:19:57.206807: step 8000/150100 (epoch 6/100), loss = 0.142620 (0.059 sec/batch), lr: 0.200000
# 2018-03-11 14:20:20.749442: step 8400/150100 (epoch 6/100), loss = 0.199917 (0.058 sec/batch), lr: 0.200000
# 2018-03-11 14:20:44.240940: step 8800/150100 (epoch 6/100), loss = 0.191703 (0.052 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2545.0 / guessed_by_relation= 3772.0
# Calculating Recall: correct_by_relation= 2545.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.471%
#    Recall (micro): 39.402%
#        F1 (micro): 49.751%
# epoch 6: train_loss = 0.229053, dev_loss = 0.307428, dev_f1 = 0.4975
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_6.pt
#
# 2018-03-11 14:21:18.767798: step 9200/150100 (epoch 7/100), loss = 0.290105 (0.064 sec/batch), lr: 0.200000
# 2018-03-11 14:21:42.272331: step 9600/150100 (epoch 7/100), loss = 0.184734 (0.059 sec/batch), lr: 0.200000
# 2018-03-11 14:22:05.797920: step 10000/150100 (epoch 7/100), loss = 0.159084 (0.056 sec/batch), lr: 0.200000
# 2018-03-11 14:22:29.369971: step 10400/150100 (epoch 7/100), loss = 0.132088 (0.055 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2665.0 / guessed_by_relation= 3942.0
# Calculating Recall: correct_by_relation= 2665.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.605%
#    Recall (micro): 41.260%
#        F1 (micro): 51.245%
# epoch 7: train_loss = 0.223374, dev_loss = 0.313665, dev_f1 = 0.5125
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_7.pt
# new best model saved.
#
# 2018-03-11 14:23:04.458323: step 10800/150100 (epoch 8/100), loss = 0.207913 (0.059 sec/batch), lr: 0.200000
# 2018-03-11 14:23:27.948819: step 11200/150100 (epoch 8/100), loss = 0.346832 (0.060 sec/batch), lr: 0.200000
# 2018-03-11 14:23:51.455357: step 11600/150100 (epoch 8/100), loss = 0.227864 (0.063 sec/batch), lr: 0.200000
# 2018-03-11 14:24:15.087229: step 12000/150100 (epoch 8/100), loss = 0.112151 (0.053 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2796.0 / guessed_by_relation= 4111.0
# Calculating Recall: correct_by_relation= 2796.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 68.013%
#    Recall (micro): 43.288%
#        F1 (micro): 52.904%
# epoch 8: train_loss = 0.219315, dev_loss = 0.307818, dev_f1 = 0.5290
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_8.pt
# new best model saved.
#
# 2018-03-11 14:24:50.104311: step 12400/150100 (epoch 9/100), loss = 0.223276 (0.059 sec/batch), lr: 0.200000
# 2018-03-11 14:25:13.679146: step 12800/150100 (epoch 9/100), loss = 0.171007 (0.060 sec/batch), lr: 0.200000
# 2018-03-11 14:25:37.167636: step 13200/150100 (epoch 9/100), loss = 0.239821 (0.062 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2530.0 / guessed_by_relation= 3499.0
# Calculating Recall: correct_by_relation= 2530.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 72.306%
#    Recall (micro): 39.170%
#        F1 (micro): 50.813%
# epoch 9: train_loss = 0.216147, dev_loss = 0.283871, dev_f1 = 0.5081
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_9.pt
#
# 2018-03-11 14:26:12.087540: step 13600/150100 (epoch 10/100), loss = 0.225210 (0.058 sec/batch), lr: 0.200000
# 2018-03-11 14:26:35.679305: step 14000/150100 (epoch 10/100), loss = 0.239717 (0.063 sec/batch), lr: 0.200000
# 2018-03-11 14:26:59.260041: step 14400/150100 (epoch 10/100), loss = 0.148667 (0.060 sec/batch), lr: 0.200000
# 2018-03-11 14:27:22.758558: step 14800/150100 (epoch 10/100), loss = 0.294291 (0.046 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 2825.0 / guessed_by_relation= 3948.0
# Calculating Recall: correct_by_relation= 2825.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 71.555%
#    Recall (micro): 43.737%
#        F1 (micro): 54.290%
# epoch 10: train_loss = 0.212531, dev_loss = 0.285426, dev_f1 = 0.5429
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_10.pt
# new best model saved.
#
# 2018-03-11 14:27:57.769704: step 15200/150100 (epoch 11/100), loss = 0.322265 (0.044 sec/batch), lr: 0.200000
# 2018-03-11 14:28:21.258195: step 15600/150100 (epoch 11/100), loss = 0.259280 (0.065 sec/batch), lr: 0.200000
# 2018-03-11 14:28:44.807848: step 16000/150100 (epoch 11/100), loss = 0.194363 (0.061 sec/batch), lr: 0.200000
# 2018-03-11 14:29:08.389586: step 16400/150100 (epoch 11/100), loss = 0.159612 (0.061 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3103.0 / guessed_by_relation= 4475.0
# Calculating Recall: correct_by_relation= 3103.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 69.341%
#    Recall (micro): 48.041%
#        F1 (micro): 56.759%
# epoch 11: train_loss = 0.209333, dev_loss = 0.298087, dev_f1 = 0.5676
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_11.pt
# new best model saved.
#
# 2018-03-11 14:29:42.853277: step 16800/150100 (epoch 12/100), loss = 0.329616 (0.055 sec/batch), lr: 0.200000
# 2018-03-11 14:30:06.329735: step 17200/150100 (epoch 12/100), loss = 0.197966 (0.052 sec/batch), lr: 0.200000
# 2018-03-11 14:30:29.880414: step 17600/150100 (epoch 12/100), loss = 0.176964 (0.054 sec/batch), lr: 0.200000
# 2018-03-11 14:30:53.479197: step 18000/150100 (epoch 12/100), loss = 0.136850 (0.063 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3395.0 / guessed_by_relation= 5097.0
# Calculating Recall: correct_by_relation= 3395.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 66.608%
#    Recall (micro): 52.562%
#        F1 (micro): 58.757%
# epoch 12: train_loss = 0.206570, dev_loss = 0.317151, dev_f1 = 0.5876
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_12.pt
# new best model saved.
#
# 2018-03-11 14:31:28.001019: step 18400/150100 (epoch 13/100), loss = 0.300465 (0.065 sec/batch), lr: 0.200000
# 2018-03-11 14:31:51.551674: step 18800/150100 (epoch 13/100), loss = 0.089913 (0.052 sec/batch), lr: 0.200000
# 2018-03-11 14:32:15.051194: step 19200/150100 (epoch 13/100), loss = 0.173719 (0.057 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3182.0 / guessed_by_relation= 4638.0
# Calculating Recall: correct_by_relation= 3182.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 68.607%
#    Recall (micro): 49.265%
#        F1 (micro): 57.349%
# epoch 13: train_loss = 0.203798, dev_loss = 0.303840, dev_f1 = 0.5735
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_13.pt
#
# 2018-03-11 14:32:50.085402: step 19600/150100 (epoch 14/100), loss = 0.124964 (0.046 sec/batch), lr: 0.190000
# 2018-03-11 14:33:13.662127: step 20000/150100 (epoch 14/100), loss = 0.164773 (0.064 sec/batch), lr: 0.190000
# 2018-03-11 14:33:37.240857: step 20400/150100 (epoch 14/100), loss = 0.194184 (0.063 sec/batch), lr: 0.190000
# 2018-03-11 14:34:00.763866: step 20800/150100 (epoch 14/100), loss = 0.145332 (0.055 sec/batch), lr: 0.190000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3352.0 / guessed_by_relation= 4967.0
# Calculating Recall: correct_by_relation= 3352.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.485%
#    Recall (micro): 51.897%
#        F1 (micro): 58.673%
# epoch 14: train_loss = 0.200013, dev_loss = 0.308029, dev_f1 = 0.5867
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_14.pt
#
# 2018-03-11 14:34:36.103804: step 21200/150100 (epoch 15/100), loss = 0.237157 (0.059 sec/batch), lr: 0.190000
# 2018-03-11 14:34:59.762572: step 21600/150100 (epoch 15/100), loss = 0.207951 (0.052 sec/batch), lr: 0.190000
# 2018-03-11 14:35:23.407730: step 22000/150100 (epoch 15/100), loss = 0.157516 (0.045 sec/batch), lr: 0.190000
# 2018-03-11 14:35:46.952370: step 22400/150100 (epoch 15/100), loss = 0.203217 (0.063 sec/batch), lr: 0.190000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3158.0 / guessed_by_relation= 4456.0
# Calculating Recall: correct_by_relation= 3158.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 70.871%
#    Recall (micro): 48.893%
#        F1 (micro): 57.865%
# epoch 15: train_loss = 0.196436, dev_loss = 0.284558, dev_f1 = 0.5787
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_15.pt
#
# 2018-03-11 14:36:21.882300: step 22800/150100 (epoch 16/100), loss = 0.127991 (0.053 sec/batch), lr: 0.180500
# 2018-03-11 14:36:45.364775: step 23200/150100 (epoch 16/100), loss = 0.204136 (0.058 sec/batch), lr: 0.180500
# 2018-03-11 14:37:09.028732: step 23600/150100 (epoch 16/100), loss = 0.189102 (0.050 sec/batch), lr: 0.180500
# 2018-03-11 14:37:32.848074: step 24000/150100 (epoch 16/100), loss = 0.202151 (0.064 sec/batch), lr: 0.180500
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3382.0 / guessed_by_relation= 4955.0
# Calculating Recall: correct_by_relation= 3382.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 68.254%
#    Recall (micro): 52.361%
#        F1 (micro): 59.261%
# epoch 16: train_loss = 0.193150, dev_loss = 0.301651, dev_f1 = 0.5926
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_16.pt
# new best model saved.
#
# 2018-03-11 14:38:07.885616: step 24400/150100 (epoch 17/100), loss = 0.164657 (0.058 sec/batch), lr: 0.180500
# 2018-03-11 14:38:38.328765: step 24800/150100 (epoch 17/100), loss = 0.200651 (0.062 sec/batch), lr: 0.180500
# 2018-03-11 14:39:07.375098: step 25200/150100 (epoch 17/100), loss = 0.212094 (0.096 sec/batch), lr: 0.180500
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3283.0 / guessed_by_relation= 4760.0
# Calculating Recall: correct_by_relation= 3283.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 68.971%
#    Recall (micro): 50.828%
#        F1 (micro): 58.526%
# epoch 17: train_loss = 0.190717, dev_loss = 0.293076, dev_f1 = 0.5853
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_17.pt
#
# 2018-03-11 14:39:43.409190: step 25600/150100 (epoch 18/100), loss = 0.160047 (0.064 sec/batch), lr: 0.171475
# 2018-03-11 14:40:07.150352: step 26000/150100 (epoch 18/100), loss = 0.140344 (0.052 sec/batch), lr: 0.171475
# 2018-03-11 14:40:30.719056: step 26400/150100 (epoch 18/100), loss = 0.169518 (0.054 sec/batch), lr: 0.171475
# 2018-03-11 14:40:54.566501: step 26800/150100 (epoch 18/100), loss = 0.238249 (0.050 sec/batch), lr: 0.171475
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3377.0 / guessed_by_relation= 4997.0
# Calculating Recall: correct_by_relation= 3377.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.581%
#    Recall (micro): 52.284%
#        F1 (micro): 58.956%
# epoch 18: train_loss = 0.187635, dev_loss = 0.300438, dev_f1 = 0.5896
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_18.pt
#
# 2018-03-11 14:41:29.366085: step 27200/150100 (epoch 19/100), loss = 0.262891 (0.050 sec/batch), lr: 0.171475
# 2018-03-11 14:41:52.887664: step 27600/150100 (epoch 19/100), loss = 0.092965 (0.047 sec/batch), lr: 0.171475
# 2018-03-11 14:42:16.496474: step 28000/150100 (epoch 19/100), loss = 0.093624 (0.052 sec/batch), lr: 0.171475
# 2018-03-11 14:42:40.046127: step 28400/150100 (epoch 19/100), loss = 0.182078 (0.054 sec/batch), lr: 0.171475
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3568.0 / guessed_by_relation= 5394.0
# Calculating Recall: correct_by_relation= 3568.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 66.148%
#    Recall (micro): 55.241%
#        F1 (micro): 60.204%
# epoch 19: train_loss = 0.184949, dev_loss = 0.313079, dev_f1 = 0.6020
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_19.pt
# new best model saved.
#
# 2018-03-11 14:43:15.261599: step 28800/150100 (epoch 20/100), loss = 0.304193 (0.047 sec/batch), lr: 0.171475
# 2018-03-11 14:43:38.717002: step 29200/150100 (epoch 20/100), loss = 0.148371 (0.062 sec/batch), lr: 0.171475
# 2018-03-11 14:44:02.258634: step 29600/150100 (epoch 20/100), loss = 0.131920 (0.044 sec/batch), lr: 0.171475
# 2018-03-11 14:44:25.861878: step 30000/150100 (epoch 20/100), loss = 0.172697 (0.056 sec/batch), lr: 0.171475
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3336.0 / guessed_by_relation= 4874.0
# Calculating Recall: correct_by_relation= 3336.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 68.445%
#    Recall (micro): 51.649%
#        F1 (micro): 58.872%
# epoch 20: train_loss = 0.183378, dev_loss = 0.293601, dev_f1 = 0.5887
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_20.pt
#
# 2018-03-11 14:45:00.707584: step 30400/150100 (epoch 21/100), loss = 0.100475 (0.062 sec/batch), lr: 0.162901
# 2018-03-11 14:45:24.259242: step 30800/150100 (epoch 21/100), loss = 0.188218 (0.062 sec/batch), lr: 0.162901
# 2018-03-11 14:45:47.925205: step 31200/150100 (epoch 21/100), loss = 0.125415 (0.061 sec/batch), lr: 0.162901
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3423.0 / guessed_by_relation= 5091.0
# Calculating Recall: correct_by_relation= 3423.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.236%
#    Recall (micro): 52.996%
#        F1 (micro): 59.273%
# epoch 21: train_loss = 0.178920, dev_loss = 0.301968, dev_f1 = 0.5927
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_21.pt
#
# 2018-03-11 14:46:22.979705: step 31600/150100 (epoch 22/100), loss = 0.218424 (0.052 sec/batch), lr: 0.162901
# 2018-03-11 14:46:46.498275: step 32000/150100 (epoch 22/100), loss = 0.132439 (0.057 sec/batch), lr: 0.162901
# 2018-03-11 14:47:10.086701: step 32400/150100 (epoch 22/100), loss = 0.251578 (0.054 sec/batch), lr: 0.162901
# 2018-03-11 14:47:33.704535: step 32800/150100 (epoch 22/100), loss = 0.126542 (0.053 sec/batch), lr: 0.162901
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3762.0 / guessed_by_relation= 5793.0
# Calculating Recall: correct_by_relation= 3762.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 64.940%
#    Recall (micro): 58.244%
#        F1 (micro): 61.410%
# epoch 22: train_loss = 0.176545, dev_loss = 0.323864, dev_f1 = 0.6141
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_22.pt
# new best model saved.
#
# 2018-03-11 14:48:08.861723: step 33200/150100 (epoch 23/100), loss = 0.125919 (0.057 sec/batch), lr: 0.162901
# 2018-03-11 14:48:32.682394: step 33600/150100 (epoch 23/100), loss = 0.106852 (0.063 sec/batch), lr: 0.162901
# 2018-03-11 14:49:03.394101: step 34000/150100 (epoch 23/100), loss = 0.283867 (0.062 sec/batch), lr: 0.162901
# 2018-03-11 14:49:27.135847: step 34400/150100 (epoch 23/100), loss = 0.085691 (0.063 sec/batch), lr: 0.162901
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3273.0 / guessed_by_relation= 4729.0
# Calculating Recall: correct_by_relation= 3273.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 69.211%
#    Recall (micro): 50.673%
#        F1 (micro): 58.509%
# epoch 23: train_loss = 0.175825, dev_loss = 0.289697, dev_f1 = 0.5851
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_23.pt
#
# 2018-03-11 14:50:02.106441: step 34800/150100 (epoch 24/100), loss = 0.474405 (0.062 sec/batch), lr: 0.154756
# 2018-03-11 14:50:25.779890: step 35200/150100 (epoch 24/100), loss = 0.142666 (0.062 sec/batch), lr: 0.154756
# 2018-03-11 14:50:50.917415: step 35600/150100 (epoch 24/100), loss = 0.130351 (0.065 sec/batch), lr: 0.154756
# 2018-03-11 14:51:15.651408: step 36000/150100 (epoch 24/100), loss = 0.224838 (0.055 sec/batch), lr: 0.154756
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3468.0 / guessed_by_relation= 5172.0
# Calculating Recall: correct_by_relation= 3468.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.053%
#    Recall (micro): 53.693%
#        F1 (micro): 59.634%
# epoch 24: train_loss = 0.171655, dev_loss = 0.303568, dev_f1 = 0.5963
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_24.pt
#
# 2018-03-11 14:51:50.825989: step 36400/150100 (epoch 25/100), loss = 0.152420 (0.059 sec/batch), lr: 0.154756
# 2018-03-11 14:52:15.130894: step 36800/150100 (epoch 25/100), loss = 0.194071 (0.063 sec/batch), lr: 0.154756
# 2018-03-11 14:52:39.237877: step 37200/150100 (epoch 25/100), loss = 0.106624 (0.065 sec/batch), lr: 0.154756
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3614.0 / guessed_by_relation= 5563.0
# Calculating Recall: correct_by_relation= 3614.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 64.965%
#    Recall (micro): 55.953%
#        F1 (micro): 60.123%
# epoch 25: train_loss = 0.169345, dev_loss = 0.320098, dev_f1 = 0.6012
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_25.pt
#
# 2018-03-11 14:53:15.069526: step 37600/150100 (epoch 26/100), loss = 0.157983 (0.054 sec/batch), lr: 0.154756
# 2018-03-11 14:53:39.384891: step 38000/150100 (epoch 26/100), loss = 0.145014 (0.050 sec/batch), lr: 0.154756
# 2018-03-11 14:54:03.366694: step 38400/150100 (epoch 26/100), loss = 0.095054 (0.058 sec/batch), lr: 0.154756
# 2018-03-11 14:54:27.326439: step 38800/150100 (epoch 26/100), loss = 0.159957 (0.067 sec/batch), lr: 0.154756
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3656.0 / guessed_by_relation= 5626.0
# Calculating Recall: correct_by_relation= 3656.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 64.984%
#    Recall (micro): 56.603%
#        F1 (micro): 60.505%
# epoch 26: train_loss = 0.167039, dev_loss = 0.322407, dev_f1 = 0.6050
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_26.pt
#
# 2018-03-11 14:55:03.495462: step 39200/150100 (epoch 27/100), loss = 0.064006 (0.062 sec/batch), lr: 0.154756
# 2018-03-11 14:55:27.945692: step 39600/150100 (epoch 27/100), loss = 0.320095 (0.057 sec/batch), lr: 0.154756
# 2018-03-11 14:55:52.086627: step 40000/150100 (epoch 27/100), loss = 0.213259 (0.051 sec/batch), lr: 0.154756
# 2018-03-11 14:56:16.425107: step 40400/150100 (epoch 27/100), loss = 0.250429 (0.068 sec/batch), lr: 0.154756
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3580.0 / guessed_by_relation= 5435.0
# Calculating Recall: correct_by_relation= 3580.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 65.869%
#    Recall (micro): 55.427%
#        F1 (micro): 60.198%
# epoch 27: train_loss = 0.164886, dev_loss = 0.316915, dev_f1 = 0.6020
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_27.pt
#
# 2018-03-11 14:56:52.351334: step 40800/150100 (epoch 28/100), loss = 0.156294 (0.055 sec/batch), lr: 0.147018
# 2018-03-11 14:57:16.109542: step 41200/150100 (epoch 28/100), loss = 0.148050 (0.060 sec/batch), lr: 0.147018
# 2018-03-11 14:57:40.309927: step 41600/150100 (epoch 28/100), loss = 0.115606 (0.063 sec/batch), lr: 0.147018
# 2018-03-11 14:58:04.857234: step 42000/150100 (epoch 28/100), loss = 0.185155 (0.062 sec/batch), lr: 0.147018
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3538.0 / guessed_by_relation= 5360.0
# Calculating Recall: correct_by_relation= 3538.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 66.007%
#    Recall (micro): 54.776%
#        F1 (micro): 59.870%
# epoch 28: train_loss = 0.160885, dev_loss = 0.320172, dev_f1 = 0.5987
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_28.pt
#
# 2018-03-11 14:58:40.800473: step 42400/150100 (epoch 29/100), loss = 0.275964 (0.050 sec/batch), lr: 0.139667
# 2018-03-11 14:59:04.739928: step 42800/150100 (epoch 29/100), loss = 0.252365 (0.058 sec/batch), lr: 0.139667
# 2018-03-11 14:59:29.408558: step 43200/150100 (epoch 29/100), loss = 0.113745 (0.073 sec/batch), lr: 0.139667
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3417.0 / guessed_by_relation= 4932.0
# Calculating Recall: correct_by_relation= 3417.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 69.282%
#    Recall (micro): 52.903%
#        F1 (micro): 59.995%
# epoch 29: train_loss = 0.157334, dev_loss = 0.298543, dev_f1 = 0.5999
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_29.pt
#
# 2018-03-11 15:00:05.051157: step 43600/150100 (epoch 30/100), loss = 0.063435 (0.052 sec/batch), lr: 0.139667
# 2018-03-11 15:00:29.586123: step 44000/150100 (epoch 30/100), loss = 0.191482 (0.053 sec/batch), lr: 0.139667
# 2018-03-11 15:00:53.984481: step 44400/150100 (epoch 30/100), loss = 0.134061 (0.053 sec/batch), lr: 0.139667
# 2018-03-11 15:01:17.895094: step 44800/150100 (epoch 30/100), loss = 0.248404 (0.059 sec/batch), lr: 0.139667
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3509.0 / guessed_by_relation= 5383.0
# Calculating Recall: correct_by_relation= 3509.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 65.187%
#    Recall (micro): 54.327%
#        F1 (micro): 59.264%
# epoch 30: train_loss = 0.154798, dev_loss = 0.326390, dev_f1 = 0.5926
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_30.pt
#
# 2018-03-11 15:01:53.528180: step 45200/150100 (epoch 31/100), loss = 0.142638 (0.072 sec/batch), lr: 0.132684
# 2018-03-11 15:02:17.989819: step 45600/150100 (epoch 31/100), loss = 0.196503 (0.065 sec/batch), lr: 0.132684
# 2018-03-11 15:02:41.885572: step 46000/150100 (epoch 31/100), loss = 0.178110 (0.060 sec/batch), lr: 0.132684
# 2018-03-11 15:03:06.064055: step 46400/150100 (epoch 31/100), loss = 0.091148 (0.061 sec/batch), lr: 0.132684
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3470.0 / guessed_by_relation= 5221.0
# Calculating Recall: correct_by_relation= 3470.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 66.462%
#    Recall (micro): 53.723%
#        F1 (micro): 59.418%
# epoch 31: train_loss = 0.150715, dev_loss = 0.319951, dev_f1 = 0.5942
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_31.pt
#
# 2018-03-11 15:03:41.679288: step 46800/150100 (epoch 32/100), loss = 0.112115 (0.064 sec/batch), lr: 0.132684
# 2018-03-11 15:04:06.028213: step 47200/150100 (epoch 32/100), loss = 0.263808 (0.063 sec/batch), lr: 0.132684
# 2018-03-11 15:04:30.132341: step 47600/150100 (epoch 32/100), loss = 0.126227 (0.065 sec/batch), lr: 0.132684
# 2018-03-11 15:04:54.152728: step 48000/150100 (epoch 32/100), loss = 0.130091 (0.065 sec/batch), lr: 0.132684
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3414.0 / guessed_by_relation= 5046.0
# Calculating Recall: correct_by_relation= 3414.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 67.658%
#    Recall (micro): 52.856%
#        F1 (micro): 59.348%
# epoch 32: train_loss = 0.147899, dev_loss = 0.316568, dev_f1 = 0.5935
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_32.pt
#
# 2018-03-11 15:05:29.415318: step 48400/150100 (epoch 33/100), loss = 0.181412 (0.044 sec/batch), lr: 0.126050
# 2018-03-11 15:05:53.118371: step 48800/150100 (epoch 33/100), loss = 0.382513 (0.058 sec/batch), lr: 0.126050
# 2018-03-11 15:06:16.793417: step 49200/150100 (epoch 33/100), loss = 0.147543 (0.063 sec/batch), lr: 0.126050
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3463.0 / guessed_by_relation= 5293.0
# Calculating Recall: correct_by_relation= 3463.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 65.426%
#    Recall (micro): 53.615%
#        F1 (micro): 58.935%
# epoch 33: train_loss = 0.144205, dev_loss = 0.330360, dev_f1 = 0.5893
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_33.pt
#
# 2018-03-11 15:06:53.031829: step 49600/150100 (epoch 34/100), loss = 0.347257 (0.052 sec/batch), lr: 0.119747
# 2018-03-11 15:07:17.244245: step 50000/150100 (epoch 34/100), loss = 0.125807 (0.058 sec/batch), lr: 0.119747
# 2018-03-11 15:07:41.404733: step 50400/150100 (epoch 34/100), loss = 0.105049 (0.047 sec/batch), lr: 0.119747
# 2018-03-11 15:08:05.004816: step 50800/150100 (epoch 34/100), loss = 0.151033 (0.060 sec/batch), lr: 0.119747
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3493.0 / guessed_by_relation= 5298.0
# Calculating Recall: correct_by_relation= 3493.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 65.931%
#    Recall (micro): 54.080%
#        F1 (micro): 59.420%
# epoch 34: train_loss = 0.141768, dev_loss = 0.327541, dev_f1 = 0.5942
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_34.pt
#
# 2018-03-11 15:08:40.676721: step 51200/150100 (epoch 35/100), loss = 0.073489 (0.064 sec/batch), lr: 0.119747
# 2018-03-11 15:09:04.900166: step 51600/150100 (epoch 35/100), loss = 0.075843 (0.064 sec/batch), lr: 0.119747
# 2018-03-11 15:09:29.507635: step 52000/150100 (epoch 35/100), loss = 0.119233 (0.051 sec/batch), lr: 0.119747
# 2018-03-11 15:09:53.439304: step 52400/150100 (epoch 35/100), loss = 0.066870 (0.059 sec/batch), lr: 0.119747
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3508.0 / guessed_by_relation= 5303.0
# Calculating Recall: correct_by_relation= 3508.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 66.151%
#    Recall (micro): 54.312%
#        F1 (micro): 59.650%
# epoch 35: train_loss = 0.137283, dev_loss = 0.333157, dev_f1 = 0.5965
# model saved to ./saved_models/26_self_attention_dropout/checkpoint_epoch_35.pt
#
# 2018-03-11 15:10:28.844498: step 52800/150100 (epoch 36/100), loss = 0.156223 (0.048 sec/batch), lr: 0.119747
# 2018-03-11 15:10:52.718013: step 53200/150100 (epoch 36/100), loss = 0.119572 (0.063 sec/batch), lr: 0.119747

# %%
# change dropout

# %%
# using class weights, dropout 0.4
"""
weights = [
    1.0, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8
]


# new
weights = [
    1.0, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3,
    0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3,
    0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3,
    0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3,
    0.3, 0.3
]
        
"""

# %%
# try without residual and with ulinear
# other weights
# now dropout 0.1
