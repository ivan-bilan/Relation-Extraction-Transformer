# %%
"""
Train a model on TACRED.
"""

import os
from datetime import datetime
import time
import numpy as np
import random
import argparse
from shutil import copyfile
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from data.loader import DataLoader
from model.rnn import RelationModel
from utils import scorer, constant, helper
from utils.vocab import Vocab

# %%
print(torch.__version__)
# Out:
# 0.3.0b0+591e73e

# %%
import argparse
import sys; sys.argv=['']; del sys  # this has to be done if argparse is used in the notebook
from datetime import datetime

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--data_dir', type=str, default='dataset/tacred')
parser.add_argument('--vocab_dir', type=str, default='dataset/vocab')
parser.add_argument('--emb_dim', type=int, default=300, help='Word embedding dimension.')
parser.add_argument('--ner_dim', type=int, default=30, help='NER embedding dimension.')
parser.add_argument('--pos_dim', type=int, default=30, help='POS embedding dimension.')
parser.add_argument('--hidden_dim', type=int, default=200, help='RNN hidden state size.')
parser.add_argument('--num_layers', type=int, default=2, help='Num of RNN layers.')
parser.add_argument('--dropout', type=float, default=0.5, help='Input and RNN dropout rate.')
parser.add_argument('--word_dropout', type=float, default=0.04, help='The rate at which randomly set a word to UNK.')
parser.add_argument('--topn', type=int, default=1e10, help='Only finetune top N embeddings.')
parser.add_argument('--lower', dest='lower', action='store_true', help='Lowercase all words.')
parser.add_argument('--no-lower', dest='lower', action='store_false')
parser.set_defaults(lower=False)

parser.add_argument('--attn', dest='attn', action='store_true', help='Use attention layer.', default="true")
parser.add_argument('--no-attn', dest='attn', action='store_false')
parser.set_defaults(attn=True)
parser.add_argument('--attn_dim', type=int, default=200, help='Attention size.')
parser.add_argument('--pe_dim', type=int, default=30, help='Position encoding dimension.')

parser.add_argument('--lr', type=float, default=1.0, help='Applies to SGD and Adagrad.')
parser.add_argument('--lr_decay', type=float, default=0.9)
parser.add_argument('--optim', type=str, default='sgd', help='sgd, adagrad, adam or adamax.')
parser.add_argument('--num_epoch', type=int, default=30)
parser.add_argument('--batch_size', type=int, default=50)
parser.add_argument('--max_grad_norm', type=float, default=5.0, help='Gradient clipping.')
parser.add_argument('--log_step', type=int, default=20, help='Print log every k steps.')
parser.add_argument('--log', type=str, default='logs.txt', help='Write training log to file.')
parser.add_argument('--save_epoch', type=int, default=5, help='Save model checkpoints every k epochs.')
parser.add_argument('--save_dir', type=str, default='./saved_models', help='Root dir for saving models.')
parser.add_argument('--id', type=str, default='01', help='Model ID under which to save models.')
parser.add_argument('--info', type=str, default='', help='Optional info for the experiment.')

parser.add_argument('--seed', type=int, default=1234)
parser.add_argument('--cuda', type=bool, default=torch.cuda.is_available())
parser.add_argument('--cpu', action='store_true', help='Ignore CUDA.')
args = parser.parse_args()

# %%
torch.manual_seed(args.seed)
np.random.seed(args.seed)
random.seed(1234)
if args.cpu:
    args.cuda = False
elif args.cuda:
    torch.cuda.manual_seed(args.seed)

# make opt
opt = vars(args)
opt['num_class'] = len(constant.LABEL_TO_ID)

# load vocab
vocab_file = opt['vocab_dir'] + '/vocab.pkl'
vocab = Vocab(vocab_file, load=True)
opt['vocab_size'] = vocab.size
emb_file = opt['vocab_dir'] + '/embedding.npy'
emb_matrix = np.load(emb_file)
assert emb_matrix.shape[0] == vocab.size
assert emb_matrix.shape[1] == opt['emb_dim']

# load data
print("Loading data from {} with batch size {}...".format(opt['data_dir'], opt['batch_size']))
train_batch = DataLoader(opt['data_dir'] + '/train.json', opt['batch_size'], opt, vocab, evaluation=False)
dev_batch = DataLoader(opt['data_dir'] + '/dev.json', opt['batch_size'], opt, vocab, evaluation=True)

model_id = opt['id'] if len(opt['id']) > 1 else '0' + opt['id']
model_save_dir = opt['save_dir'] + '/' + model_id
opt['model_save_dir'] = model_save_dir
helper.ensure_dir(model_save_dir, verbose=True)

# save config
helper.save_config(opt, model_save_dir + '/config.json', verbose=True)
vocab.save(model_save_dir + '/vocab.pkl')
file_logger = helper.FileLogger(model_save_dir + '/' + opt['log'], header="# epoch\ttrain_loss\tdev_loss\tdev_f1")

# print model info
helper.print_config(opt)

# model
model = RelationModel(opt, emb_matrix=emb_matrix)

id2label = dict([(v,k) for k,v in constant.LABEL_TO_ID.items()])
dev_f1_history = []
current_lr = opt['lr']

global_step = 0
global_start_time = time.time()
format_str = '{}: step {}/{} (epoch {}/{}), loss = {:.6f} ({:.3f} sec/batch), lr: {:.6f}'
max_steps = len(train_batch) * opt['num_epoch']
# Out:
# Vocab size 55950 loaded from file
# Loading data from dataset/tacred with batch size 50...
# 1501 batches created for dataset/tacred/train.json
# 516 batches created for dataset/tacred/dev.json
# Config saved to file ./saved_models/01/config.json
# Overwriting old vocab file at ./saved_models/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : dataset/tacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	attn : True
# 	attn_dim : 200
# 	pe_dim : 30
# 	lr : 1.0
# 	lr_decay : 0.9
# 	optim : sgd
# 	num_epoch : 30
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 5
# 	save_dir : ./saved_models
# 	id : 01
# 	info :
# 	seed : 1234
# 	cuda : True
# 	cpu : False
# 	num_class : 42
# 	vocab_size : 55950
# 	model_save_dir : ./saved_models/01
#
#
# Finetune all embeddings.

# %%
# start training
for epoch in range(1, opt['num_epoch']+1):
    train_loss = 0
    for i, batch in enumerate(train_batch):
        start_time = time.time()
        global_step += 1
        loss = model.update(batch)
        train_loss += loss
        if global_step % 400 == 0: # if global_step % opt['log_step'] == 0:
            duration = time.time() - start_time
            print(format_str.format(datetime.now(), global_step, max_steps, epoch,\
                    opt['num_epoch'], loss, duration, current_lr))

    # eval on dev
    print("Evaluating on dev set...")
    predictions = []
    dev_loss = 0
    for i, batch in enumerate(dev_batch):
        preds, _, loss = model.predict(batch)
        predictions += preds
        dev_loss += loss
        
    predictions = [id2label[p] for p in predictions]
    dev_p, dev_r, dev_f1 = scorer.score(dev_batch.gold(), predictions)
    
    train_loss = train_loss / train_batch.num_examples * opt['batch_size'] # avg loss per batch
    dev_loss = dev_loss / dev_batch.num_examples * opt['batch_size']
    print("epoch {}: train_loss = {:.6f}, dev_loss = {:.6f}, dev_f1 = {:.4f}".format(epoch,\
            train_loss, dev_loss, dev_f1))
    file_logger.log("{}\t{:.6f}\t{:.6f}\t{:.4f}".format(epoch, train_loss, dev_loss, dev_f1))

    # save
    model_file = model_save_dir + '/checkpoint_epoch_{}.pt'.format(epoch)
    model.save(model_file, epoch)
    if epoch == 1 or dev_f1 > max(dev_f1_history):
        copyfile(model_file, model_save_dir + '/best_model.pt')
        print("new best model saved.")
    if epoch % opt['save_epoch'] != 0:
        os.remove(model_file)
    
    # lr schedule
    if len(dev_f1_history) > 10 and dev_f1 <= dev_f1_history[-1] and \
            opt['optim'] in ['sgd', 'adagrad']:
        current_lr *= opt['lr_decay']
        model.update_lr(current_lr)

    dev_f1_history += [dev_f1]
    print("")

print("Training ended with {} epochs.".format(epoch))
# Out:
# J:\PyCharmProjects\tac-self-attention\model\rnn.py:166: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   weights = F.softmax(scores)
# 2018-02-14 12:18:00.039929: step 400/45030 (epoch 1/30), loss = 0.579343 (0.042 sec/batch), lr: 1.000000
# 2018-02-14 12:18:18.074894: step 800/45030 (epoch 1/30), loss = 0.486023 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:18:35.946424: step 1200/45030 (epoch 1/30), loss = 0.434787 (0.037 sec/batch), lr: 1.000000
# Evaluating on dev set...
# J:\PyCharmProjects\tac-self-attention\model\rnn.py:73: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = F.softmax(logits).data.cpu().numpy().tolist()
# Precision (micro): 52.369%
#    Recall (micro): 53.894%
#        F1 (micro): 53.121%
# epoch 1: train_loss = 0.664744, dev_loss = 0.623006, dev_f1 = 0.5312
# model saved to ./saved_models/01/checkpoint_epoch_1.pt
# new best model saved.
#
# 2018-02-14 12:19:01.447523: step 1600/45030 (epoch 2/30), loss = 0.411436 (0.048 sec/batch), lr: 1.000000
# 2018-02-14 12:19:19.471464: step 2000/45030 (epoch 2/30), loss = 0.536936 (0.045 sec/batch), lr: 1.000000
# 2018-02-14 12:19:37.956627: step 2400/45030 (epoch 2/30), loss = 0.513828 (0.048 sec/batch), lr: 1.000000
# 2018-02-14 12:19:56.191047: step 2800/45030 (epoch 2/30), loss = 0.487703 (0.045 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 57.251%
#    Recall (micro): 60.752%
#        F1 (micro): 58.950%
# epoch 2: train_loss = 0.463385, dev_loss = 0.544689, dev_f1 = 0.5895
# model saved to ./saved_models/01/checkpoint_epoch_2.pt
# new best model saved.
#
# 2018-02-14 12:20:21.464590: step 3200/45030 (epoch 3/30), loss = 0.428520 (0.038 sec/batch), lr: 1.000000
# 2018-02-14 12:20:39.700256: step 3600/45030 (epoch 3/30), loss = 0.365786 (0.051 sec/batch), lr: 1.000000
# 2018-02-14 12:20:58.172832: step 4000/45030 (epoch 3/30), loss = 0.366004 (0.047 sec/batch), lr: 1.000000
# 2018-02-14 12:21:16.436517: step 4400/45030 (epoch 3/30), loss = 0.383868 (0.043 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 58.610%
#    Recall (micro): 63.710%
#        F1 (micro): 61.053%
# epoch 3: train_loss = 0.426077, dev_loss = 0.516925, dev_f1 = 0.6105
# model saved to ./saved_models/01/checkpoint_epoch_3.pt
# new best model saved.
#
# 2018-02-14 12:21:41.920293: step 4800/45030 (epoch 4/30), loss = 0.249321 (0.039 sec/batch), lr: 1.000000
# 2018-02-14 12:21:59.861378: step 5200/45030 (epoch 4/30), loss = 0.571584 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:22:17.871913: step 5600/45030 (epoch 4/30), loss = 0.598822 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:22:35.796585: step 6000/45030 (epoch 4/30), loss = 0.318958 (0.045 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 58.125%
#    Recall (micro): 65.459%
#        F1 (micro): 61.574%
# epoch 4: train_loss = 0.405578, dev_loss = 0.513186, dev_f1 = 0.6157
# model saved to ./saved_models/01/checkpoint_epoch_4.pt
# new best model saved.
#
# 2018-02-14 12:23:00.809107: step 6400/45030 (epoch 5/30), loss = 0.436231 (0.046 sec/batch), lr: 1.000000
# 2018-02-14 12:23:18.798360: step 6800/45030 (epoch 5/30), loss = 0.254551 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:23:36.640813: step 7200/45030 (epoch 5/30), loss = 0.387002 (0.042 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 61.100%
#    Recall (micro): 66.047%
#        F1 (micro): 63.477%
# epoch 5: train_loss = 0.387228, dev_loss = 0.485868, dev_f1 = 0.6348
# model saved to ./saved_models/01/checkpoint_epoch_5.pt
# new best model saved.
#
# 2018-02-14 12:24:01.510781: step 7600/45030 (epoch 6/30), loss = 0.373938 (0.045 sec/batch), lr: 1.000000
# 2018-02-14 12:24:19.401364: step 8000/45030 (epoch 6/30), loss = 0.340615 (0.048 sec/batch), lr: 1.000000
# 2018-02-14 12:24:37.279128: step 8400/45030 (epoch 6/30), loss = 0.381086 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:24:55.111555: step 8800/45030 (epoch 6/30), loss = 0.465693 (0.039 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 62.644%
#    Recall (micro): 66.388%
#        F1 (micro): 64.462%
# epoch 6: train_loss = 0.375272, dev_loss = 0.470283, dev_f1 = 0.6446
# model saved to ./saved_models/01/checkpoint_epoch_6.pt
# new best model saved.
#
# 2018-02-14 12:25:20.236360: step 9200/45030 (epoch 7/30), loss = 0.596113 (0.048 sec/batch), lr: 1.000000
# 2018-02-14 12:25:38.095858: step 9600/45030 (epoch 7/30), loss = 0.182765 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:25:56.002591: step 10000/45030 (epoch 7/30), loss = 0.165489 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:26:13.874490: step 10400/45030 (epoch 7/30), loss = 0.118238 (0.043 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 60.661%
#    Recall (micro): 67.921%
#        F1 (micro): 64.086%
# epoch 7: train_loss = 0.359511, dev_loss = 0.483317, dev_f1 = 0.6409
# model saved to ./saved_models/01/checkpoint_epoch_7.pt
#
# 2018-02-14 12:26:38.586213: step 10800/45030 (epoch 8/30), loss = 0.318004 (0.045 sec/batch), lr: 1.000000
# 2018-02-14 12:26:56.428667: step 11200/45030 (epoch 8/30), loss = 0.389442 (0.045 sec/batch), lr: 1.000000
# 2018-02-14 12:27:14.337058: step 11600/45030 (epoch 8/30), loss = 0.312361 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:27:32.198591: step 12000/45030 (epoch 8/30), loss = 0.258007 (0.041 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 64.610%
#    Recall (micro): 65.831%
#        F1 (micro): 65.215%
# epoch 8: train_loss = 0.351201, dev_loss = 0.460905, dev_f1 = 0.6521
# model saved to ./saved_models/01/checkpoint_epoch_8.pt
# new best model saved.
#
# 2018-02-14 12:27:56.934623: step 12400/45030 (epoch 9/30), loss = 0.267103 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:28:14.945501: step 12800/45030 (epoch 9/30), loss = 0.250259 (0.047 sec/batch), lr: 1.000000
# 2018-02-14 12:28:32.871176: step 13200/45030 (epoch 9/30), loss = 0.360552 (0.045 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 63.208%
#    Recall (micro): 67.240%
#        F1 (micro): 65.161%
# epoch 9: train_loss = 0.339582, dev_loss = 0.460604, dev_f1 = 0.6516
# model saved to ./saved_models/01/checkpoint_epoch_9.pt
#
# 2018-02-14 12:28:57.730291: step 13600/45030 (epoch 10/30), loss = 0.345577 (0.042 sec/batch), lr: 1.000000
# 2018-02-14 12:29:15.658973: step 14000/45030 (epoch 10/30), loss = 0.362668 (0.045 sec/batch), lr: 1.000000
# 2018-02-14 12:29:33.576788: step 14400/45030 (epoch 10/30), loss = 0.270442 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:29:51.458204: step 14800/45030 (epoch 10/30), loss = 0.531344 (0.040 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 64.704%
#    Recall (micro): 67.379%
#        F1 (micro): 66.014%
# epoch 10: train_loss = 0.331607, dev_loss = 0.451929, dev_f1 = 0.6601
# model saved to ./saved_models/01/checkpoint_epoch_10.pt
# new best model saved.
#
# 2018-02-14 12:30:16.522135: step 15200/45030 (epoch 11/30), loss = 0.469018 (0.039 sec/batch), lr: 1.000000
# 2018-02-14 12:30:34.498946: step 15600/45030 (epoch 11/30), loss = 0.315745 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:30:52.423618: step 16000/45030 (epoch 11/30), loss = 0.319377 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:31:10.369056: step 16400/45030 (epoch 11/30), loss = 0.169399 (0.043 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 65.037%
#    Recall (micro): 66.125%
#        F1 (micro): 65.577%
# epoch 11: train_loss = 0.325981, dev_loss = 0.448572, dev_f1 = 0.6558
# model saved to ./saved_models/01/checkpoint_epoch_11.pt
#
# 2018-02-14 12:31:35.372555: step 16800/45030 (epoch 12/30), loss = 0.511457 (0.038 sec/batch), lr: 1.000000
# 2018-02-14 12:31:53.255114: step 17200/45030 (epoch 12/30), loss = 0.315057 (0.041 sec/batch), lr: 1.000000
# 2018-02-14 12:32:11.202848: step 17600/45030 (epoch 12/30), loss = 0.252069 (0.040 sec/batch), lr: 1.000000
# 2018-02-14 12:32:29.126238: step 18000/45030 (epoch 12/30), loss = 0.355880 (0.047 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 64.046%
#    Recall (micro): 67.348%
#        F1 (micro): 65.655%
# epoch 12: train_loss = 0.316329, dev_loss = 0.457902, dev_f1 = 0.6566
# model saved to ./saved_models/01/checkpoint_epoch_12.pt
#
# 2018-02-14 12:32:54.207461: step 18400/45030 (epoch 13/30), loss = 0.437062 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:33:12.124111: step 18800/45030 (epoch 13/30), loss = 0.230699 (0.039 sec/batch), lr: 1.000000
# 2018-02-14 12:33:30.006024: step 19200/45030 (epoch 13/30), loss = 0.195813 (0.045 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 65.214%
#    Recall (micro): 67.425%
#        F1 (micro): 66.301%
# epoch 13: train_loss = 0.309670, dev_loss = 0.449841, dev_f1 = 0.6630
# model saved to ./saved_models/01/checkpoint_epoch_13.pt
# new best model saved.
#
# 2018-02-14 12:33:55.052740: step 19600/45030 (epoch 14/30), loss = 0.202326 (0.038 sec/batch), lr: 1.000000
# 2018-02-14 12:34:12.925273: step 20000/45030 (epoch 14/30), loss = 0.241685 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:34:30.813551: step 20400/45030 (epoch 14/30), loss = 0.313758 (0.046 sec/batch), lr: 1.000000
# 2018-02-14 12:34:48.668037: step 20800/45030 (epoch 14/30), loss = 0.207040 (0.042 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 66.776%
#    Recall (micro): 66.094%
#        F1 (micro): 66.433%
# epoch 14: train_loss = 0.302735, dev_loss = 0.445913, dev_f1 = 0.6643
# model saved to ./saved_models/01/checkpoint_epoch_14.pt
# new best model saved.
#
# 2018-02-14 12:35:13.566026: step 21200/45030 (epoch 15/30), loss = 0.551980 (0.041 sec/batch), lr: 1.000000
# 2018-02-14 12:35:31.441631: step 21600/45030 (epoch 15/30), loss = 0.190361 (0.038 sec/batch), lr: 1.000000
# 2018-02-14 12:35:49.323342: step 22000/45030 (epoch 15/30), loss = 0.259568 (0.038 sec/batch), lr: 1.000000
# 2018-02-14 12:36:07.236052: step 22400/45030 (epoch 15/30), loss = 0.428814 (0.043 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 65.976%
#    Recall (micro): 67.518%
#        F1 (micro): 66.738%
# epoch 15: train_loss = 0.295355, dev_loss = 0.454698, dev_f1 = 0.6674
# model saved to ./saved_models/01/checkpoint_epoch_15.pt
# new best model saved.
#
# 2018-02-14 12:36:32.458671: step 22800/45030 (epoch 16/30), loss = 0.339725 (0.041 sec/batch), lr: 1.000000
# 2018-02-14 12:36:50.336218: step 23200/45030 (epoch 16/30), loss = 0.310790 (0.043 sec/batch), lr: 1.000000
# 2018-02-14 12:37:08.295983: step 23600/45030 (epoch 16/30), loss = 0.167656 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:37:26.176538: step 24000/45030 (epoch 16/30), loss = 0.366856 (0.043 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 65.504%
#    Recall (micro): 68.617%
#        F1 (micro): 67.025%
# epoch 16: train_loss = 0.289900, dev_loss = 0.455458, dev_f1 = 0.6702
# model saved to ./saved_models/01/checkpoint_epoch_16.pt
# new best model saved.
#
# 2018-02-14 12:37:51.053700: step 24400/45030 (epoch 17/30), loss = 0.304505 (0.040 sec/batch), lr: 1.000000
# 2018-02-14 12:38:08.929242: step 24800/45030 (epoch 17/30), loss = 0.257385 (0.044 sec/batch), lr: 1.000000
# 2018-02-14 12:38:26.728580: step 25200/45030 (epoch 17/30), loss = 0.282713 (0.037 sec/batch), lr: 1.000000
# Evaluating on dev set...
# Precision (micro): 64.793%
#    Recall (micro): 67.270%
#        F1 (micro): 66.008%
# epoch 17: train_loss = 0.284838, dev_loss = 0.460802, dev_f1 = 0.6601
# model saved to ./saved_models/01/checkpoint_epoch_17.pt
#
# 2018-02-14 12:38:51.732079: step 25600/45030 (epoch 18/30), loss = 0.183178 (0.047 sec/batch), lr: 0.900000
# 2018-02-14 12:39:09.649733: step 26000/45030 (epoch 18/30), loss = 0.217201 (0.041 sec/batch), lr: 0.900000
# 2018-02-14 12:39:27.549338: step 26400/45030 (epoch 18/30), loss = 0.250638 (0.041 sec/batch), lr: 0.900000
# 2018-02-14 12:39:45.391791: step 26800/45030 (epoch 18/30), loss = 0.422439 (0.038 sec/batch), lr: 0.900000
# Evaluating on dev set...
# Precision (micro): 67.706%
#    Recall (micro): 64.205%
#        F1 (micro): 65.909%
# epoch 18: train_loss = 0.275274, dev_loss = 0.452266, dev_f1 = 0.6591
# model saved to ./saved_models/01/checkpoint_epoch_18.pt
#
# 2018-02-14 12:40:10.218821: step 27200/45030 (epoch 19/30), loss = 0.270113 (0.039 sec/batch), lr: 0.810000
# 2018-02-14 12:40:28.073306: step 27600/45030 (epoch 19/30), loss = 0.139141 (0.038 sec/batch), lr: 0.810000
# 2018-02-14 12:40:45.880666: step 28000/45030 (epoch 19/30), loss = 0.114053 (0.042 sec/batch), lr: 0.810000
# 2018-02-14 12:41:04.159724: step 28400/45030 (epoch 19/30), loss = 0.298878 (0.043 sec/batch), lr: 0.810000
# Evaluating on dev set...
# Precision (micro): 66.562%
#    Recall (micro): 65.645%
#        F1 (micro): 66.100%
# epoch 19: train_loss = 0.266635, dev_loss = 0.466423, dev_f1 = 0.6610
# model saved to ./saved_models/01/checkpoint_epoch_19.pt
#
# 2018-02-14 12:41:29.681979: step 28800/45030 (epoch 20/30), loss = 0.311799 (0.038 sec/batch), lr: 0.810000
# 2018-02-14 12:41:48.055094: step 29200/45030 (epoch 20/30), loss = 0.198333 (0.053 sec/batch), lr: 0.810000
# 2018-02-14 12:42:06.083041: step 29600/45030 (epoch 20/30), loss = 0.158803 (0.040 sec/batch), lr: 0.810000
# 2018-02-14 12:42:24.025761: step 30000/45030 (epoch 20/30), loss = 0.230454 (0.041 sec/batch), lr: 0.810000
# Evaluating on dev set...
# Precision (micro): 63.247%
#    Recall (micro): 67.673%
#        F1 (micro): 65.385%
# epoch 20: train_loss = 0.261555, dev_loss = 0.486908, dev_f1 = 0.6539
# model saved to ./saved_models/01/checkpoint_epoch_20.pt
#
# 2018-02-14 12:42:49.099446: step 30400/45030 (epoch 21/30), loss = 0.082939 (0.046 sec/batch), lr: 0.729000
# 2018-02-14 12:43:07.554529: step 30800/45030 (epoch 21/30), loss = 0.194671 (0.043 sec/batch), lr: 0.729000
# 2018-02-14 12:43:26.068769: step 31200/45030 (epoch 21/30), loss = 0.170199 (0.043 sec/batch), lr: 0.729000
# Evaluating on dev set...
# Precision (micro): 65.362%
#    Recall (micro): 66.465%
#        F1 (micro): 65.909%
# epoch 21: train_loss = 0.251494, dev_loss = 0.475977, dev_f1 = 0.6591
# model saved to ./saved_models/01/checkpoint_epoch_21.pt
#
# 2018-02-14 12:43:51.492385: step 31600/45030 (epoch 22/30), loss = 0.201958 (0.042 sec/batch), lr: 0.729000
# 2018-02-14 12:44:09.729889: step 32000/45030 (epoch 22/30), loss = 0.226910 (0.043 sec/batch), lr: 0.729000
# 2018-02-14 12:44:27.952352: step 32400/45030 (epoch 22/30), loss = 0.355745 (0.042 sec/batch), lr: 0.729000
# 2018-02-14 12:44:46.606374: step 32800/45030 (epoch 22/30), loss = 0.178854 (0.042 sec/batch), lr: 0.729000
# Evaluating on dev set...
# Precision (micro): 63.189%
#    Recall (micro): 68.834%
#        F1 (micro): 65.891%
# epoch 22: train_loss = 0.246880, dev_loss = 0.488800, dev_f1 = 0.6589
# model saved to ./saved_models/01/checkpoint_epoch_22.pt
#
# 2018-02-14 12:45:12.572148: step 33200/45030 (epoch 23/30), loss = 0.257193 (0.044 sec/batch), lr: 0.656100
# 2018-02-14 12:45:31.425289: step 33600/45030 (epoch 23/30), loss = 0.134517 (0.050 sec/batch), lr: 0.656100
# 2018-02-14 12:45:50.530313: step 34000/45030 (epoch 23/30), loss = 0.279442 (0.043 sec/batch), lr: 0.656100
# 2018-02-14 12:46:09.251102: step 34400/45030 (epoch 23/30), loss = 0.137956 (0.044 sec/batch), lr: 0.656100
# Evaluating on dev set...
# Precision (micro): 65.020%
#    Recall (micro): 67.023%
#        F1 (micro): 66.006%
# epoch 23: train_loss = 0.237895, dev_loss = 0.486517, dev_f1 = 0.6601
# model saved to ./saved_models/01/checkpoint_epoch_23.pt
#
# 2018-02-14 12:46:35.449399: step 34800/45030 (epoch 24/30), loss = 0.473859 (0.047 sec/batch), lr: 0.656100
# 2018-02-14 12:46:53.851251: step 35200/45030 (epoch 24/30), loss = 0.205750 (0.049 sec/batch), lr: 0.656100
# 2018-02-14 12:47:11.960035: step 35600/45030 (epoch 24/30), loss = 0.135644 (0.046 sec/batch), lr: 0.656100
# 2018-02-14 12:47:29.923811: step 36000/45030 (epoch 24/30), loss = 0.217334 (0.041 sec/batch), lr: 0.656100
# Evaluating on dev set...
# Precision (micro): 66.635%
#    Recall (micro): 66.109%
#        F1 (micro): 66.371%
# epoch 24: train_loss = 0.235099, dev_loss = 0.487524, dev_f1 = 0.6637
# model saved to ./saved_models/01/checkpoint_epoch_24.pt
#
# 2018-02-14 12:47:55.542947: step 36400/45030 (epoch 25/30), loss = 0.131872 (0.042 sec/batch), lr: 0.656100
# 2018-02-14 12:48:13.586937: step 36800/45030 (epoch 25/30), loss = 0.196694 (0.048 sec/batch), lr: 0.656100
# 2018-02-14 12:48:31.509603: step 37200/45030 (epoch 25/30), loss = 0.139395 (0.044 sec/batch), lr: 0.656100
# Evaluating on dev set...
# Precision (micro): 67.019%
#    Recall (micro): 63.864%
#        F1 (micro): 65.404%
# epoch 25: train_loss = 0.232154, dev_loss = 0.479291, dev_f1 = 0.6540
# model saved to ./saved_models/01/checkpoint_epoch_25.pt
#
# 2018-02-14 12:48:56.533155: step 37600/45030 (epoch 26/30), loss = 0.114388 (0.043 sec/batch), lr: 0.590490
# 2018-02-14 12:49:14.440782: step 38000/45030 (epoch 26/30), loss = 0.153616 (0.038 sec/batch), lr: 0.590490
# 2018-02-14 12:49:32.353422: step 38400/45030 (epoch 26/30), loss = 0.172967 (0.046 sec/batch), lr: 0.590490
# 2018-02-14 12:49:50.275086: step 38800/45030 (epoch 26/30), loss = 0.228416 (0.047 sec/batch), lr: 0.590490
# Evaluating on dev set...
# Precision (micro): 66.836%
#    Recall (micro): 65.118%
#        F1 (micro): 65.966%
# epoch 26: train_loss = 0.223806, dev_loss = 0.490807, dev_f1 = 0.6597
# model saved to ./saved_models/01/checkpoint_epoch_26.pt
#
# 2018-02-14 12:50:15.226446: step 39200/45030 (epoch 27/30), loss = 0.096621 (0.044 sec/batch), lr: 0.590490
# 2018-02-14 12:50:33.134072: step 39600/45030 (epoch 27/30), loss = 0.409983 (0.041 sec/batch), lr: 0.590490
# 2018-02-14 12:50:51.033678: step 40000/45030 (epoch 27/30), loss = 0.230516 (0.042 sec/batch), lr: 0.590490
# 2018-02-14 12:51:08.923314: step 40400/45030 (epoch 27/30), loss = 0.232255 (0.046 sec/batch), lr: 0.590490
# Evaluating on dev set...
# Precision (micro): 67.119%
#    Recall (micro): 64.344%
#        F1 (micro): 65.702%
# epoch 27: train_loss = 0.219933, dev_loss = 0.493099, dev_f1 = 0.6570
# model saved to ./saved_models/01/checkpoint_epoch_27.pt
#
# 2018-02-14 12:51:34.255687: step 40800/45030 (epoch 28/30), loss = 0.176615 (0.039 sec/batch), lr: 0.531441
# 2018-02-14 12:51:52.101149: step 41200/45030 (epoch 28/30), loss = 0.176443 (0.046 sec/batch), lr: 0.531441
# 2018-02-14 12:52:10.068935: step 41600/45030 (epoch 28/30), loss = 0.143398 (0.042 sec/batch), lr: 0.531441
# 2018-02-14 12:52:27.991369: step 42000/45030 (epoch 28/30), loss = 0.195805 (0.042 sec/batch), lr: 0.531441
# Evaluating on dev set...
# Precision (micro): 67.128%
#    Recall (micro): 63.833%
#        F1 (micro): 65.439%
# epoch 28: train_loss = 0.215085, dev_loss = 0.500732, dev_f1 = 0.6544
# model saved to ./saved_models/01/checkpoint_epoch_28.pt
#
# 2018-02-14 12:52:53.461108: step 42400/45030 (epoch 29/30), loss = 0.248295 (0.039 sec/batch), lr: 0.478297
# 2018-02-14 12:53:11.368735: step 42800/45030 (epoch 29/30), loss = 0.251032 (0.046 sec/batch), lr: 0.478297
# 2018-02-14 12:53:29.209183: step 43200/45030 (epoch 29/30), loss = 0.053539 (0.044 sec/batch), lr: 0.478297
# Evaluating on dev set...
# Precision (micro): 65.872%
#    Recall (micro): 63.741%
#        F1 (micro): 64.789%
# epoch 29: train_loss = 0.211894, dev_loss = 0.508141, dev_f1 = 0.6479
# model saved to ./saved_models/01/checkpoint_epoch_29.pt
#
# 2018-02-14 12:53:54.001119: step 43600/45030 (epoch 30/30), loss = 0.182911 (0.039 sec/batch), lr: 0.430467
# 2018-02-14 12:54:11.981940: step 44000/45030 (epoch 30/30), loss = 0.297465 (0.040 sec/batch), lr: 0.430467
# 2018-02-14 12:54:29.967775: step 44400/45030 (epoch 30/30), loss = 0.074140 (0.043 sec/batch), lr: 0.430467
# 2018-02-14 12:54:47.948012: step 44800/45030 (epoch 30/30), loss = 0.192286 (0.043 sec/batch), lr: 0.430467
# Evaluating on dev set...
# Precision (micro): 66.758%
#    Recall (micro): 64.422%
#        F1 (micro): 65.569%
# epoch 30: train_loss = 0.204141, dev_loss = 0.510558, dev_f1 = 0.6557
# model saved to ./saved_models/01/checkpoint_epoch_30.pt
#
# Training ended with 30 epochs.
