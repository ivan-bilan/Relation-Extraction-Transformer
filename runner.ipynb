# %%
"""
Train a model on TACRED.
"""

import os
from datetime import datetime
import time
import numpy as np
import random
import argparse
from shutil import copyfile
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from data.loader import DataLoader
from model.rnn import RelationModel
from utils import scorer, constant, helper
from utils.vocab import Vocab

# %%
print(torch.__version__)
# Out:
# 0.3.1.post2

# %%
import argparse
import sys; sys.argv=['']; del sys  # this has to be done if argparse is used in the notebook
from datetime import datetime

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--data_dir', type=str, default='dataset/tacred')
parser.add_argument('--vocab_dir', type=str, default='dataset/vocab')
parser.add_argument('--emb_dim', type=int, default=300, help='Word embedding dimension.')
parser.add_argument('--ner_dim', type=int, default=30, help='NER embedding dimension.')
parser.add_argument('--pos_dim', type=int, default=30, help='POS embedding dimension.')
parser.add_argument('--hidden_dim', type=int, default=360, help='RNN hidden state size.')            # 200 original
parser.add_argument('--num_layers', type=int, default=2, help='Num of self-attention layers.')
parser.add_argument('--dropout', type=float, default=0.2, help='Input and RNN dropout rate.')        # 0.5 original
parser.add_argument('--word_dropout', type=float, default=0.04,                                      # 0.04
                    help='The rate at which randomly set a word to UNK.'
                   )

parser.add_argument('--topn', type=int, default=1e10, help='Only finetune top N embeddings.')
parser.add_argument('--lower', dest='lower', action='store_true', help='Lowercase all words.',
                   default=True)
parser.add_argument('--no-lower', dest='lower', action='store_false')
parser.set_defaults(lower=False)

parser.add_argument(
    '--self-attn', dest='self_att', action='store_true', 
    help='Use self-attention layer instead of LSTM.', default=True
)

parser.add_argument('--attn', dest='attn', action='store_true', help='Use attention layer.', default="true")
parser.add_argument('--no-attn', dest='attn', action='store_false')
parser.set_defaults(attn=True)

parser.add_argument('--attn_dim', type=int, default=200, help='Attention size.')                    # 200 original
parser.add_argument('--pe_dim', type=int, default=30, help='Position encoding dimension.')

parser.add_argument('--lr', type=float, default=0.2, help='Applies to SGD and Adagrad.')            # lr 1.0 orig
parser.add_argument('--lr_decay', type=float, default=0.9)                                          # lr_decay 0.9 original
parser.add_argument('--optim', type=str, default='sgd', help='sgd, adagrad, adam or adamax.')       # sgd original
parser.add_argument('--num_epoch', type=int, default=100)                                           # epochs 30 original
parser.add_argument('--batch_size', type=int, default=50)                                           # batch size 50 original
parser.add_argument('--max_grad_norm', type=float, default=5.0, help='Gradient clipping.')
parser.add_argument('--log_step', type=int, default=400, help='Print log every k steps.')
parser.add_argument('--log', type=str, default='logs.txt', help='Write training log to file.')
parser.add_argument('--save_epoch', type=int, default=5, help='Save model checkpoints every k epochs.')
parser.add_argument('--save_dir', type=str, default='./saved_models', help='Root dir for saving models.')

parser.add_argument(
    '--id', type=str, 
    default='24_self_attention_dropout',                                 # change model folder output before running
    help='Model ID under which to save models.'
   )

parser.add_argument('--info', type=str, default='', help='Optional info for the experiment.')

parser.add_argument('--seed', type=int, default=1234)
parser.add_argument('--cuda', type=bool, default=torch.cuda.is_available())
parser.add_argument('--cpu', action='store_true', help='Ignore CUDA.')

args = parser.parse_args()

# %%
torch.manual_seed(args.seed)
np.random.seed(args.seed)
random.seed(1234)
if args.cpu:
    args.cuda = False
elif args.cuda:
    torch.cuda.manual_seed(args.seed)

# make opt
opt = vars(args)
opt['num_class'] = len(constant.LABEL_TO_ID)

# load vocab
vocab_file = opt['vocab_dir'] + '/vocab.pkl'
vocab = Vocab(vocab_file, load=True)
opt['vocab_size'] = vocab.size
emb_file = opt['vocab_dir'] + '/embedding.npy'
emb_matrix = np.load(emb_file)
assert emb_matrix.shape[0] == vocab.size
assert emb_matrix.shape[1] == opt['emb_dim']

# load data
print("Loading data from {} with batch size {}...".format(opt['data_dir'], opt['batch_size']))
train_batch = DataLoader(opt['data_dir'] + '/train.json', opt['batch_size'], opt, vocab, evaluation=False)
dev_batch = DataLoader(opt['data_dir'] + '/dev.json', opt['batch_size'], opt, vocab, evaluation=True)

model_id = opt['id'] if len(opt['id']) > 1 else '0' + opt['id']
model_save_dir = opt['save_dir'] + '/' + model_id
opt['model_save_dir'] = model_save_dir
helper.ensure_dir(model_save_dir, verbose=True)

# save config
helper.save_config(opt, model_save_dir + '/config.json', verbose=True)
vocab.save(model_save_dir + '/vocab.pkl')
file_logger = helper.FileLogger(model_save_dir + '/' + opt['log'], header="# epoch\ttrain_loss\tdev_loss\tdev_f1")

# print model info
helper.print_config(opt)

# model
model = RelationModel(opt, emb_matrix=emb_matrix)

id2label = dict([(v,k) for k,v in constant.LABEL_TO_ID.items()])
dev_f1_history = []
current_lr = opt['lr']

global_step = 0
global_start_time = time.time()
format_str = '{}: step {}/{} (epoch {}/{}), loss = {:.6f} ({:.3f} sec/batch), lr: {:.6f}'
max_steps = len(train_batch) * opt['num_epoch']
# Out:
# Vocab size 55950 loaded from file
# Loading data from dataset/tacred with batch size 50...
# 1501 batches created for dataset/tacred/train.json
# 516 batches created for dataset/tacred/dev.json
# Config saved to file ./saved_models/24_self_attention_dropout/config.json
# Overwriting old vocab file at ./saved_models/24_self_attention_dropout/vocab.pkl
#
# Running with the following configs:
# 	data_dir : dataset/tacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 360
# 	num_layers : 2
# 	dropout : 0.2
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	self_att : True
# 	attn : True
# 	attn_dim : 200
# 	pe_dim : 30
# 	lr : 0.2
# 	lr_decay : 0.9
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 400
# 	log : logs.txt
# 	save_epoch : 5
# 	save_dir : ./saved_models
# 	id : 24_self_attention_dropout
# 	info :
# 	seed : 1234
# 	cuda : True
# 	cpu : False
# 	num_class : 42
# 	vocab_size : 55950
# 	model_save_dir : ./saved_models/24_self_attention_dropout
#
#
# Finetune all embeddings.
# using weights [1.0, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8]

# %%
# start training
for epoch in range(1, opt['num_epoch']+1):
    train_loss = 0
    for i, batch in enumerate(train_batch):
        start_time = time.time()
        global_step += 1
        loss = model.update(batch)
        train_loss += loss
        if global_step % opt['log_step'] == 0:
            duration = time.time() - start_time
            print(
                format_str.format(datetime.now(), global_step, max_steps, epoch,
                opt['num_epoch'], loss, duration, current_lr)
            )
        # do garbage collection, as per https://discuss.pytorch.org/t/best-practices-for-maximum-gpu-utilization/13863/6
        del loss

    # eval on dev
    print("Evaluating on dev set...")
    predictions = []
    dev_loss = 0
    for i, batch in enumerate(dev_batch):
        preds, _, loss = model.predict(batch)
        predictions += preds
        dev_loss += loss
        
    predictions = [id2label[p] for p in predictions]
    dev_p, dev_r, dev_f1 = scorer.score(dev_batch.gold(), predictions)
    
    train_loss = train_loss / train_batch.num_examples * opt['batch_size'] # avg loss per batch
    dev_loss = dev_loss / dev_batch.num_examples * opt['batch_size']
    print(
        "epoch {}: train_loss = {:.6f}, dev_loss = {:.6f}, dev_f1 = {:.4f}".format(epoch,\
            train_loss, dev_loss, dev_f1)
        )
    file_logger.log("{}\t{:.6f}\t{:.6f}\t{:.4f}".format(epoch, train_loss, dev_loss, dev_f1))

    # save
    model_file = model_save_dir + '/checkpoint_epoch_{}.pt'.format(epoch)
    model.save(model_file, epoch)
    if epoch == 1 or dev_f1 > max(dev_f1_history):
        copyfile(model_file, model_save_dir + '/best_model.pt')
        print("new best model saved.")
    if epoch % opt['save_epoch'] != 0:
        os.remove(model_file)
    
    # lr schedule
    if len(dev_f1_history) > 10 and dev_f1 <= dev_f1_history[-1] and opt['optim'] in ['sgd', 'adagrad', 'adam']:
        current_lr *= opt['lr_decay']
        model.update_lr(current_lr)

    dev_f1_history += [dev_f1]
    print("")

print("Training ended with {} epochs.".format(epoch))

# !!!!!!!! change the model output folder !!!!!!!!!!!
# Out:
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\nn\modules\module.py:357: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   result = self.forward(*input, **kwargs)
# 2018-03-11 08:50:55.338441: step 400/150100 (epoch 1/100), loss = 0.412174 (0.049 sec/batch), lr: 0.200000
# 2018-03-11 08:51:18.168179: step 800/150100 (epoch 1/100), loss = 0.478000 (0.061 sec/batch), lr: 0.200000
# 2018-03-11 08:51:41.425053: step 1200/150100 (epoch 1/100), loss = 0.549372 (0.045 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 3973.0 / guessed_by_relation= 10550.0
# Calculating Recall: correct_by_relation= 3973.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 37.659%
#    Recall (micro): 61.511%
#        F1 (micro): 46.716%
# epoch 1: train_loss = 0.662512, dev_loss = 0.886191, dev_f1 = 0.4672
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_1.pt
# new best model saved.
#
# 2018-03-11 08:52:17.497616: step 1600/150100 (epoch 2/100), loss = 0.436146 (0.061 sec/batch), lr: 0.200000
# 2018-03-11 08:52:41.167589: step 2000/150100 (epoch 2/100), loss = 0.635653 (0.058 sec/batch), lr: 0.200000
# 2018-03-11 08:53:04.272954: step 2400/150100 (epoch 2/100), loss = 0.596624 (0.058 sec/batch), lr: 0.200000
# 2018-03-11 08:53:27.532836: step 2800/150100 (epoch 2/100), loss = 0.707241 (0.061 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4152.0 / guessed_by_relation= 10216.0
# Calculating Recall: correct_by_relation= 4152.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 40.642%
#    Recall (micro): 64.282%
#        F1 (micro): 49.799%
# epoch 2: train_loss = 0.495748, dev_loss = 0.786875, dev_f1 = 0.4980
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_2.pt
# new best model saved.
#
# 2018-03-11 08:54:02.261467: step 3200/150100 (epoch 3/100), loss = 0.434667 (0.050 sec/batch), lr: 0.200000
# 2018-03-11 08:54:25.786053: step 3600/150100 (epoch 3/100), loss = 0.384901 (0.058 sec/batch), lr: 0.200000
# 2018-03-11 08:54:49.156575: step 4000/150100 (epoch 3/100), loss = 0.359102 (0.065 sec/batch), lr: 0.200000
# 2018-03-11 08:55:12.608786: step 4400/150100 (epoch 3/100), loss = 0.378661 (0.056 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4041.0 / guessed_by_relation= 8419.0
# Calculating Recall: correct_by_relation= 4041.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 47.999%
#    Recall (micro): 62.564%
#        F1 (micro): 54.322%
# epoch 3: train_loss = 0.460867, dev_loss = 0.636951, dev_f1 = 0.5432
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_3.pt
# new best model saved.
#
# 2018-03-11 08:56:13.446644: step 4800/150100 (epoch 4/100), loss = 0.328119 (0.106 sec/batch), lr: 0.200000
# 2018-03-11 08:56:59.797403: step 5200/150100 (epoch 4/100), loss = 0.656902 (0.108 sec/batch), lr: 0.200000
# 2018-03-11 08:57:45.731610: step 5600/150100 (epoch 4/100), loss = 0.740269 (0.124 sec/batch), lr: 0.200000
# 2018-03-11 08:58:30.550850: step 6000/150100 (epoch 4/100), loss = 0.270011 (0.061 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4074.0 / guessed_by_relation= 8500.0
# Calculating Recall: correct_by_relation= 4074.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 47.929%
#    Recall (micro): 63.075%
#        F1 (micro): 54.469%
# epoch 4: train_loss = 0.441430, dev_loss = 0.661025, dev_f1 = 0.5447
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_4.pt
# new best model saved.
#
# 2018-03-11 08:59:36.377982: step 6400/150100 (epoch 5/100), loss = 0.480190 (0.120 sec/batch), lr: 0.200000
# 2018-03-11 09:00:22.171816: step 6800/150100 (epoch 5/100), loss = 0.251567 (0.111 sec/batch), lr: 0.200000
# 2018-03-11 09:01:07.686907: step 7200/150100 (epoch 5/100), loss = 0.582820 (0.106 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4444.0 / guessed_by_relation= 9846.0
# Calculating Recall: correct_by_relation= 4444.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 45.135%
#    Recall (micro): 68.803%
#        F1 (micro): 54.511%
# epoch 5: train_loss = 0.430881, dev_loss = 0.723208, dev_f1 = 0.5451
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_5.pt
# new best model saved.
#
# 2018-03-11 09:02:11.185569: step 7600/150100 (epoch 6/100), loss = 0.443801 (0.117 sec/batch), lr: 0.200000
# 2018-03-11 09:02:57.545447: step 8000/150100 (epoch 6/100), loss = 0.285823 (0.124 sec/batch), lr: 0.200000
# 2018-03-11 09:03:44.216398: step 8400/150100 (epoch 6/100), loss = 0.412223 (0.116 sec/batch), lr: 0.200000
# 2018-03-11 09:04:29.968710: step 8800/150100 (epoch 6/100), loss = 0.431338 (0.107 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4624.0 / guessed_by_relation= 10694.0
# Calculating Recall: correct_by_relation= 4624.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 43.239%
#    Recall (micro): 71.590%
#        F1 (micro): 53.915%
# epoch 6: train_loss = 0.424571, dev_loss = 0.775367, dev_f1 = 0.5391
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_6.pt
#
# 2018-03-11 09:05:33.844461: step 9200/150100 (epoch 7/100), loss = 0.571959 (0.119 sec/batch), lr: 0.200000
# 2018-03-11 09:06:19.658759: step 9600/150100 (epoch 7/100), loss = 0.285932 (0.124 sec/batch), lr: 0.200000
# 2018-03-11 09:07:05.573916: step 10000/150100 (epoch 7/100), loss = 0.264206 (0.115 sec/batch), lr: 0.200000
# 2018-03-11 09:07:51.333658: step 10400/150100 (epoch 7/100), loss = 0.235509 (0.106 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4555.0 / guessed_by_relation= 10176.0
# Calculating Recall: correct_by_relation= 4555.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 44.762%
#    Recall (micro): 70.522%
#        F1 (micro): 54.764%
# epoch 7: train_loss = 0.416319, dev_loss = 0.725440, dev_f1 = 0.5476
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_7.pt
# new best model saved.
#
# 2018-03-11 09:08:56.033903: step 10800/150100 (epoch 8/100), loss = 0.396515 (0.122 sec/batch), lr: 0.200000
# 2018-03-11 09:09:41.937280: step 11200/150100 (epoch 8/100), loss = 0.543301 (0.112 sec/batch), lr: 0.200000
# 2018-03-11 09:10:28.246011: step 11600/150100 (epoch 8/100), loss = 0.490519 (0.118 sec/batch), lr: 0.200000
# 2018-03-11 09:11:13.630366: step 12000/150100 (epoch 8/100), loss = 0.205919 (0.094 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4321.0 / guessed_by_relation= 8876.0
# Calculating Recall: correct_by_relation= 4321.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 48.682%
#    Recall (micro): 66.899%
#        F1 (micro): 56.355%
# epoch 8: train_loss = 0.407199, dev_loss = 0.625401, dev_f1 = 0.5635
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_8.pt
# new best model saved.
#
# 2018-03-11 09:12:19.469118: step 12400/150100 (epoch 9/100), loss = 0.468263 (0.119 sec/batch), lr: 0.200000
# 2018-03-11 09:13:06.432783: step 12800/150100 (epoch 9/100), loss = 0.314970 (0.123 sec/batch), lr: 0.200000
# 2018-03-11 09:13:53.205283: step 13200/150100 (epoch 9/100), loss = 0.503411 (0.118 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4547.0 / guessed_by_relation= 9694.0
# Calculating Recall: correct_by_relation= 4547.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 46.905%
#    Recall (micro): 70.398%
#        F1 (micro): 56.299%
# epoch 9: train_loss = 0.405305, dev_loss = 0.697765, dev_f1 = 0.5630
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_9.pt
#
# 2018-03-11 09:14:58.567675: step 13600/150100 (epoch 10/100), loss = 0.420571 (0.117 sec/batch), lr: 0.200000
# 2018-03-11 09:15:44.508915: step 14000/150100 (epoch 10/100), loss = 0.546695 (0.120 sec/batch), lr: 0.200000
# 2018-03-11 09:16:30.457282: step 14400/150100 (epoch 10/100), loss = 0.266179 (0.116 sec/batch), lr: 0.200000
# 2018-03-11 09:17:16.489834: step 14800/150100 (epoch 10/100), loss = 0.547013 (0.100 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4531.0 / guessed_by_relation= 9290.0
# Calculating Recall: correct_by_relation= 4531.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 48.773%
#    Recall (micro): 70.150%
#        F1 (micro): 57.540%
# epoch 10: train_loss = 0.396721, dev_loss = 0.634133, dev_f1 = 0.5754
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_10.pt
# new best model saved.
#
# 2018-03-11 09:18:21.098013: step 15200/150100 (epoch 11/100), loss = 0.531011 (0.104 sec/batch), lr: 0.200000
# 2018-03-11 09:19:07.122365: step 15600/150100 (epoch 11/100), loss = 0.479312 (0.118 sec/batch), lr: 0.200000
# 2018-03-11 09:19:53.132274: step 16000/150100 (epoch 11/100), loss = 0.367281 (0.113 sec/batch), lr: 0.200000
# 2018-03-11 09:20:39.276705: step 16400/150100 (epoch 11/100), loss = 0.317465 (0.115 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4663.0 / guessed_by_relation= 9756.0
# Calculating Recall: correct_by_relation= 4663.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 47.796%
#    Recall (micro): 72.194%
#        F1 (micro): 57.515%
# epoch 11: train_loss = 0.389770, dev_loss = 0.676935, dev_f1 = 0.5751
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_11.pt
#
# 2018-03-11 09:21:52.261817: step 16800/150100 (epoch 12/100), loss = 0.743607 (0.153 sec/batch), lr: 0.200000
# 2018-03-11 09:23:01.119096: step 17200/150100 (epoch 12/100), loss = 0.319910 (0.166 sec/batch), lr: 0.200000
# 2018-03-11 09:24:01.656563: step 17600/150100 (epoch 12/100), loss = 0.324573 (0.111 sec/batch), lr: 0.200000
# 2018-03-11 09:24:46.968113: step 18000/150100 (epoch 12/100), loss = 0.282996 (0.114 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4439.0 / guessed_by_relation= 8500.0
# Calculating Recall: correct_by_relation= 4439.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.224%
#    Recall (micro): 68.726%
#        F1 (micro): 59.349%
# epoch 12: train_loss = 0.382399, dev_loss = 0.573105, dev_f1 = 0.5935
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_12.pt
# new best model saved.
#
# 2018-03-11 09:25:51.731378: step 18400/150100 (epoch 13/100), loss = 0.532067 (0.111 sec/batch), lr: 0.200000
# 2018-03-11 09:26:38.072644: step 18800/150100 (epoch 13/100), loss = 0.203102 (0.101 sec/batch), lr: 0.200000
# 2018-03-11 09:27:25.511633: step 19200/150100 (epoch 13/100), loss = 0.324596 (0.118 sec/batch), lr: 0.200000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4570.0 / guessed_by_relation= 8987.0
# Calculating Recall: correct_by_relation= 4570.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 50.851%
#    Recall (micro): 70.754%
#        F1 (micro): 59.174%
# epoch 13: train_loss = 0.374965, dev_loss = 0.598747, dev_f1 = 0.5917
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_13.pt
#
# 2018-03-11 09:28:30.714342: step 19600/150100 (epoch 14/100), loss = 0.220558 (0.095 sec/batch), lr: 0.180000
# 2018-03-11 09:29:17.389393: step 20000/150100 (epoch 14/100), loss = 0.405609 (0.121 sec/batch), lr: 0.180000
# 2018-03-11 09:30:04.753404: step 20400/150100 (epoch 14/100), loss = 0.357601 (0.121 sec/batch), lr: 0.180000
# 2018-03-11 09:30:51.220027: step 20800/150100 (epoch 14/100), loss = 0.289626 (0.113 sec/batch), lr: 0.180000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4662.0 / guessed_by_relation= 9618.0
# Calculating Recall: correct_by_relation= 4662.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 48.472%
#    Recall (micro): 72.178%
#        F1 (micro): 57.996%
# epoch 14: train_loss = 0.368135, dev_loss = 0.656898, dev_f1 = 0.5800
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_14.pt
#
# 2018-03-11 09:31:55.095526: step 21200/150100 (epoch 15/100), loss = 0.476458 (0.114 sec/batch), lr: 0.162000
# 2018-03-11 09:32:40.779066: step 21600/150100 (epoch 15/100), loss = 0.361376 (0.107 sec/batch), lr: 0.162000
# 2018-03-11 09:33:26.527473: step 22000/150100 (epoch 15/100), loss = 0.254009 (0.098 sec/batch), lr: 0.162000
# 2018-03-11 09:34:12.354379: step 22400/150100 (epoch 15/100), loss = 0.401405 (0.121 sec/batch), lr: 0.162000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4501.0 / guessed_by_relation= 8559.0
# Calculating Recall: correct_by_relation= 4501.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 52.588%
#    Recall (micro): 69.686%
#        F1 (micro): 59.941%
# epoch 15: train_loss = 0.359609, dev_loss = 0.574157, dev_f1 = 0.5994
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_15.pt
# new best model saved.
#
# 2018-03-11 09:35:16.257249: step 22800/150100 (epoch 16/100), loss = 0.276796 (0.111 sec/batch), lr: 0.162000
# 2018-03-11 09:36:02.005963: step 23200/150100 (epoch 16/100), loss = 0.462479 (0.111 sec/batch), lr: 0.162000
# 2018-03-11 09:36:47.681777: step 23600/150100 (epoch 16/100), loss = 0.317488 (0.112 sec/batch), lr: 0.162000
# 2018-03-11 09:37:33.120666: step 24000/150100 (epoch 16/100), loss = 0.369676 (0.113 sec/batch), lr: 0.162000
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4694.0 / guessed_by_relation= 9479.0
# Calculating Recall: correct_by_relation= 4694.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 49.520%
#    Recall (micro): 72.674%
#        F1 (micro): 58.903%
# epoch 16: train_loss = 0.355533, dev_loss = 0.620522, dev_f1 = 0.5890
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_16.pt
#
# 2018-03-11 09:38:37.061780: step 24400/150100 (epoch 17/100), loss = 0.267938 (0.116 sec/batch), lr: 0.145800
# 2018-03-11 09:39:22.882849: step 24800/150100 (epoch 17/100), loss = 0.366935 (0.112 sec/batch), lr: 0.145800
# 2018-03-11 09:40:08.581837: step 25200/150100 (epoch 17/100), loss = 0.282089 (0.109 sec/batch), lr: 0.145800
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4679.0 / guessed_by_relation= 9251.0
# Calculating Recall: correct_by_relation= 4679.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 50.578%
#    Recall (micro): 72.442%
#        F1 (micro): 59.567%
# epoch 17: train_loss = 0.348089, dev_loss = 0.608003, dev_f1 = 0.5957
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_17.pt
#
# 2018-03-11 09:41:12.504903: step 25600/150100 (epoch 18/100), loss = 0.301811 (0.119 sec/batch), lr: 0.145800
# 2018-03-11 09:41:58.266690: step 26000/150100 (epoch 18/100), loss = 0.239189 (0.115 sec/batch), lr: 0.145800
# 2018-03-11 09:42:44.100830: step 26400/150100 (epoch 18/100), loss = 0.282450 (0.118 sec/batch), lr: 0.145800
# 2018-03-11 09:43:29.774213: step 26800/150100 (epoch 18/100), loss = 0.569275 (0.113 sec/batch), lr: 0.145800
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4512.0 / guessed_by_relation= 8402.0
# Calculating Recall: correct_by_relation= 4512.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.701%
#    Recall (micro): 69.856%
#        F1 (micro): 60.723%
# epoch 18: train_loss = 0.345239, dev_loss = 0.553330, dev_f1 = 0.6072
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_18.pt
# new best model saved.
#
# 2018-03-11 09:44:33.723253: step 27200/150100 (epoch 19/100), loss = 0.463087 (0.098 sec/batch), lr: 0.145800
# 2018-03-11 09:45:19.319696: step 27600/150100 (epoch 19/100), loss = 0.248928 (0.100 sec/batch), lr: 0.145800
# 2018-03-11 09:46:05.064398: step 28000/150100 (epoch 19/100), loss = 0.180190 (0.104 sec/batch), lr: 0.145800
# 2018-03-11 09:46:50.673740: step 28400/150100 (epoch 19/100), loss = 0.308926 (0.112 sec/batch), lr: 0.145800
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4534.0 / guessed_by_relation= 8372.0
# Calculating Recall: correct_by_relation= 4534.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.157%
#    Recall (micro): 70.197%
#        F1 (micro): 61.142%
# epoch 19: train_loss = 0.340242, dev_loss = 0.558951, dev_f1 = 0.6114
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_19.pt
# new best model saved.
#
# 2018-03-11 09:47:54.187718: step 28800/150100 (epoch 20/100), loss = 0.510337 (0.095 sec/batch), lr: 0.145800
# 2018-03-11 09:48:39.664708: step 29200/150100 (epoch 20/100), loss = 0.299691 (0.119 sec/batch), lr: 0.145800
# 2018-03-11 09:49:25.239960: step 29600/150100 (epoch 20/100), loss = 0.285469 (0.097 sec/batch), lr: 0.145800
# 2018-03-11 09:50:10.700907: step 30000/150100 (epoch 20/100), loss = 0.296287 (0.103 sec/batch), lr: 0.145800
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4356.0 / guessed_by_relation= 7587.0
# Calculating Recall: correct_by_relation= 4356.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.414%
#    Recall (micro): 67.441%
#        F1 (micro): 62.025%
# epoch 20: train_loss = 0.336788, dev_loss = 0.501649, dev_f1 = 0.6202
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_20.pt
# new best model saved.
#
# 2018-03-11 09:51:15.091216: step 30400/150100 (epoch 21/100), loss = 0.219800 (0.122 sec/batch), lr: 0.145800
# 2018-03-11 09:52:00.667471: step 30800/150100 (epoch 21/100), loss = 0.288517 (0.126 sec/batch), lr: 0.145800
# 2018-03-11 09:52:46.036173: step 31200/150100 (epoch 21/100), loss = 0.299461 (0.121 sec/batch), lr: 0.145800
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4588.0 / guessed_by_relation= 8431.0
# Calculating Recall: correct_by_relation= 4588.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.418%
#    Recall (micro): 71.033%
#        F1 (micro): 61.625%
# epoch 21: train_loss = 0.331366, dev_loss = 0.545996, dev_f1 = 0.6163
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_21.pt
#
# 2018-03-11 09:53:49.459910: step 31600/150100 (epoch 22/100), loss = 0.366009 (0.112 sec/batch), lr: 0.131220
# 2018-03-11 09:54:35.044186: step 32000/150100 (epoch 22/100), loss = 0.255345 (0.118 sec/batch), lr: 0.131220
# 2018-03-11 09:55:20.623448: step 32400/150100 (epoch 22/100), loss = 0.323452 (0.103 sec/batch), lr: 0.131220
# 2018-03-11 09:56:06.042284: step 32800/150100 (epoch 22/100), loss = 0.237093 (0.110 sec/batch), lr: 0.131220
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4574.0 / guessed_by_relation= 8318.0
# Calculating Recall: correct_by_relation= 4574.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.989%
#    Recall (micro): 70.816%
#        F1 (micro): 61.907%
# epoch 22: train_loss = 0.325548, dev_loss = 0.544995, dev_f1 = 0.6191
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_22.pt
#
# 2018-03-11 09:57:10.351376: step 33200/150100 (epoch 23/100), loss = 0.156103 (0.110 sec/batch), lr: 0.131220
# 2018-03-11 09:57:55.827364: step 33600/150100 (epoch 23/100), loss = 0.235667 (0.119 sec/batch), lr: 0.131220
# 2018-03-11 09:58:41.384568: step 34000/150100 (epoch 23/100), loss = 0.455180 (0.119 sec/batch), lr: 0.131220
# 2018-03-11 09:59:26.971851: step 34400/150100 (epoch 23/100), loss = 0.165351 (0.124 sec/batch), lr: 0.131220
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4476.0 / guessed_by_relation= 8111.0
# Calculating Recall: correct_by_relation= 4476.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.184%
#    Recall (micro): 69.299%
#        F1 (micro): 61.441%
# epoch 23: train_loss = 0.322217, dev_loss = 0.536516, dev_f1 = 0.6144
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_23.pt
#
# 2018-03-11 10:00:30.761562: step 34800/150100 (epoch 24/100), loss = 0.722540 (0.109 sec/batch), lr: 0.118098
# 2018-03-11 10:01:16.224515: step 35200/150100 (epoch 24/100), loss = 0.249691 (0.111 sec/batch), lr: 0.118098
# 2018-03-11 10:02:01.777708: step 35600/150100 (epoch 24/100), loss = 0.253075 (0.118 sec/batch), lr: 0.118098
# 2018-03-11 10:02:47.332907: step 36000/150100 (epoch 24/100), loss = 0.387481 (0.103 sec/batch), lr: 0.118098
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4587.0 / guessed_by_relation= 8598.0
# Calculating Recall: correct_by_relation= 4587.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.350%
#    Recall (micro): 71.017%
#        F1 (micro): 60.928%
# epoch 24: train_loss = 0.316963, dev_loss = 0.542573, dev_f1 = 0.6093
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_24.pt
#
# 2018-03-11 10:03:52.233689: step 36400/150100 (epoch 25/100), loss = 0.295649 (0.113 sec/batch), lr: 0.106288
# 2018-03-11 10:04:38.252120: step 36800/150100 (epoch 25/100), loss = 0.314871 (0.115 sec/batch), lr: 0.106288
# 2018-03-11 10:05:23.805313: step 37200/150100 (epoch 25/100), loss = 0.190897 (0.119 sec/batch), lr: 0.106288
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4576.0 / guessed_by_relation= 8398.0
# Calculating Recall: correct_by_relation= 4576.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.489%
#    Recall (micro): 70.847%
#        F1 (micro): 61.601%
# epoch 25: train_loss = 0.311244, dev_loss = 0.537266, dev_f1 = 0.6160
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_25.pt
#
# 2018-03-11 10:06:28.939468: step 37600/150100 (epoch 26/100), loss = 0.251993 (0.105 sec/batch), lr: 0.106288
# 2018-03-11 10:07:15.256528: step 38000/150100 (epoch 26/100), loss = 0.213075 (0.107 sec/batch), lr: 0.106288
# 2018-03-11 10:08:01.269604: step 38400/150100 (epoch 26/100), loss = 0.165120 (0.107 sec/batch), lr: 0.106288
# 2018-03-11 10:08:46.917048: step 38800/150100 (epoch 26/100), loss = 0.283279 (0.120 sec/batch), lr: 0.106288
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4550.0 / guessed_by_relation= 8153.0
# Calculating Recall: correct_by_relation= 4550.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.808%
#    Recall (micro): 70.444%
#        F1 (micro): 62.278%
# epoch 26: train_loss = 0.307215, dev_loss = 0.525590, dev_f1 = 0.6228
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_26.pt
# new best model saved.
#
# 2018-03-11 10:09:51.872024: step 39200/150100 (epoch 27/100), loss = 0.123696 (0.112 sec/batch), lr: 0.106288
# 2018-03-11 10:10:38.587758: step 39600/150100 (epoch 27/100), loss = 0.543062 (0.099 sec/batch), lr: 0.106288
# 2018-03-11 10:11:25.237269: step 40000/150100 (epoch 27/100), loss = 0.331000 (0.105 sec/batch), lr: 0.106288
# 2018-03-11 10:12:12.469819: step 40400/150100 (epoch 27/100), loss = 0.418975 (0.138 sec/batch), lr: 0.106288
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4502.0 / guessed_by_relation= 8029.0
# Calculating Recall: correct_by_relation= 4502.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.072%
#    Recall (micro): 69.701%
#        F1 (micro): 62.148%
# epoch 27: train_loss = 0.304129, dev_loss = 0.525292, dev_f1 = 0.6215
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_27.pt
#
# 2018-03-11 10:13:23.772804: step 40800/150100 (epoch 28/100), loss = 0.371651 (0.099 sec/batch), lr: 0.095659
# 2018-03-11 10:14:09.450430: step 41200/150100 (epoch 28/100), loss = 0.315809 (0.115 sec/batch), lr: 0.095659
# 2018-03-11 10:14:55.260800: step 41600/150100 (epoch 28/100), loss = 0.137492 (0.113 sec/batch), lr: 0.095659
# 2018-03-11 10:15:41.105033: step 42000/150100 (epoch 28/100), loss = 0.301815 (0.114 sec/batch), lr: 0.095659
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4460.0 / guessed_by_relation= 7835.0
# Calculating Recall: correct_by_relation= 4460.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.924%
#    Recall (micro): 69.051%
#        F1 (micro): 62.404%
# epoch 28: train_loss = 0.299148, dev_loss = 0.513580, dev_f1 = 0.6240
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_28.pt
# new best model saved.
#
# 2018-03-11 10:16:45.938258: step 42400/150100 (epoch 29/100), loss = 0.404574 (0.105 sec/batch), lr: 0.095659
# 2018-03-11 10:17:32.138695: step 42800/150100 (epoch 29/100), loss = 0.466272 (0.110 sec/batch), lr: 0.095659
# 2018-03-11 10:18:18.007182: step 43200/150100 (epoch 29/100), loss = 0.161425 (0.123 sec/batch), lr: 0.095659
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4374.0 / guessed_by_relation= 7552.0
# Calculating Recall: correct_by_relation= 4374.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.918%
#    Recall (micro): 67.719%
#        F1 (micro): 62.437%
# epoch 29: train_loss = 0.295128, dev_loss = 0.505143, dev_f1 = 0.6244
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_29.pt
# new best model saved.
#
# 2018-03-11 10:19:25.002235: step 43600/150100 (epoch 30/100), loss = 0.193250 (0.105 sec/batch), lr: 0.095659
# 2018-03-11 10:20:12.359127: step 44000/150100 (epoch 30/100), loss = 0.405750 (0.111 sec/batch), lr: 0.095659
# 2018-03-11 10:21:00.744856: step 44400/150100 (epoch 30/100), loss = 0.291914 (0.126 sec/batch), lr: 0.095659
# 2018-03-11 10:21:48.982695: step 44800/150100 (epoch 30/100), loss = 0.432596 (0.127 sec/batch), lr: 0.095659
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4551.0 / guessed_by_relation= 8443.0
# Calculating Recall: correct_by_relation= 4551.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 53.903%
#    Recall (micro): 70.460%
#        F1 (micro): 61.079%
# epoch 30: train_loss = 0.292826, dev_loss = 0.557217, dev_f1 = 0.6108
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_30.pt
#
# 2018-03-11 10:22:56.466280: step 45200/150100 (epoch 31/100), loss = 0.283091 (0.127 sec/batch), lr: 0.086093
# 2018-03-11 10:23:43.373122: step 45600/150100 (epoch 31/100), loss = 0.350724 (0.119 sec/batch), lr: 0.086093
# 2018-03-11 10:24:32.667773: step 46000/150100 (epoch 31/100), loss = 0.385853 (0.132 sec/batch), lr: 0.086093
# 2018-03-11 10:25:25.870818: step 46400/150100 (epoch 31/100), loss = 0.186226 (0.146 sec/batch), lr: 0.086093
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4357.0 / guessed_by_relation= 7504.0
# Calculating Recall: correct_by_relation= 4357.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 58.062%
#    Recall (micro): 67.456%
#        F1 (micro): 62.408%
# epoch 31: train_loss = 0.287841, dev_loss = 0.509259, dev_f1 = 0.6241
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_31.pt
#
# 2018-03-11 10:26:33.016470: step 46800/150100 (epoch 32/100), loss = 0.165288 (0.123 sec/batch), lr: 0.086093
# 2018-03-11 10:27:19.043926: step 47200/150100 (epoch 32/100), loss = 0.469091 (0.123 sec/batch), lr: 0.086093
# 2018-03-11 10:28:04.841770: step 47600/150100 (epoch 32/100), loss = 0.228120 (0.120 sec/batch), lr: 0.086093
# 2018-03-11 10:28:50.731922: step 48000/150100 (epoch 32/100), loss = 0.204568 (0.115 sec/batch), lr: 0.086093
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4428.0 / guessed_by_relation= 7842.0
# Calculating Recall: correct_by_relation= 4428.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.465%
#    Recall (micro): 68.556%
#        F1 (micro): 61.926%
# epoch 32: train_loss = 0.284080, dev_loss = 0.530122, dev_f1 = 0.6193
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_32.pt
#
# 2018-03-11 10:29:55.021665: step 48400/150100 (epoch 33/100), loss = 0.401084 (0.102 sec/batch), lr: 0.077484
# 2018-03-11 10:30:41.048574: step 48800/150100 (epoch 33/100), loss = 0.631723 (0.119 sec/batch), lr: 0.077484
# 2018-03-11 10:31:26.880551: step 49200/150100 (epoch 33/100), loss = 0.193020 (0.113 sec/batch), lr: 0.077484
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4334.0 / guessed_by_relation= 7480.0
# Calculating Recall: correct_by_relation= 4334.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.941%
#    Recall (micro): 67.100%
#        F1 (micro): 62.185%
# epoch 33: train_loss = 0.278067, dev_loss = 0.509582, dev_f1 = 0.6219
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_33.pt
#
# 2018-03-11 10:32:31.382161: step 49600/150100 (epoch 34/100), loss = 0.525420 (0.096 sec/batch), lr: 0.077484
# 2018-03-11 10:33:17.378560: step 50000/150100 (epoch 34/100), loss = 0.301954 (0.119 sec/batch), lr: 0.077484
# 2018-03-11 10:34:03.322698: step 50400/150100 (epoch 34/100), loss = 0.236444 (0.101 sec/batch), lr: 0.077484
# 2018-03-11 10:34:49.102163: step 50800/150100 (epoch 34/100), loss = 0.208750 (0.116 sec/batch), lr: 0.077484
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4273.0 / guessed_by_relation= 7261.0
# Calculating Recall: correct_by_relation= 4273.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 58.849%
#    Recall (micro): 66.156%
#        F1 (micro): 62.289%
# epoch 34: train_loss = 0.275164, dev_loss = 0.504834, dev_f1 = 0.6229
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_34.pt
#
# 2018-03-11 10:35:53.496432: step 51200/150100 (epoch 35/100), loss = 0.143654 (0.120 sec/batch), lr: 0.077484
# 2018-03-11 10:36:39.413450: step 51600/150100 (epoch 35/100), loss = 0.172194 (0.122 sec/batch), lr: 0.077484
# 2018-03-11 10:37:25.407367: step 52000/150100 (epoch 35/100), loss = 0.224769 (0.102 sec/batch), lr: 0.077484
# 2018-03-11 10:38:11.333736: step 52400/150100 (epoch 35/100), loss = 0.212319 (0.111 sec/batch), lr: 0.077484
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4461.0 / guessed_by_relation= 8059.0
# Calculating Recall: correct_by_relation= 4461.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 55.354%
#    Recall (micro): 69.066%
#        F1 (micro): 61.455%
# epoch 35: train_loss = 0.270860, dev_loss = 0.546513, dev_f1 = 0.6145
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_35.pt
#
# 2018-03-11 10:39:16.234069: step 52800/150100 (epoch 36/100), loss = 0.213912 (0.092 sec/batch), lr: 0.069736
# 2018-03-11 10:40:01.969471: step 53200/150100 (epoch 36/100), loss = 0.225274 (0.125 sec/batch), lr: 0.069736
# 2018-03-11 10:40:47.858628: step 53600/150100 (epoch 36/100), loss = 0.233128 (0.091 sec/batch), lr: 0.069736
# 2018-03-11 10:41:34.467528: step 54000/150100 (epoch 36/100), loss = 0.303504 (0.119 sec/batch), lr: 0.069736
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4511.0 / guessed_by_relation= 8251.0
# Calculating Recall: correct_by_relation= 4511.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.672%
#    Recall (micro): 69.841%
#        F1 (micro): 61.332%
# epoch 36: train_loss = 0.265911, dev_loss = 0.558873, dev_f1 = 0.6133
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_36.pt
#
# 2018-03-11 10:42:40.132903: step 54400/150100 (epoch 37/100), loss = 0.206033 (0.118 sec/batch), lr: 0.062762
# 2018-03-11 10:43:28.491253: step 54800/150100 (epoch 37/100), loss = 0.188807 (0.114 sec/batch), lr: 0.062762
# 2018-03-11 10:44:16.155078: step 55200/150100 (epoch 37/100), loss = 0.353976 (0.111 sec/batch), lr: 0.062762
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4482.0 / guessed_by_relation= 8156.0
# Calculating Recall: correct_by_relation= 4482.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 54.953%
#    Recall (micro): 69.392%
#        F1 (micro): 61.334%
# epoch 37: train_loss = 0.259005, dev_loss = 0.554889, dev_f1 = 0.6133
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_37.pt
#
# 2018-03-11 10:45:21.981748: step 55600/150100 (epoch 38/100), loss = 0.161731 (0.110 sec/batch), lr: 0.062762
# 2018-03-11 10:46:08.515735: step 56000/150100 (epoch 38/100), loss = 0.166388 (0.115 sec/batch), lr: 0.062762
# 2018-03-11 10:46:54.890892: step 56400/150100 (epoch 38/100), loss = 0.378288 (0.119 sec/batch), lr: 0.062762
# 2018-03-11 10:47:41.804939: step 56800/150100 (epoch 38/100), loss = 0.163221 (0.124 sec/batch), lr: 0.062762
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4354.0 / guessed_by_relation= 7549.0
# Calculating Recall: correct_by_relation= 4354.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.677%
#    Recall (micro): 67.410%
#        F1 (micro): 62.164%
# epoch 38: train_loss = 0.258145, dev_loss = 0.528484, dev_f1 = 0.6216
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_38.pt
#
# 2018-03-11 10:48:47.354332: step 57200/150100 (epoch 39/100), loss = 0.213259 (0.119 sec/batch), lr: 0.062762
# 2018-03-11 10:49:33.156790: step 57600/150100 (epoch 39/100), loss = 0.455623 (0.113 sec/batch), lr: 0.062762
# 2018-03-11 10:50:20.552155: step 58000/150100 (epoch 39/100), loss = 0.350441 (0.124 sec/batch), lr: 0.062762
# 2018-03-11 10:51:07.805998: step 58400/150100 (epoch 39/100), loss = 0.285680 (0.111 sec/batch), lr: 0.062762
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4432.0 / guessed_by_relation= 7874.0
# Calculating Recall: correct_by_relation= 4432.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.287%
#    Recall (micro): 68.617%
#        F1 (micro): 61.843%
# epoch 39: train_loss = 0.254685, dev_loss = 0.542424, dev_f1 = 0.6184
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_39.pt
#
# 2018-03-11 10:52:13.920788: step 58800/150100 (epoch 40/100), loss = 0.292368 (0.114 sec/batch), lr: 0.056486
# 2018-03-11 10:53:01.157799: step 59200/150100 (epoch 40/100), loss = 0.297040 (0.105 sec/batch), lr: 0.056486
# 2018-03-11 10:53:47.967953: step 59600/150100 (epoch 40/100), loss = 0.240055 (0.111 sec/batch), lr: 0.056486
# 2018-03-11 10:54:35.065196: step 60000/150100 (epoch 40/100), loss = 0.414819 (0.119 sec/batch), lr: 0.056486
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4409.0 / guessed_by_relation= 7873.0
# Calculating Recall: correct_by_relation= 4409.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.002%
#    Recall (micro): 68.261%
#        F1 (micro): 61.527%
# epoch 40: train_loss = 0.247470, dev_loss = 0.552504, dev_f1 = 0.6153
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_40.pt
#
# 2018-03-11 10:55:40.944609: step 60400/150100 (epoch 41/100), loss = 0.197257 (0.114 sec/batch), lr: 0.050837
# 2018-03-11 10:56:27.974643: step 60800/150100 (epoch 41/100), loss = 0.119801 (0.114 sec/batch), lr: 0.050837
# 2018-03-11 10:57:14.355768: step 61200/150100 (epoch 41/100), loss = 0.211472 (0.122 sec/batch), lr: 0.050837
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4293.0 / guessed_by_relation= 7353.0
# Calculating Recall: correct_by_relation= 4293.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 58.384%
#    Recall (micro): 66.465%
#        F1 (micro): 62.163%
# epoch 41: train_loss = 0.241648, dev_loss = 0.530843, dev_f1 = 0.6216
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_41.pt
#
# 2018-03-11 10:58:25.905435: step 61600/150100 (epoch 42/100), loss = 0.229773 (0.121 sec/batch), lr: 0.050837
# 2018-03-11 10:59:11.798752: step 62000/150100 (epoch 42/100), loss = 0.493796 (0.108 sec/batch), lr: 0.050837
# 2018-03-11 10:59:58.199530: step 62400/150100 (epoch 42/100), loss = 0.139687 (0.111 sec/batch), lr: 0.050837
# 2018-03-11 11:00:50.305061: step 62800/150100 (epoch 42/100), loss = 0.196673 (0.108 sec/batch), lr: 0.050837
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4174.0 / guessed_by_relation= 7003.0
# Calculating Recall: correct_by_relation= 4174.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 59.603%
#    Recall (micro): 64.623%
#        F1 (micro): 62.012%
# epoch 42: train_loss = 0.240187, dev_loss = 0.518667, dev_f1 = 0.6201
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_42.pt
#
# 2018-03-11 11:01:55.590629: step 63200/150100 (epoch 43/100), loss = 0.306652 (0.115 sec/batch), lr: 0.045754
# 2018-03-11 11:02:41.377818: step 63600/150100 (epoch 43/100), loss = 0.175278 (0.120 sec/batch), lr: 0.045754
# 2018-03-11 11:03:27.341102: step 64000/150100 (epoch 43/100), loss = 0.364020 (0.123 sec/batch), lr: 0.045754
# 2018-03-11 11:04:13.429210: step 64400/150100 (epoch 43/100), loss = 0.167290 (0.128 sec/batch), lr: 0.045754
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4302.0 / guessed_by_relation= 7404.0
# Calculating Recall: correct_by_relation= 4302.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 58.104%
#    Recall (micro): 66.605%
#        F1 (micro): 62.064%
# epoch 43: train_loss = 0.234643, dev_loss = 0.539021, dev_f1 = 0.6206
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_43.pt
#
# 2018-03-11 11:05:18.768211: step 64800/150100 (epoch 44/100), loss = 0.175529 (0.118 sec/batch), lr: 0.045754
# 2018-03-11 11:06:04.754962: step 65200/150100 (epoch 44/100), loss = 0.171023 (0.114 sec/batch), lr: 0.045754
# 2018-03-11 11:06:51.881674: step 65600/150100 (epoch 44/100), loss = 0.343439 (0.120 sec/batch), lr: 0.045754
# 2018-03-11 11:07:39.484543: step 66000/150100 (epoch 44/100), loss = 0.287779 (0.097 sec/batch), lr: 0.045754
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4291.0 / guessed_by_relation= 7417.0
# Calculating Recall: correct_by_relation= 4291.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.854%
#    Recall (micro): 66.434%
#        F1 (micro): 61.848%
# epoch 44: train_loss = 0.228950, dev_loss = 0.547389, dev_f1 = 0.6185
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_44.pt
#
# 2018-03-11 11:08:46.972479: step 66400/150100 (epoch 45/100), loss = 0.208000 (0.127 sec/batch), lr: 0.041178
# 2018-03-11 11:09:33.370920: step 66800/150100 (epoch 45/100), loss = 0.142742 (0.113 sec/batch), lr: 0.041178
# 2018-03-11 11:10:19.155729: step 67200/150100 (epoch 45/100), loss = 0.380435 (0.091 sec/batch), lr: 0.041178
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4331.0 / guessed_by_relation= 7580.0
# Calculating Recall: correct_by_relation= 4331.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.137%
#    Recall (micro): 67.054%
#        F1 (micro): 61.700%
# epoch 45: train_loss = 0.227685, dev_loss = 0.561420, dev_f1 = 0.6170
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_45.pt
#
# 2018-03-11 11:11:25.302155: step 67600/150100 (epoch 46/100), loss = 0.168002 (0.123 sec/batch), lr: 0.037060
# 2018-03-11 11:12:11.229343: step 68000/150100 (epoch 46/100), loss = 0.327990 (0.100 sec/batch), lr: 0.037060
# 2018-03-11 11:12:57.183603: step 68400/150100 (epoch 46/100), loss = 0.280677 (0.092 sec/batch), lr: 0.037060
# 2018-03-11 11:13:42.785927: step 68800/150100 (epoch 46/100), loss = 0.195919 (0.101 sec/batch), lr: 0.037060
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4207.0 / guessed_by_relation= 7234.0
# Calculating Recall: correct_by_relation= 4207.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 58.156%
#    Recall (micro): 65.134%
#        F1 (micro): 61.447%
# epoch 46: train_loss = 0.220608, dev_loss = 0.543691, dev_f1 = 0.6145
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_46.pt
#
# 2018-03-11 11:14:48.354370: step 69200/150100 (epoch 47/100), loss = 0.275709 (0.110 sec/batch), lr: 0.033354
# 2018-03-11 11:15:34.116118: step 69600/150100 (epoch 47/100), loss = 0.343036 (0.117 sec/batch), lr: 0.033354
# 2018-03-11 11:16:20.059813: step 70000/150100 (epoch 47/100), loss = 0.273866 (0.108 sec/batch), lr: 0.033354
# 2018-03-11 11:17:05.792484: step 70400/150100 (epoch 47/100), loss = 0.167497 (0.107 sec/batch), lr: 0.033354
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4167.0 / guessed_by_relation= 7226.0
# Calculating Recall: correct_by_relation= 4167.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.667%
#    Recall (micro): 64.515%
#        F1 (micro): 60.899%
# epoch 47: train_loss = 0.214872, dev_loss = 0.558268, dev_f1 = 0.6090
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_47.pt
#
# 2018-03-11 11:18:11.182566: step 70800/150100 (epoch 48/100), loss = 0.273521 (0.109 sec/batch), lr: 0.030019
# 2018-03-11 11:18:56.827002: step 71200/150100 (epoch 48/100), loss = 0.372504 (0.125 sec/batch), lr: 0.030019
# 2018-03-11 11:19:42.731129: step 71600/150100 (epoch 48/100), loss = 0.049978 (0.120 sec/batch), lr: 0.030019
# 2018-03-11 11:20:28.617348: step 72000/150100 (epoch 48/100), loss = 0.129941 (0.103 sec/batch), lr: 0.030019
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4202.0 / guessed_by_relation= 7259.0
# Calculating Recall: correct_by_relation= 4202.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.887%
#    Recall (micro): 65.057%
#        F1 (micro): 61.263%
# epoch 48: train_loss = 0.210276, dev_loss = 0.564755, dev_f1 = 0.6126
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_48.pt
#
# 2018-03-11 11:21:34.568415: step 72400/150100 (epoch 49/100), loss = 0.225132 (0.097 sec/batch), lr: 0.030019
# 2018-03-11 11:22:20.282571: step 72800/150100 (epoch 49/100), loss = 0.379171 (0.124 sec/batch), lr: 0.030019
# 2018-03-11 11:23:06.109492: step 73200/150100 (epoch 49/100), loss = 0.097288 (0.100 sec/batch), lr: 0.030019
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4154.0 / guessed_by_relation= 7169.0
# Calculating Recall: correct_by_relation= 4154.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.944%
#    Recall (micro): 64.313%
#        F1 (micro): 60.963%
# epoch 49: train_loss = 0.208073, dev_loss = 0.563541, dev_f1 = 0.6096
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_49.pt
#
# 2018-03-11 11:24:11.949606: step 73600/150100 (epoch 50/100), loss = 0.237774 (0.125 sec/batch), lr: 0.027017
# 2018-03-11 11:24:57.879802: step 74000/150100 (epoch 50/100), loss = 0.131818 (0.101 sec/batch), lr: 0.027017
# 2018-03-11 11:25:43.827050: step 74400/150100 (epoch 50/100), loss = 0.190146 (0.126 sec/batch), lr: 0.027017
# 2018-03-11 11:26:29.430376: step 74800/150100 (epoch 50/100), loss = 0.121526 (0.112 sec/batch), lr: 0.027017
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4197.0 / guessed_by_relation= 7296.0
# Calculating Recall: correct_by_relation= 4197.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.525%
#    Recall (micro): 64.979%
#        F1 (micro): 61.025%
# epoch 50: train_loss = 0.203873, dev_loss = 0.582534, dev_f1 = 0.6103
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_50.pt
#
# 2018-03-11 11:27:35.662585: step 75200/150100 (epoch 51/100), loss = 0.136765 (0.120 sec/batch), lr: 0.027017
# 2018-03-11 11:28:21.414215: step 75600/150100 (epoch 51/100), loss = 0.300020 (0.121 sec/batch), lr: 0.027017
# 2018-03-11 11:29:07.341805: step 76000/150100 (epoch 51/100), loss = 0.201058 (0.123 sec/batch), lr: 0.027017
# 2018-03-11 11:29:53.095531: step 76400/150100 (epoch 51/100), loss = 0.209991 (0.114 sec/batch), lr: 0.027017
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4227.0 / guessed_by_relation= 7510.0
# Calculating Recall: correct_by_relation= 4227.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.285%
#    Recall (micro): 65.444%
#        F1 (micro): 60.520%
# epoch 51: train_loss = 0.201700, dev_loss = 0.593596, dev_f1 = 0.6052
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_51.pt
#
# 2018-03-11 11:30:58.273797: step 76800/150100 (epoch 52/100), loss = 0.298059 (0.122 sec/batch), lr: 0.024315
# 2018-03-11 11:31:43.910211: step 77200/150100 (epoch 52/100), loss = 0.107596 (0.092 sec/batch), lr: 0.024315
# 2018-03-11 11:32:29.828375: step 77600/150100 (epoch 52/100), loss = 0.189759 (0.117 sec/batch), lr: 0.024315
# 2018-03-11 11:33:15.700417: step 78000/150100 (epoch 52/100), loss = 0.144568 (0.124 sec/batch), lr: 0.024315
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4130.0 / guessed_by_relation= 7135.0
# Calculating Recall: correct_by_relation= 4130.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 57.884%
#    Recall (micro): 63.942%
#        F1 (micro): 60.762%
# epoch 52: train_loss = 0.198705, dev_loss = 0.577619, dev_f1 = 0.6076
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_52.pt
#
# 2018-03-11 11:34:21.388445: step 78400/150100 (epoch 53/100), loss = 0.276898 (0.110 sec/batch), lr: 0.024315
# 2018-03-11 11:35:07.107007: step 78800/150100 (epoch 53/100), loss = 0.173981 (0.122 sec/batch), lr: 0.024315
# 2018-03-11 11:35:52.988629: step 79200/150100 (epoch 53/100), loss = 0.109012 (0.122 sec/batch), lr: 0.024315
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4217.0 / guessed_by_relation= 7494.0
# Calculating Recall: correct_by_relation= 4217.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.272%
#    Recall (micro): 65.289%
#        F1 (micro): 60.446%
# epoch 53: train_loss = 0.195231, dev_loss = 0.600066, dev_f1 = 0.6045
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_53.pt
#
# 2018-03-11 11:36:58.959231: step 79600/150100 (epoch 54/100), loss = 0.072736 (0.119 sec/batch), lr: 0.021884
# 2018-03-11 11:37:45.010604: step 80000/150100 (epoch 54/100), loss = 0.206082 (0.100 sec/batch), lr: 0.021884
# 2018-03-11 11:38:30.971506: step 80400/150100 (epoch 54/100), loss = 0.199001 (0.106 sec/batch), lr: 0.021884
# 2018-03-11 11:39:16.482587: step 80800/150100 (epoch 54/100), loss = 0.094206 (0.117 sec/batch), lr: 0.021884
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4105.0 / guessed_by_relation= 7013.0
# Calculating Recall: correct_by_relation= 4105.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 58.534%
#    Recall (micro): 63.555%
#        F1 (micro): 60.941%
# epoch 54: train_loss = 0.190635, dev_loss = 0.583647, dev_f1 = 0.6094
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_54.pt
#
# 2018-03-11 11:40:22.251564: step 81200/150100 (epoch 55/100), loss = 0.117815 (0.091 sec/batch), lr: 0.021884
# 2018-03-11 11:41:07.960171: step 81600/150100 (epoch 55/100), loss = 0.252305 (0.117 sec/batch), lr: 0.021884
# 2018-03-11 11:41:53.820180: step 82000/150100 (epoch 55/100), loss = 0.181294 (0.121 sec/batch), lr: 0.021884
# 2018-03-11 11:42:39.494696: step 82400/150100 (epoch 55/100), loss = 0.173677 (0.108 sec/batch), lr: 0.021884
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4137.0 / guessed_by_relation= 7259.0
# Calculating Recall: correct_by_relation= 4137.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.991%
#    Recall (micro): 64.050%
#        F1 (micro): 60.315%
# epoch 55: train_loss = 0.188936, dev_loss = 0.602724, dev_f1 = 0.6031
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_55.pt
#
# 2018-03-11 11:43:44.750307: step 82800/150100 (epoch 56/100), loss = 0.123006 (0.112 sec/batch), lr: 0.019695
# 2018-03-11 11:44:30.308513: step 83200/150100 (epoch 56/100), loss = 0.104527 (0.120 sec/batch), lr: 0.019695
# 2018-03-11 11:45:16.368097: step 83600/150100 (epoch 56/100), loss = 0.169803 (0.110 sec/batch), lr: 0.019695
# 2018-03-11 11:46:02.372767: step 84000/150100 (epoch 56/100), loss = 0.146099 (0.103 sec/batch), lr: 0.019695
# Evaluating on dev set...
# Calculating Precision: correct_by_relation= 4200.0 / guessed_by_relation= 7407.0
# Calculating Recall: correct_by_relation= 4200.0 / gold_by_relation= 6459.0
# only_non_relation: 6459.0
# Precision (micro): 56.703%
#    Recall (micro): 65.026%
#        F1 (micro): 60.580%
# epoch 56: train_loss = 0.187263, dev_loss = 0.611209, dev_f1 = 0.6058
# model saved to ./saved_models/24_self_attention_dropout/checkpoint_epoch_56.pt
#
# 2018-03-11 11:47:15.566637: step 84400/150100 (epoch 57/100), loss = 0.233540 (0.137 sec/batch), lr: 0.019695
# 2018-03-11 11:48:09.266484: step 84800/150100 (epoch 57/100), loss = 0.280255 (0.107 sec/batch), lr: 0.019695
# 2018-03-11 11:48:55.168346: step 85200/150100 (epoch 57/100), loss = 0.143672 (0.115 sec/batch), lr: 0.019695
# Evaluating on dev set...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6bc31db1d5bf> in <module>()
#      21     dev_loss = 0
#      22     for i, batch in enumerate(dev_batch):
# ---> 23         preds, _, loss = model.predict(batch)
#      24         predictions += preds
#      25         dev_loss += loss
#
# J:\PyCharmProjects\tac-self-attention\model\rnn.py in predict(self, batch, unsort)
#      98         logits, _ = self.model(inputs)
#      99         loss = self.criterion(logits, labels)
# --> 100         probs = F.softmax(logits, dim=-1).data.cpu().numpy().tolist()
#     101         predictions = np.argmax(logits.data.cpu().numpy(), axis=1).tolist()
#     102         if unsort:
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\tensor.py in cpu(self)
#      43     def cpu(self):
#      44         r"""Returns a CPU copy of this tensor if it's not already on the CPU"""
# ---> 45         return self.type(getattr(torch, self.__class__.__name__))
#      46
#      47     def double(self):
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\cuda\__init__.py in type(self, *args, **kwargs)
#     413     def type(self, *args, **kwargs):
#     414         with device(self.get_device()):
# --> 415             return super(_CudaBase, self).type(*args, **kwargs)
#     416
#     417     __new__ = _lazy_new
#
# J:\Anaconda_Python3_6\envs\cuda\lib\site-packages\torch\_utils.py in _type(self, new_type, async)
#      36     if new_type.is_sparse:
#      37         raise RuntimeError("Cannot cast dense tensor to sparse tensor")
# ---> 38     return new_type(self.size()).copy_(self, async)
#      39
#      40
#
# KeyboardInterrupt:

# %%
# change dropout

# %%
# !!! without any dropout precision is quite high, also 60% fscore after 28 epochs!!

# %%
# using class weights, drouput 0.2
"""
weights = [
    1.0, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
    0.8, 0.8
]
Final Score:
Calculating Precision: correct_by_relation= 2762.0 / guessed_by_relation= 4970.0
Calculating Recall: correct_by_relation= 2762.0 / gold_by_relation= 4143.0
only_non_relation: 4143.0
Precision (micro): 55.573%
   Recall (micro): 66.667%
       F1 (micro): 60.617%
Prediction scores saved to saved_models/out/test_4.pkl.
Evaluation ended.

"""
